# %% [markdown]
# # Data anaylsis in cerebellar granular layer simulations
# ## Running the simulation
#
# First, we set current working directory to the root of Spiking Granular Layer and insert the source folder to the python path:

# %%
import os
os.chdir('../../')
os.getcwd()
import sys
import numpy
# %matplotlib inline
import matplotlib.pyplot as plt
sys.path.insert(1,'./src')

# %% [markdown]
# Now start setting a new simulation with the configuration file that we specify:

# %%
config_file = './config/GoCGrC/SimulationConfigNPR4.cfg'
simulation_time = 100.0
import SpikingSimulation.FrequencySimulation as FrequencySimulation
simulation = FrequencySimulation.FrequencySimulation(config_file=config_file)

# %% [markdown]
# Initialize the simulation

# %%
simulation.config_options['simulation']['verbosity'] = 'Debug'
simulation.config_options['simulation']['seed'] = 123456
simulation.config_options['simulation']['time'] = simulation_time
simulation.config_options['network']['load_file'] = './results/GoCGrC/network01_4mf_NPR.h5'
simulation.config_options['network']['save_file'] = None
simulation.config_options['stimulation']['load_pattern_file'] = './results/GoCGrC/stimulation_NPR4.h5'
simulation.config_options['stimulation']['save_pattern_file'] = None
simulation.config_options['grclayer']['register_activity'] = True
simulation.config_options['goclayer']['register_activity'] = True
simulation.config_options['grclayer']['load_state_vars'] = 'Vth'
simulation.config_options['goclayer']['load_state_vars'] = 'Vth'
simulation.config_options['grclayer']['load_state_vars'] = None
simulation.config_options['goclayer']['load_state_vars'] = None
simulation.initialize()
# Out:
# 2016-11-21 13:20:36,989 - P45858 - Simulation - DEBUG: Simulation time fixed to 100.0s
# 2016-11-21 13:20:36,991 - P45858 - Simulation - DEBUG: Creating cerebellum generator
# 2016-11-21 13:20:37,214 - P45858 - Simulation - DEBUG: Initializing cerebellum generator
# 2016-11-21 13:20:37,215 - P45858 - Simulation - DEBUG: Cerebellar simulation initialized
# 2016-11-21 13:20:37,237 - P45858 - Simulation - DEBUG: NEST module loaded
# 2016-11-21 13:20:37,268 - P45858 - Simulation - DEBUG: Setting Global NEST Seed: 12356
# 2016-11-21 13:20:37,276 - P45858 - Simulation - DEBUG: Setting Per-Process NEST Seeds: [12357, 12358, 12359, 12360, 12361, 12362, 12363, 12364, 12365, 12366]
# 2016-11-21 13:20:37,351 - P45858 - Simulation - WARNING: Non-specified cell model parameter: tau_minus in layer mflayer. Using default value
# 2016-11-21 13:20:37,360 - P45858 - Simulation - WARNING: Non-specified number of neurons in layer mflayer
# 2016-11-21 13:20:37,370 - P45858 - Simulation - WARNING: Non-specified number of neurons in layer grclayer
# 2016-11-21 13:20:37,393 - P45858 - Simulation - WARNING: Non-specified number of neurons in layer goclayer
# 2016-11-21 13:20:37,408 - P45858 - Simulation - WARNING: tau_minus cannot be calculated in layer mflayer. Variable tau_minus is not defined. Using default value 20.0
# 2016-11-21 13:20:37,409 - P45858 - Simulation - WARNING: tau_minus_triplet cannot be calculated in layer mflayer. Variable tau_istdp is not defined. Using default value 110.0
# 2016-11-21 13:20:37,437 - P45858 - Simulation - DEBUG: Nest Process: 0. Neuron layer created in layer mflayer: 300. Local: 300
# 2016-11-21 13:20:37,668 - P45858 - Simulation - DEBUG: Nest Process: 0. Neuron layer created in layer grclayer: 4000. Local: 4000
# 2016-11-21 13:20:37,674 - P45858 - Simulation - DEBUG: Nest Process: 0. Neuron layer created in layer goclayer: 9. Local: 9
# /Users/jgarrido/NEST/nest210/ins_nompi/lib/python2.7/site-packages/nest/lib/hl_api_helper.py:61: UserWarning:
# OneToOneConnect is deprecated and will be removed in a future version of NEST.
# Please use Connect instead!
# For details, see http://www.nest-simulator.org/connection_management
# 2016-11-21 13:20:39,637 - P45858 - Simulation - DEBUG: Nest Process: 0. Connections created in layer mfgrcsynapsis: 16133
# 2016-11-21 13:20:39,920 - P45858 - Simulation - DEBUG: Nest Process: 0. Connections created in layer mfgocsynapsis: 1897
# 2016-11-21 13:20:43,918 - P45858 - Simulation - DEBUG: Nest Process: 0. Connections created in layer grcgocsynapsis: 35915
# 2016-11-21 13:20:44,271 - P45858 - Simulation - DEBUG: Nest Process: 0. Connections created in layer gocgrcsynapsis: 8091
# 2016-11-21 13:20:44,278 - P45858 - Simulation - DEBUG: Nest Process: 0. Connections created in layer gocgocsynapsis: 81
# 2016-11-21 13:20:44,279 - P45858 - Simulation - DEBUG: Creating AC Current generator
# 2016-11-21 13:20:44,282 - P45858 - Simulation - DEBUG: Creating DC Current generator
# 2016-11-21 13:20:44,290 - P45858 - Simulation - INFO: Loading activation patterns from hdf5 file ./results/GoCGrC/stimulation_NPR4.h5
# 2016-11-21 13:20:44,293 - P45858 - Simulation - DEBUG: Loading stimulation pattern 0
# 2016-11-21 13:20:44,295 - P45858 - Simulation - DEBUG: Loading stimulation pattern 1
# 2016-11-21 13:20:44,296 - P45858 - Simulation - DEBUG: Loading stimulation pattern 2
# 2016-11-21 13:20:44,298 - P45858 - Simulation - DEBUG: Loading stimulation pattern 3
# 2016-11-21 13:20:44,301 - P45858 - Simulation - DEBUG: File reading ended
# 2016-11-21 13:20:44,308 - P45858 - Simulation - DEBUG: Pattern 0 and 1 share 9 input cells: [  3  10  63  97  98 166 225 250 291]
# 2016-11-21 13:20:44,310 - P45858 - Simulation - DEBUG: Activation level of pattern 0 in shared cells: [ 0.31384434  0.57676696  0.16831371  0.42600163  0.8247      0.94795745
#   0.12610996  0.33126451  0.30310977]
# 2016-11-21 13:20:44,312 - P45858 - Simulation - DEBUG: Activation level of pattern 1 in shared cells: [ 0.27535109  0.95452754  0.39605282  0.84281578  0.79400769  0.01264391
#   0.66262406  0.68188127  0.56055618]
# 2016-11-21 13:20:44,314 - P45858 - Simulation - DEBUG: Pattern 0 and 2 share 10 input cells: [  6  17  42 108 151 166 192 232 249 287]
# 2016-11-21 13:20:44,315 - P45858 - Simulation - DEBUG: Activation level of pattern 0 in shared cells: [ 0.36215377  0.93545104  0.4321796   0.20337727  0.8763047   0.94795745
#   0.02412733  0.46506151  0.6692381   0.7452776 ]
# 2016-11-21 13:20:44,318 - P45858 - Simulation - DEBUG: Activation level of pattern 2 in shared cells: [ 0.74963008  0.70697753  0.70971614  0.95603006  0.91893935  0.48986737
#   0.65290225  0.31420186  0.50351634  0.92865547]
# 2016-11-21 13:20:44,319 - P45858 - Simulation - DEBUG: Pattern 0 and 3 share 10 input cells: [ 17  42  43  63  98 101 144 151 172 192]
# 2016-11-21 13:20:44,321 - P45858 - Simulation - DEBUG: Activation level of pattern 0 in shared cells: [ 0.93545104  0.4321796   0.75142018  0.16831371  0.8247      0.16729703
#   0.36877867  0.8763047   0.7439374   0.02412733]
# 2016-11-21 13:20:44,323 - P45858 - Simulation - DEBUG: Activation level of pattern 3 in shared cells: [ 1.          0.76985416  0.21513196  0.5976772   0.46424307  0.02378312
#   0.90314845  0.01046952  0.48201751  0.58944637]
# 2016-11-21 13:20:44,325 - P45858 - Simulation - DEBUG: Pattern 1 and 2 share 8 input cells: [  5  15 150 162 166 219 242 255]
# 2016-11-21 13:20:44,326 - P45858 - Simulation - DEBUG: Activation level of pattern 1 in shared cells: [ 0.54752595  0.57425288  0.7430636   0.43275778  0.01264391  0.24871644
#   0.70156692  0.14088301]
# 2016-11-21 13:20:44,329 - P45858 - Simulation - DEBUG: Activation level of pattern 2 in shared cells: [ 0.23014886  0.13830816  0.08593616  0.89562755  0.48986737  0.21630022
#   0.50686006  0.66718018]
# 2016-11-21 13:20:44,332 - P45858 - Simulation - DEBUG: Pattern 1 and 3 share 12 input cells: [ 19  63  98 112 129 155 160 188 245 272 279 284]
# 2016-11-21 13:20:44,335 - P45858 - Simulation - DEBUG: Activation level of pattern 1 in shared cells: [ 0.1587538   0.39605282  0.79400769  0.87871829  0.1899886   0.08618984
#   0.04889717  0.85506368  0.91141739  0.08174307  0.61748296  0.11539903]
# 2016-11-21 13:20:44,338 - P45858 - Simulation - DEBUG: Activation level of pattern 3 in shared cells: [ 0.61557826  0.5976772   0.46424307  0.38925199  0.62303051  0.71416198
#   0.03702566  1.          0.88081103  0.23334569  0.90276667  0.47727511]
# 2016-11-21 13:20:44,340 - P45858 - Simulation - DEBUG: Pattern 2 and 3 share 15 input cells: [ 17  23  42  56  59 119 136 151 192 217 247 252 263 270 289]
# 2016-11-21 13:20:44,342 - P45858 - Simulation - DEBUG: Activation level of pattern 2 in shared cells: [ 0.70697753  0.73999847  0.70971614  0.46204165  0.13040329  0.95618846
#   0.7980752   0.91893935  0.65290225  0.1757998   0.6119256   0.30097695
#   0.69812818  0.28068602  0.34511541]
# 2016-11-21 13:20:44,345 - P45858 - Simulation - DEBUG: Activation level of pattern 3 in shared cells: [ 1.          0.11101392  0.76985416  0.69811594  1.          0.80404384
#   0.24560298  0.01046952  0.58944637  0.87940841  1.          0.15007137
#   0.93464438  0.32819368  0.04236616]
# 2016-11-21 13:20:44,385 - P45858 - Simulation - DEBUG: Normalization on iteration 10
# 2016-11-21 13:20:44,387 - P45858 - Simulation - DEBUG: Average sum per columns 149.954633897
# 2016-11-21 13:20:44,388 - P45858 - Simulation - DEBUG: Average sum per rows 199.439663083

# %% [markdown]
# Visualize the simulation or only run it.

# %%
#simulation.visualize_animation()
simulation.run_simulation()
# Out:
# 2016-11-21 13:20:44,396 - P45858 - Simulation - INFO: Running the simulation from 0.0s until time 100.0s
# 2016-11-21 13:20:44,406 - P45858 - Simulation - DEBUG: Running the simulation 0.177s until 0.177s
# 2016-11-21 13:20:45,523 - P45858 - Simulation - DEBUG: Running the simulation 0.113s until 0.29s
# 2016-11-21 13:20:46,211 - P45858 - Simulation - DEBUG: Running the simulation 0.964s until 1.254s
# 2016-11-21 13:20:56,630 - P45858 - Simulation - DEBUG: Running the simulation 0.38s until 1.634s
# 2016-11-21 13:21:00,749 - P45858 - Simulation - DEBUG: Running the simulation 0.076s until 1.71s
# 2016-11-21 13:21:01,332 - P45858 - Simulation - DEBUG: Running the simulation 0.125s until 1.835s
# 2016-11-21 13:21:02,192 - P45858 - Simulation - DEBUG: Running the simulation 0.024s until 1.859s
# 2016-11-21 13:21:02,356 - P45858 - Simulation - DEBUG: Running the simulation 0.021s until 1.88s
# 2016-11-21 13:21:02,530 - P45858 - Simulation - DEBUG: Running the simulation 0.063s until 1.943s
# 2016-11-21 13:21:02,989 - P45858 - Simulation - DEBUG: Running the simulation 0.352s until 2.295s
# 2016-11-21 13:21:05,523 - P45858 - Simulation - DEBUG: Running the simulation 0.04s until 2.335s
# 2016-11-21 13:21:05,906 - P45858 - Simulation - DEBUG: Running the simulation 0.793s until 3.128s
# 2016-11-21 13:21:13,628 - P45858 - Simulation - DEBUG: Running the simulation 0.393s until 3.521s
# 2016-11-21 13:21:17,527 - P45858 - Simulation - DEBUG: Running the simulation 0.102s until 3.623s
# 2016-11-21 13:21:18,220 - P45858 - Simulation - DEBUG: Running the simulation 0.122s until 3.745s
# 2016-11-21 13:21:19,081 - P45858 - Simulation - DEBUG: Running the simulation 0.084s until 3.829s
# 2016-11-21 13:21:19,767 - P45858 - Simulation - DEBUG: Running the simulation 0.552s until 4.381s
# 2016-11-21 13:21:24,601 - P45858 - Simulation - DEBUG: Running the simulation 0.191s until 4.572s
# 2016-11-21 13:21:26,350 - P45858 - Simulation - DEBUG: Running the simulation 0.344s until 4.916s
# 2016-11-21 13:21:29,397 - P45858 - Simulation - DEBUG: Running the simulation 0.05s until 4.966s
# 2016-11-21 13:21:29,840 - P45858 - Simulation - DEBUG: Running the simulation 0.007s until 4.973s
# 2016-11-21 13:21:29,909 - P45858 - Simulation - DEBUG: Running the simulation 0.321s until 5.294s
# 2016-11-21 13:21:32,774 - P45858 - Simulation - DEBUG: Running the simulation 0.087s until 5.381s
# 2016-11-21 13:21:33,346 - P45858 - Simulation - DEBUG: Running the simulation 0.139s until 5.52s
# 2016-11-21 13:21:34,128 - P45858 - Simulation - DEBUG: Running the simulation 0.122s until 5.642s
# 2016-11-21 13:21:34,794 - P45858 - Simulation - DEBUG: Running the simulation 0.081s until 5.723s
# 2016-11-21 13:21:35,264 - P45858 - Simulation - DEBUG: Running the simulation 0.482s until 6.205s
# 2016-11-21 13:21:39,449 - P45858 - Simulation - DEBUG: Running the simulation 0.369s until 6.574s
# 2016-11-21 13:21:43,186 - P45858 - Simulation - DEBUG: Running the simulation 0.103s until 6.677s
# 2016-11-21 13:22:46,478 - P45858 - Simulation - DEBUG: Running the simulation 0.24s until 14.037s
# 2016-11-21 13:22:48,610 - P45858 - Simulation - DEBUG: Running the simulation 0.047s until 14.084s
# 2016-11-21 13:22:49,087 - P45858 - Simulation - DEBUG: Running the simulation 0.023s until 14.107s
# 2016-11-21 13:22:49,276 - P45858 - Simulation - DEBUG: Running the simulation 0.093s until 14.2s
# 2016-11-21 13:22:50,107 - P45858 - Simulation - DEBUG: Running the simulation 0.09s until 14.29s
# 2016-11-21 13:22:50,680 - P45858 - Simulation - DEBUG: Running the simulation 0.139s until 14.429s
# 2016-11-21 13:22:51,443 - P45858 - Simulation - DEBUG: Running the simulation 0.533s until 14.962s
# 2016-11-21 13:22:55,172 - P45858 - Simulation - DEBUG: Running the simulation 0.314s until 15.276s
# 2016-11-21 13:22:57,976 - P45858 - Simulation - DEBUG: Running the simulation 0.038s until 15.314s
# 2016-11-21 13:22:58,342 - P45858 - Simulation - DEBUG: Running the simulation 0.167s until 15.481s
# 2016-11-21 13:22:59,871 - P45858 - Simulation - DEBUG: Running the simulation 0.206s until 15.687s
# 2016-11-21 13:23:01,803 - P45858 - Simulation - DEBUG: Running the simulation 0.42s until 16.107s
# 2016-11-21 13:23:04,956 - P45858 - Simulation - DEBUG: Running the simulation 0.655s until 16.762s
# 2016-11-21 13:23:09,562 - P45858 - Simulation - DEBUG: Running the simulation 0.246s until 17.008s
# 2016-11-21 13:23:12,241 - P45858 - Simulation - DEBUG: Running the simulation 0.214s until 17.222s
# 2016-11-21 13:23:14,595 - P45858 - Simulation - DEBUG: Running the simulation 0.218s until 17.44s
# 2016-11-21 13:23:16,829 - P45858 - Simulation - DEBUG: Running the simulation 0.211s until 17.651s
# 2016-11-21 13:23:19,113 - P45858 - Simulation - DEBUG: Running the simulation 0.14s until 17.791s
# 2016-11-21 13:23:20,161 - P45858 - Simulation - DEBUG: Running the simulation 0.02s until 17.811s
# 2016-11-21 13:23:20,307 - P45858 - Simulation - DEBUG: Running the simulation 0.414s until 18.225s
# 2016-11-21 13:23:22,808 - P45858 - Simulation - DEBUG: Running the simulation 0.302s until 18.527s
# 2016-11-21 13:23:25,476 - P45858 - Simulation - DEBUG: Running the simulation 0.24s until 18.767s
# 2016-11-21 13:23:27,739 - P45858 - Simulation - DEBUG: Running the simulation 0.395s until 19.162s
# 2016-11-21 13:23:31,457 - P45858 - Simulation - DEBUG: Running the simulation 0.239s until 19.401s
# 2016-11-21 13:23:33,778 - P45858 - Simulation - DEBUG: Running the simulation 0.072s until 19.473s
# 2016-11-21 13:23:34,433 - P45858 - Simulation - DEBUG: Running the simulation 0.231s until 19.704s
# 2016-11-21 13:23:35,738 - P45858 - Simulation - DEBUG: Running the simulation 0.117s until 19.821s
# 2016-11-21 13:23:36,404 - P45858 - Simulation - DEBUG: Running the simulation 0.103s until 19.924s
# 2016-11-21 13:23:36,946 - P45858 - Simulation - DEBUG: Running the simulation 0.073s until 19.997s
# 2016-11-21 13:25:15,354 - P45858 - Simulation - DEBUG: Running the simulation 0.025s until 31.447s
# 2016-11-21 13:25:15,653 - P45858 - Simulation - DEBUG: Running the simulation 0.499s until 31.946s
# 2016-11-21 13:25:20,928 - P45858 - Simulation - DEBUG: Running the simulation 0.465s until 32.411s
# 2016-11-21 13:25:24,433 - P45858 - Simulation - DEBUG: Running the simulation 0.024s until 32.435s
# 2016-11-21 13:25:24,658 - P45858 - Simulation - DEBUG: Running the simulation 0.406s until 32.841s
# 2016-11-21 13:25:28,500 - P45858 - Simulation - DEBUG: Running the simulation 0.077s until 32.918s
# 2016-11-21 13:25:29,372 - P45858 - Simulation - DEBUG: Running the simulation 0.068s until 32.986s
# 2016-11-21 13:25:30,193 - P45858 - Simulation - DEBUG: Running the simulation 0.494s until 33.48s
# 2016-11-21 13:25:35,397 - P45858 - Simulation - DEBUG: Running the simulation 0.046s until 33.526s
# 2016-11-21 13:25:35,970 - P45858 - Simulation - DEBUG: Running the simulation 0.002s until 33.528s
# 2016-11-21 13:25:36,008 - P45858 - Simulation - DEBUG: Running the simulation 0.209s until 33.737s
# 2016-11-21 13:25:38,785 - P45858 - Simulation - DEBUG: Running the simulation 0.334s until 34.071s
# 2016-11-21 13:25:41,282 - P45858 - Simulation - DEBUG: Running the simulation 0.14s until 34.211s
# 2016-11-21 13:25:42,058 - P45858 - Simulation - DEBUG: Running the simulation 0.089s until 34.3s
# 2016-11-21 13:25:42,617 - P45858 - Simulation - DEBUG: Running the simulation 0.192s until 34.492s
# 2016-11-21 13:25:44,293 - P45858 - Simulation - DEBUG: Running the simulation 0.142s until 34.634s
# 2016-11-21 13:25:46,176 - P45858 - Simulation - DEBUG: Running the simulation 0.038s until 34.672s
# 2016-11-21 13:25:46,685 - P45858 - Simulation - DEBUG: Running the simulation 0.019s until 34.691s
# 2016-11-21 13:25:46,947 - P45858 - Simulation - DEBUG: Running the simulation 0.135s until 34.826s
# 2016-11-21 13:25:48,808 - P45858 - Simulation - DEBUG: Running the simulation 0.645s until 35.471s
# 2016-11-21 13:25:55,962 - P45858 - Simulation - DEBUG: Running the simulation 0.276s until 35.747s
# 2016-11-21 13:25:58,709 - P45858 - Simulation - DEBUG: Running the simulation 0.431s until 36.178s
# 2016-11-21 13:26:01,565 - P45858 - Simulation - DEBUG: Running the simulation 0.049s until 36.227s
# 2016-11-21 13:26:02,001 - P45858 - Simulation - DEBUG: Running the simulation 0.347s until 36.574s
# 2016-11-21 13:26:05,881 - P45858 - Simulation - DEBUG: Running the simulation 0.17s until 36.744s
# 2016-11-21 13:26:07,489 - P45858 - Simulation - DEBUG: Running the simulation 0.509s until 37.253s
# 2016-11-21 13:26:13,377 - P45858 - Simulation - DEBUG: Running the simulation 0.113s until 37.366s
# 2016-11-21 13:26:14,567 - P45858 - Simulation - DEBUG: Running the simulation 0.06s until 37.426s
# 2016-11-21 13:26:15,157 - P45858 - Simulation - DEBUG: Running the simulation 0.969s until 38.395s
# 2016-11-21 13:26:23,478 - P45858 - Simulation - DEBUG: Running the simulation 0.15s until 38.545s
# 2016-11-21 13:26:25,311 - P45858 - Simulation - DEBUG: Running the simulation 0.47s until 39.015s
# 2016-11-21 13:26:31,005 - P45858 - Simulation - DEBUG: Running the simulation 0.031s until 39.046s
# 2016-11-21 13:26:31,382 - P45858 - Simulation - DEBUG: Running the simulation 0.873s until 39.919s
# 2016-11-21 13:26:40,252 - P45858 - Simulation - DEBUG: Running the simulation 0.188s until 40.107s
# 2016-11-21 13:26:41,920 - P45858 - Simulation - DEBUG: Running the simulation 0.916s until 41.023s
# 2016-11-21 13:26:52,884 - P45858 - Simulation - DEBUG: Running the simulation 0.448s until 41.471s
# 2016-11-21 13:26:57,843 - P45858 - Simulation - DEBUG: Running the simulation 0.118s until 41.589s
# 2016-11-21 13:26:58,693 - P45858 - Simulation - DEBUG: Running the simulation 0.071s until 41.66s
# 2016-11-21 13:26:59,147 - P45858 - Simulation - DEBUG: Running the simulation 0.072s until 41.732s
# 2016-11-21 13:26:59,597 - P45858 - Simulation - DEBUG: Running the simulation 0.345s until 42.077s
# 2016-11-21 13:27:01,953 - P45858 - Simulation - DEBUG: Running the simulation 0.029s until 42.106s
# 2016-11-21 13:27:02,408 - P45858 - Simulation - DEBUG: Running the simulation 0.849s until 42.955s
# 2016-11-21 13:27:12,968 - P45858 - Simulation - DEBUG: Running the simulation 0.692s until 43.647s
# 2016-11-21 13:27:19,475 - P45858 - Simulation - DEBUG: Running the simulation 0.011s until 43.658s
# 2016-11-21 13:27:19,584 - P45858 - Simulation - DEBUG: Running the simulation 0.002s until 43.66s
# 2016-11-21 13:27:19,608 - P45858 - Simulation - DEBUG: Running the simulation 0.133s until 43.793s
# 2016-11-21 13:27:20,835 - P45858 - Simulation - DEBUG: Running the simulation 0.239s until 44.032s
# 2016-11-21 13:27:22,969 - P45858 - Simulation - DEBUG: Running the simulation 1.351s until 45.383s
# 2016-11-21 13:27:39,438 - P45858 - Simulation - DEBUG: Running the simulation 0.206s until 45.589s
# 2016-11-21 13:27:40,876 - P45858 - Simulation - DEBUG: Running the simulation 0.235s until 45.824s
# 2016-11-21 13:27:42,536 - P45858 - Simulation - DEBUG: Running the simulation 0.073s until 45.897s
# 2016-11-21 13:27:43,315 - P45858 - Simulation - DEBUG: Running the simulation 0.032s until 45.929s
# 2016-11-21 13:27:43,765 - P45858 - Simulation - DEBUG: Running the simulation 0.218s until 46.147s
# 2016-11-21 13:27:46,527 - P45858 - Simulation - DEBUG: Running the simulation 0.132s until 46.279s
# 2016-11-21 13:27:47,923 - P45858 - Simulation - DEBUG: Running the simulation 0.572s until 46.851s
# 2016-11-21 13:27:54,337 - P45858 - Simulation - DEBUG: Running the simulation 0.573s until 47.424s
# 2016-11-21 13:28:00,001 - P45858 - Simulation - DEBUG: Running the simulation 0.284s until 47.708s
# 2016-11-21 13:28:01,923 - P45858 - Simulation - DEBUG: Running the simulation 0.232s until 47.94s
# 2016-11-21 13:28:04,351 - P45858 - Simulation - DEBUG: Running the simulation 0.026s until 47.966s
# 2016-11-21 13:30:37,341 - P45858 - Simulation - DEBUG: Running the simulation 0.141s until 64.513s
# 2016-11-21 13:30:38,414 - P45858 - Simulation - DEBUG: Running the simulation 0.09s until 64.603s
# 2016-11-21 13:30:39,259 - P45858 - Simulation - DEBUG: Running the simulation 0.051s until 64.654s
# 2016-11-21 13:30:39,720 - P45858 - Simulation - DEBUG: Running the simulation 0.39s until 65.044s
# 2016-11-21 13:30:43,115 - P45858 - Simulation - DEBUG: Running the simulation 0.466s until 65.51s
# 2016-11-21 13:30:47,168 - P45858 - Simulation - DEBUG: Running the simulation 0.002s until 65.512s
# 2016-11-21 13:30:47,190 - P45858 - Simulation - DEBUG: Running the simulation 0.052s until 65.564s
# 2016-11-21 13:30:47,662 - P45858 - Simulation - DEBUG: Running the simulation 0.041s until 65.605s
# 2016-11-21 13:30:48,030 - P45858 - Simulation - DEBUG: Running the simulation 0.726s until 66.331s
# 2016-11-21 13:30:52,672 - P45858 - Simulation - DEBUG: Running the simulation 0.075s until 66.406s
# 2016-11-21 13:30:53,316 - P45858 - Simulation - DEBUG: Running the simulation 0.159s until 66.565s
# 2016-11-21 13:30:54,696 - P45858 - Simulation - DEBUG: Running the simulation 0.315s until 66.88s
# 2016-11-21 13:30:57,404 - P45858 - Simulation - DEBUG: Running the simulation 0.493s until 67.373s
# 2016-11-21 13:31:01,669 - P45858 - Simulation - DEBUG: Running the simulation 0.547s until 67.92s
# 2016-11-21 13:31:05,179 - P45858 - Simulation - DEBUG: Running the simulation 0.382s until 68.302s
# 2016-11-21 13:31:08,205 - P45858 - Simulation - DEBUG: Running the simulation 0.223s until 68.525s
# 2016-11-21 13:31:10,130 - P45858 - Simulation - DEBUG: Running the simulation 0.059s until 68.584s
# 2016-11-21 13:31:10,669 - P45858 - Simulation - DEBUG: Running the simulation 0.053s until 68.637s
# 2016-11-21 13:31:11,134 - P45858 - Simulation - DEBUG: Running the simulation 1.285s until 69.922s
# 2016-11-21 13:31:20,592 - P45858 - Simulation - DEBUG: Running the simulation 0.649s until 70.571s
# 2016-11-21 13:31:26,211 - P45858 - Simulation - DEBUG: Running the simulation 0.152s until 70.723s
# 2016-11-21 13:31:27,539 - P45858 - Simulation - DEBUG: Running the simulation 0.531s until 71.254s
# 2016-11-21 13:31:32,426 - P45858 - Simulation - DEBUG: Running the simulation 0.484s until 71.738s
# 2016-11-21 13:31:35,588 - P45858 - Simulation - DEBUG: Running the simulation 0.946s until 72.684s
# 2016-11-21 13:31:46,241 - P45858 - Simulation - DEBUG: Running the simulation 0.47s until 73.154s
# 2016-11-21 13:31:50,700 - P45858 - Simulation - DEBUG: Running the simulation 0.175s until 73.329s
# 2016-11-21 13:31:52,039 - P45858 - Simulation - DEBUG: Running the simulation 0.48s until 73.809s
# 2016-11-21 13:31:55,408 - P45858 - Simulation - DEBUG: Running the simulation 0.155s until 73.964s
# 2016-11-21 13:31:56,896 - P45858 - Simulation - DEBUG: Running the simulation 0.215s until 74.179s
# 2016-11-21 13:31:59,172 - P45858 - Simulation - DEBUG: Running the simulation 0.298s until 74.477s
# 2016-11-21 13:32:58,452 - P45858 - Simulation - DEBUG: Running the simulation 0.168s until 81.675s
# 2016-11-21 13:32:59,955 - P45858 - Simulation - DEBUG: Running the simulation 0.062s until 81.737s
# 2016-11-21 13:33:00,503 - P45858 - Simulation - DEBUG: Running the simulation 0.471s until 82.208s
# 2016-11-21 13:33:04,594 - P45858 - Simulation - DEBUG: Running the simulation 0.127s until 82.335s
# 2016-11-21 13:33:05,722 - P45858 - Simulation - DEBUG: Running the simulation 0.223s until 82.558s
# 2016-11-21 13:33:07,131 - P45858 - Simulation - DEBUG: Running the simulation 0.251s until 82.809s
# 2016-11-21 13:33:08,543 - P45858 - Simulation - DEBUG: Running the simulation 0.148s until 82.957s
# 2016-11-21 13:33:09,630 - P45858 - Simulation - DEBUG: Running the simulation 0.001s until 82.958s
# 2016-11-21 13:33:09,646 - P45858 - Simulation - DEBUG: Running the simulation 0.001s until 82.959s
# 2016-11-21 13:33:09,670 - P45858 - Simulation - DEBUG: Running the simulation 0.648s until 83.607s
# 2016-11-21 13:33:15,251 - P45858 - Simulation - DEBUG: Running the simulation 0.459s until 84.066s
# 2016-11-21 13:33:19,299 - P45858 - Simulation - DEBUG: Running the simulation 0.538s until 84.604s
# 2016-11-21 13:33:22,747 - P45858 - Simulation - DEBUG: Running the simulation 0.215s until 84.819s
# 2016-11-21 13:33:24,070 - P45858 - Simulation - DEBUG: Running the simulation 0.151s until 84.97s
# 2016-11-21 13:33:25,375 - P45858 - Simulation - DEBUG: Running the simulation 0.018s until 84.988s
# 2016-11-21 13:33:25,553 - P45858 - Simulation - DEBUG: Running the simulation 0.246s until 85.234s
# 2016-11-21 13:33:27,695 - P45858 - Simulation - DEBUG: Running the simulation 0.045s until 85.279s
# 2016-11-21 13:33:28,130 - P45858 - Simulation - DEBUG: Running the simulation 0.156s until 85.435s
# 2016-11-21 13:33:29,512 - P45858 - Simulation - DEBUG: Running the simulation 0.177s until 85.612s
# 2016-11-21 13:33:30,992 - P45858 - Simulation - DEBUG: Running the simulation 0.084s until 85.696s
# 2016-11-21 13:33:31,767 - P45858 - Simulation - DEBUG: Running the simulation 0.016s until 85.712s
# 2016-11-21 13:33:31,910 - P45858 - Simulation - DEBUG: Running the simulation 0.214s until 85.926s
# 2016-11-21 13:33:33,760 - P45858 - Simulation - DEBUG: Running the simulation 0.057s until 85.983s
# 2016-11-21 13:33:34,249 - P45858 - Simulation - DEBUG: Running the simulation 0.118s until 86.101s
# 2016-11-21 13:33:35,212 - P45858 - Simulation - DEBUG: Running the simulation 0.197s until 86.298s
# 2016-11-21 13:33:36,286 - P45858 - Simulation - DEBUG: Running the simulation 0.405s until 86.703s
# 2016-11-21 13:33:38,787 - P45858 - Simulation - DEBUG: Running the simulation 0.082s until 86.785s
# 2016-11-21 13:33:39,508 - P45858 - Simulation - DEBUG: Running the simulation 0.031s until 86.816s
# 2016-11-21 13:33:39,818 - P45858 - Simulation - DEBUG: Running the simulation 0.089s until 86.905s
# 2016-11-21 13:33:40,610 - P45858 - Simulation - DEBUG: Running the simulation 0.44s until 87.345s
# 2016-11-21 13:33:44,288 - P45858 - Simulation - DEBUG: Running the simulation 0.036s until 87.381s
# 2016-11-21 13:33:44,636 - P45858 - Simulation - DEBUG: Running the simulation 0.276s until 87.657s
# 2016-11-21 13:33:47,143 - P45858 - Simulation - DEBUG: Running the simulation 0.421s until 88.078s
# 2016-11-21 13:33:50,236 - P45858 - Simulation - DEBUG: Running the simulation 1.004s until 89.082s
# 2016-11-21 13:33:57,776 - P45858 - Simulation - DEBUG: Running the simulation 0.02s until 89.102s
# 2016-11-21 13:33:57,943 - P45858 - Simulation - DEBUG: Running the simulation 0.009s until 89.111s
# 2016-11-21 13:33:58,046 - P45858 - Simulation - DEBUG: Running the simulation 0.075s until 89.186s
# 2016-11-21 13:33:58,696 - P45858 - Simulation - DEBUG: Running the simulation 0.49s until 89.676s
# 2016-11-21 13:34:02,908 - P45858 - Simulation - DEBUG: Running the simulation 0.262s until 89.938s
# 2016-11-21 13:34:04,734 - P45858 - Simulation - DEBUG: Running the simulation 0.156s until 90.094s
# 2016-11-21 13:34:05,573 - P45858 - Simulation - DEBUG: Running the simulation 0.091s until 90.185s
# 2016-11-21 13:34:06,063 - P45858 - Simulation - DEBUG: Running the simulation 0.202s until 90.387s
# 2016-11-21 13:34:07,436 - P45858 - Simulation - DEBUG: Running the simulation 0.088s until 90.475s
# 2016-11-21 13:34:08,187 - P45858 - Simulation - DEBUG: Running the simulation 0.37s until 90.845s
# 2016-11-21 13:34:11,525 - P45858 - Simulation - DEBUG: Running the simulation 0.105s until 90.95s
# 2016-11-21 13:34:12,467 - P45858 - Simulation - DEBUG: Running the simulation 1.178s until 92.128s
# 2016-11-21 13:34:20,956 - P45858 - Simulation - DEBUG: Running the simulation 0.925s until 93.053s
# 2016-11-21 13:34:29,031 - P45858 - Simulation - DEBUG: Running the simulation 0.104s until 93.157s
# 2016-11-21 13:34:29,911 - P45858 - Simulation - DEBUG: Running the simulation 0.304s until 93.461s
# 2016-11-21 13:34:32,514 - P45858 - Simulation - DEBUG: Running the simulation 0.303s until 93.764s
# 2016-11-21 13:34:34,156 - P45858 - Simulation - DEBUG: Running the simulation 0.629s until 94.393s
# 2016-11-21 13:34:38,938 - P45858 - Simulation - DEBUG: Running the simulation 0.421s until 94.814s
# 2016-11-21 13:34:42,505 - P45858 - Simulation - DEBUG: Running the simulation 0.093s until 94.907s
# 2016-11-21 13:34:43,317 - P45858 - Simulation - DEBUG: Running the simulation 0.198s until 95.105s
# 2016-11-21 13:34:45,028 - P45858 - Simulation - DEBUG: Running the simulation 0.072s until 95.177s
# 2016-11-21 13:34:45,648 - P45858 - Simulation - DEBUG: Running the simulation 0.19s until 95.367s
# 2016-11-21 13:34:47,100 - P45858 - Simulation - DEBUG: Running the simulation 0.337s until 95.704s
# 2016-11-21 13:34:48,933 - P45858 - Simulation - DEBUG: Running the simulation 0.063s until 95.767s
# 2016-11-21 13:34:49,276 - P45858 - Simulation - DEBUG: Running the simulation 0.243s until 96.01s
# 2016-11-21 13:34:51,349 - P45858 - Simulation - DEBUG: Running the simulation 0.383s until 96.393s
# 2016-11-21 13:34:54,713 - P45858 - Simulation - DEBUG: Running the simulation 0.388s until 96.781s
# 2016-11-21 13:34:58,082 - P45858 - Simulation - DEBUG: Running the simulation 0.052s until 96.833s
# 2016-11-21 13:34:58,537 - P45858 - Simulation - DEBUG: Running the simulation 0.027s until 96.86s
# 2016-11-21 13:34:58,775 - P45858 - Simulation - DEBUG: Running the simulation 0.366s until 97.226s
# 2016-11-21 13:35:01,593 - P45858 - Simulation - DEBUG: Running the simulation 0.11s until 97.336s
# 2016-11-21 13:35:02,181 - P45858 - Simulation - DEBUG: Running the simulation 0.369s until 97.705s
# 2016-11-21 13:35:04,431 - P45858 - Simulation - DEBUG: Running the simulation 0.028s until 97.733s
# 2016-11-21 13:35:04,686 - P45858 - Simulation - DEBUG: Running the simulation 0.179s until 97.912s
# 2016-11-21 13:35:06,244 - P45858 - Simulation - DEBUG: Running the simulation 0.407s until 98.319s
# 2016-11-21 13:35:09,801 - P45858 - Simulation - DEBUG: Running the simulation 0.154s until 98.473s
# 2016-11-21 13:35:11,097 - P45858 - Simulation - DEBUG: Running the simulation 0.632s until 99.105s
# 2016-11-21 13:35:16,134 - P45858 - Simulation - DEBUG: Running the simulation 0.337s until 99.442s
# 2016-11-21 13:35:17,965 - P45858 - Simulation - DEBUG: Running the simulation 0.053s until 99.495s
# 2016-11-21 13:35:18,363 - P45858 - Simulation - DEBUG: Running the simulation 0.061s until 99.556s
# 2016-11-21 13:35:18,901 - P45858 - Simulation - DEBUG: Running the simulation 0.444s until 100.0s

# %% [markdown]
# Save the network state after the simulation

# %%
#simulation.cerebellum.update_network_weights()
#simulation.cerebellum.save_network()

# %% [markdown]
# ## GrC activity analysis

# %% [markdown]
# Calculate the average firing frequency of each granular cells during the ending 100 seconds

# %%
gtime,gcell_id = simulation.cerebellum.get_spike_activity(neuron_layer = 'grclayer',
                                                          init_time = simulation.current_time-200.0, 
                                                          end_time = simulation.current_time)
import numpy
firing_frequency = numpy.bincount(gcell_id) / (simulation_time*8.0)
# %matplotlib inline
import matplotlib.pyplot as plt
plt.hist(firing_frequency, bins=20)
plt.ylabel('Number of GrC cells')
plt.xlabel('Av. Spikes per Oscillatory Cycle')

# %% [markdown]
# Get the histogram of input synapses for the granular cells

# %%
target_cell_index = simulation.cerebellum.layer_map['mfgrcsynapsis'].target_index
cell_number = simulation.cerebellum.layer_map['grclayer'].number_of_neurons
number_of_inputs = numpy.bincount(target_cell_index)
plt.hist(number_of_inputs, bins=30)
plt.ylabel('Number of GrC cells')
plt.xlabel('Number of input synapses from glomeruli')

# %% [markdown]
# Plot the histogram of non-zero weights between MF and GrC

# %%
target_cell_index = simulation.cerebellum.layer_map['mfgrcsynapsis'].target_index
source_cell_index = simulation.cerebellum.layer_map['mfgrcsynapsis'].source_index
weight = simulation.cerebellum.layer_map['mfgrcsynapsis'].weights
plt.figure()
plt.hist(weight, bins=20)
plt.ylabel('Synaptic Weight')
plt.xlabel('Number of MF-GrC synapses')
max_weight = numpy.max(weight)
active_synapses = weight>max_weight*0.2
number_of_active_inputs = numpy.bincount(target_cell_index[active_synapses])
plt.figure()
plt.hist(number_of_active_inputs, bins=10)
plt.ylabel('Number of GrC cells')
plt.xlabel('Number of active inputs')
print 'Number of active synapses MF-GrC:',numpy.count_nonzero(active_synapses)
# Out:
# Number of active synapses MF-GrC: 16133

# %% [markdown]
# Histogram of active synapses connecting input fibers included in the pattern

# %%
for pat_id in range(simulation.pattern_generator.number_of_patterns):
    included_in_pattern = numpy.in1d(source_cell_index, simulation.pattern_generator.fibers_in_pattern[pat_id,:])
    included_and_active = numpy.logical_and(included_in_pattern,active_synapses)
    number_of_active_inputs_in_pattern = numpy.bincount(target_cell_index[included_and_active])
    plt.figure()
    plt.hist(number_of_active_inputs_in_pattern, bins=10)
    plt.ylabel('Number of GrC cells')
    plt.xlabel('Number of active inputs in pattern')
    print 'Number of active MF-GrC synapses also included in pattern',pat_id,':', numpy.count_nonzero(included_and_active)
    plt.figure()
    simulation.pattern_generator.fibers_in_pattern[0,:]
    activation_level = [simulation.pattern_generator.pattern_activation[pat_id,numpy.where(simulation.pattern_generator.fibers_in_pattern[pat_id,:]==source)[0][0]] 
                    for source in source_cell_index[included_and_active]]
    plt.hist(activation_level, bins=20)
    plt.ylabel('Number of active synapses')
    plt.xlabel('Activation level')
# Out:
# Number of active MF-GrC synapses also included in pattern 0 : 3093
# Number of active MF-GrC synapses also included in pattern 1 : 3131
# Number of active MF-GrC synapses also included in pattern 2 : 3156
# Number of active MF-GrC synapses also included in pattern 3 : 3100

# %% [markdown]
# Define some auxiliar functions:

# %%
def calc_Ind_Pattern_Hit_Matrix(cell_firing, pattern_present):
    '''
    Calculate the correct rejection, hit, miss and false alarm matrisses with 1 line for each cell and 1 column for each pattern (including noise).
    @param cell_firing Boolean matrix including 1 line for each cell and 1 column for each time bin.
    @param pattern_present Boolean matrix including 1 line for each pattern and 1 column for each time bin.
    '''
    hit_matrix = numpy.empty((len(pattern_present),len(cell_firing)))
    cr_matrix = numpy.empty((len(pattern_present),len(cell_firing)))
    miss_matrix = numpy.empty((len(pattern_present),len(cell_firing)))
    fa_matrix = numpy.empty((len(pattern_present),len(cell_firing)))
    faa_matrix = numpy.empty((len(cell_firing)))
    
    for index_pat, pattern in enumerate(pattern_present):
        if (numpy.count_nonzero(pattern)):
            for index_cell, firing in enumerate(cell_firing):
                hit_matrix[index_pat,index_cell] = numpy.count_nonzero(firing&pattern)/float(numpy.count_nonzero(pattern))
                cr_matrix[index_pat,index_cell] = numpy.count_nonzero(~firing&~pattern)/float(numpy.count_nonzero(~pattern))
                miss_matrix[index_pat,index_cell] = numpy.count_nonzero(~firing&pattern)/float(numpy.count_nonzero(pattern))
                fa_matrix[index_pat,index_cell] = numpy.count_nonzero(firing&~pattern)/float(numpy.count_nonzero(~pattern))
        else:
            print 'Pattern',index_pat,'never occurs. Statistics will not be calculated'
               
    any_pattern = numpy.any(pattern_present, axis=0)
    for index_cell, firing in enumerate(cell_firing):
        faa_matrix[index_cell] = numpy.count_nonzero(firing&~any_pattern)/float(numpy.count_nonzero(~any_pattern))
        
    return cr_matrix, hit_matrix, miss_matrix, fa_matrix, faa_matrix

def analyze_activity(layer, window_length, time_bin):

    cell_index = range(simulation.cerebellum.get_number_of_elements(layer=layer))
    pattern_generator = simulation.pattern_generator
    inv_time_bin = 1./time_bin

    # Generate the time bin matrix
    total_time = pattern_generator.simulation_time
    bin_time_init = numpy.linspace(0.0, window_length-time_bin, num=window_length*inv_time_bin)
    bin_time_end = numpy.linspace(time_bin,window_length,num=window_length*inv_time_bin)

    # Initialize a matrix
    pattern_index = range(0,pattern_generator.number_of_patterns)
    num_patterns = len(pattern_index)
    num_bins = len(bin_time_init)
    num_cells = len(cell_index)

    # Calculate the time of each pattern interval
    time_end_of_pattern = pattern_generator.pattern_length_cum
    time_init_of_pattern = numpy.append([0.0],time_end_of_pattern[:-1])

    # Calculate the bin of each pattern interval. Check the round of the last bin to avoid out of range
    bin_end_of_pattern = numpy.floor(time_end_of_pattern * inv_time_bin).astype(int)
    if (bin_end_of_pattern[-1]>=num_bins):
        bin_end_of_pattern[-1]=num_bins-1
    bin_init_of_pattern = numpy.append([0],bin_end_of_pattern[:-1])
    if (bin_init_of_pattern[-1]>=num_bins):
        bin_init_of_pattern[-1]=num_bins-1

    # Final matrix indicating which bins are considered of each pattern
    bin_is_pattern = numpy.empty((num_patterns, num_bins),dtype='bool')
    bin_is_pattern[:,:] = False
    bin_pattern = numpy.zeros(num_bins)

    # Final matrix indicating which bins are registered spikes
    bin_has_fired = numpy.empty((num_cells, num_bins), dtype='bool')
    bin_has_fired[:,:] = False

    for key, value in enumerate(pattern_index):
        time_of_pattern_in_bin = numpy.zeros(num_bins)
        for index in pattern_generator.pattern_id_index[value]:
            init_bin = bin_init_of_pattern[index]
            end_bin = bin_end_of_pattern[index]

            list_of_bins = range(init_bin,end_bin+1)

            # Add the time of the initial bin (if exists)
            if init_bin!=end_bin:
                time_of_pattern_in_bin[list_of_bins[0]] += (bin_time_end[init_bin] - time_init_of_pattern[index])

            # Add the time of the intermediate bins (if exist)
            time_of_pattern_in_bin[list_of_bins[1:-1]] += time_bin

            # Add the time of the final bin
            time_of_pattern_in_bin[list_of_bins[-1]] += (time_end_of_pattern[index] - max(time_init_of_pattern[index],bin_time_init[end_bin]))

        # Those bins where the time in the pattern is longer than half of the bin are set to part of that pattern    
        bin_is_pattern[key,time_of_pattern_in_bin>(time_bin/2.)] = True
        bin_pattern[bin_is_pattern[key,:]] = bin_pattern[bin_is_pattern[key,:]] + 2**value

    # Create a map of cells to index
    cell_map = dict()
    for key, value in enumerate(cell_index):
        cell_map[value] = key

    # Load data from the data provider
    gtime,gcell_id = simulation.cerebellum.get_spike_activity(neuron_layer = layer, init_time = 0.0, end_time = window_length)


    spike_bin_index = numpy.floor(gtime*inv_time_bin).astype(int)

    av_firing_rate = float(len(gtime))/(len(cell_index)*(window_length))
    print 'Average firing rate in MI analysis:',av_firing_rate,'Hz'

    cell_index = numpy.array([cell_map[value] for value in gcell_id])

    # Final matrix indicating which bins are registered spikes
    if len(spike_bin_index) and len(cell_index):
        bin_has_fired[cell_index,spike_bin_index] = True

    # Calculate mutual information in the time window
    init_bin = int(0 * inv_time_bin)
    end_bin = int(window_length * inv_time_bin)


    # Calculate hit matrix for each pattern
    cr_matrix, hit_matrix, miss_matrix, fa_matrix, faa_matrix = calc_Ind_Pattern_Hit_Matrix(bin_has_fired[:,init_bin:end_bin], bin_is_pattern[:,init_bin:end_bin])

    return cr_matrix, hit_matrix, miss_matrix, fa_matrix, faa_matrix

# %% [markdown]
# Represent the hit rate matrix of each GrC to each pattern

# %%
layer = 'grclayer'
window_length = simulation.config_options['hit_analysis']['window_length'] = 200.0
time_bin = simulation.config_options['hit_analysis']['time_bin'] = 0.125

cr_matrix, hit_matrix, miss_matrix, fa_matrix, faa_matrix = analyze_activity(layer, window_length, time_bin)

#numpy.set_printoptions(threshold=numpy.nan)
#print 'Individual pattern hit matrix:'
#print hit_matrix
#print 'Individual pattern correct rejection matrix:'
#print cr_matrix
#print 'Individual pattern miss matrix:'
#print miss_matrix
#print 'Individual pattern false alarm matrix:'
#print fa_matrix
#print 'All patterns false alarm array:'
#print faa_matrix

extended_hit = numpy.append(hit_matrix, [faa_matrix], axis=0)
selected_pattern = numpy.argmax(extended_hit, axis=0)
plt.figure()
plt.hist(selected_pattern, bins=simulation.pattern_generator.number_of_patterns+1)
plt.ylabel('Count GrCs')
plt.xlabel('Favourite pattern')
cell_sorted = numpy.argsort(selected_pattern)
plt.figure()
plt.matshow(extended_hit[:,cell_sorted], extent=[0,simulation.cerebellum.get_number_of_elements(layer=layer),
                                                 simulation.pattern_generator.number_of_patterns+1,0], 
            vmin=0, vmax=1.0, aspect='auto')
plt.ylabel('Pattern')
plt.xlabel('GrC neuron')
plt.colorbar()
# Out:
# Average firing rate in MI analysis: 1.8425225 Hz

# %% [markdown]
# Estimate the goodness of the matrix

# %%
extended_hit = numpy.append(hit_matrix, [faa_matrix], axis=0)
selected_pattern = numpy.argmax(extended_hit, axis=0)

# Select those cells mainly responding to one of the patterns
ind = numpy.where(selected_pattern<simulation.pattern_generator.number_of_patterns)

diagonal = hit_matrix[selected_pattern[ind],ind]

# Create a new matrix setting the diagonal values to zero
zero_matrix = hit_matrix
zero_matrix[selected_pattern[ind],ind] = 0.0

# Calculate the average of the diagonal elements
av_selected = numpy.average(diagonal)
av_nonselected = numpy.sum(zero_matrix[:])/(simulation.cerebellum.get_number_of_elements(layer=layer)*(simulation.pattern_generator.number_of_patterns-1))
print 'Average hits of selected elements:',av_selected
print 'Average hits of non-selected elements:',av_nonselected
hit_index = av_selected - av_nonselected
print 'Hit index:',hit_index
# Out:
# Average hits of selected elements: 0.304983439534
# Average hits of non-selected elements: 0.2724485435
# Hit index: 0.0325348960335

# %% [markdown]
# ## GoC activity analysis

# %% [markdown]
# Calculate the average firing frequency of each Golgi cells during the ending 100 seconds

# %%
gtime,gcell_id = simulation.cerebellum.get_spike_activity(neuron_layer = 'goclayer',
                                                          init_time = simulation.current_time-200.0, 
                                                          end_time = simulation.current_time)
import numpy
firing_frequency = numpy.bincount(gcell_id) / (simulation_time*8.0)
# %matplotlib inline
import matplotlib.pyplot as plt
plt.hist(firing_frequency, bins=20)
plt.ylabel('Number of GoC cells')
plt.xlabel('Av. Spikes per Oscillatory Cycle')

# %% [markdown]
# Get the histogram of input synapses for the Golgi cells

# %%
target_cell_index = simulation.cerebellum.layer_map['mfgocsynapsis'].target_index
cell_number = simulation.cerebellum.layer_map['goclayer'].number_of_neurons
number_of_inputs = numpy.bincount(target_cell_index)
plt.hist(number_of_inputs, bins=30)
plt.ylabel('Number of GoC cells')
plt.xlabel('Number of input synapses from glomeruli')

# %% [markdown]
# Plot the histogram of non-zero weights between MF and GoC

# %%
target_cell_index = simulation.cerebellum.layer_map['mfgocsynapsis'].target_index
source_cell_index = simulation.cerebellum.layer_map['mfgocsynapsis'].source_index
weight = simulation.cerebellum.layer_map['mfgocsynapsis'].weights
plt.figure()
plt.hist(weight, bins=20)
plt.ylabel('Synaptic Weight')
plt.xlabel('Number of MF-GoC synapses')
max_weight = numpy.max(weight)
active_synapses = weight>max_weight*0.2
number_of_active_inputs = numpy.bincount(target_cell_index[active_synapses])
plt.figure()
plt.hist(number_of_active_inputs, bins=10)
plt.ylabel('Number of GoC cells')
plt.xlabel('Number of active inputs')
print 'Number of active synapses MF-GoC:',numpy.count_nonzero(active_synapses)
# Out:
# Number of active synapses MF-GoC: 1897

# %% [markdown]
# Histogram of active synapses connecting input fibers included in the pattern

# %%
for pat_id in range(simulation.pattern_generator.number_of_patterns):
    included_in_pattern = numpy.in1d(source_cell_index, simulation.pattern_generator.fibers_in_pattern[pat_id,:])
    included_and_active = numpy.logical_and(included_in_pattern,active_synapses)
    number_of_active_inputs_in_pattern = numpy.bincount(target_cell_index[included_and_active])
    plt.figure()
    plt.hist(number_of_active_inputs_in_pattern, bins=10)
    plt.ylabel('Number of GoC cells')
    plt.xlabel('Number of active inputs in pattern')
    print 'Number of active MF-GoC synapses also included in pattern',pat_id,':', numpy.count_nonzero(included_and_active)
    plt.figure()
    simulation.pattern_generator.fibers_in_pattern[0,:]
    activation_level = [simulation.pattern_generator.pattern_activation[pat_id,numpy.where(simulation.pattern_generator.fibers_in_pattern[pat_id,:]==source)[0][0]] 
                    for source in source_cell_index[included_and_active]]
    plt.hist(activation_level, bins=20)
    plt.ylabel('Number of active synapses')
    plt.xlabel('Activation level')
# Out:
# Number of active MF-GoC synapses also included in pattern 0 : 388
# Number of active MF-GoC synapses also included in pattern 1 : 355
# Number of active MF-GoC synapses also included in pattern 2 : 368
# Number of active MF-GoC synapses also included in pattern 3 : 371

# %% [markdown]
# Represent the hit rate matrix of each GoC to each pattern

# %%
layer = 'goclayer'
window_length = simulation.config_options['hit_analysis']['window_length'] = 200.0
time_bin = simulation.config_options['hit_analysis']['time_bin'] = 0.125

cr_matrix, hit_matrix, miss_matrix, fa_matrix, faa_matrix = analyze_activity(layer, window_length, time_bin)

#numpy.set_printoptions(threshold=numpy.nan)
#print 'Individual pattern hit matrix:'
#print hit_matrix
#print 'Individual pattern correct rejection matrix:'
#print cr_matrix
#print 'Individual pattern miss matrix:'
#print miss_matrix
#print 'Individual pattern false alarm matrix:'
#print fa_matrix
#print 'All patterns false alarm array:'
#print faa_matrix

extended_hit = numpy.append(hit_matrix, [faa_matrix], axis=0)
selected_pattern = numpy.argmax(extended_hit, axis=0)
plt.figure()
plt.hist(selected_pattern, bins=simulation.pattern_generator.number_of_patterns+1)
plt.ylabel('Count GoCs')
plt.xlabel('Favourite pattern')
cell_sorted = numpy.argsort(selected_pattern)
plt.figure()
plt.matshow(extended_hit[:,cell_sorted], extent=[0,simulation.cerebellum.get_number_of_elements(layer=layer),0,simulation.pattern_generator.number_of_patterns+1], vmin=0, vmax=1.0, aspect='auto')
plt.ylabel('Pattern')
plt.xlabel('GoC neuron')
plt.colorbar()
# Out:
# Average firing rate in MI analysis: 11.6561111111 Hz

# %% [markdown]
# Estimate the goodness of the matrix

# %%
extended_hit = numpy.append(hit_matrix, [faa_matrix], axis=0)
selected_pattern = numpy.argmax(extended_hit, axis=0)

# Select those cells mainly responding to one of the patterns
ind = numpy.where(selected_pattern<simulation.pattern_generator.number_of_patterns)

diagonal = hit_matrix[selected_pattern[ind],ind]

# Create a new matrix setting the diagonal values to zero
zero_matrix = hit_matrix
zero_matrix[selected_pattern[ind],ind] = 0.0

# Calculate the average of the diagonal elements
av_selected = numpy.average(diagonal)
av_nonselected = numpy.sum(zero_matrix[:])/(simulation.cerebellum.get_number_of_elements(layer=layer)*(simulation.pattern_generator.number_of_patterns-1))
print 'Average hits of selected elements:',av_selected
print 'Average hits of non-selected elements:',av_nonselected
hit_index = av_selected - av_nonselected
print 'Hit index:',hit_index
# Out:
# Average hits of selected elements: 1.0
# Average hits of non-selected elements: 0.995120275202
# Hit index: 0.00487972479761

# %% [markdown]
# ## PC activity analysis

# %% [markdown]
# Histogram of active synapses GrC-PC

# %%
target_cell_index = simulation.cerebellum.layer_map['grcpcsynapsis'].target_index
source_cell_index = simulation.cerebellum.layer_map['grcpcsynapsis'].source_index
weight = simulation.cerebellum.layer_map['grcpcsynapsis'].weights
plt.figure()
plt.hist(weight, bins=20)
plt.ylabel('Number of GrC-PC synapses')
plt.xlabel('Synaptic Weight')
max_weight = numpy.max(weight)
active_synapses = weight>max_weight*0.2
number_of_active_inputs = numpy.bincount(target_cell_index[active_synapses])
plt.figure()
plt.hist(number_of_active_inputs, bins=10)
plt.ylabel('Number of PC cells')
plt.xlabel('Number of active inputs')
print 'Number of active synapses GrC-PC:',numpy.count_nonzero(active_synapses)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-173f00ce56f7> in <module>()
# ----> 1 target_cell_index = simulation.cerebellum.layer_map['grcpcsynapsis'].target_index
#       2 source_cell_index = simulation.cerebellum.layer_map['grcpcsynapsis'].source_index
#       3 weight = simulation.cerebellum.layer_map['grcpcsynapsis'].weights
#       4 plt.figure()
#       5 plt.hist(weight, bins=20)
#
# KeyError: 'grcpcsynapsis'
