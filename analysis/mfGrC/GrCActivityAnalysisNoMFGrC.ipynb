# %% [markdown]
# # Data anaylsis in cerebellar granular layer simulations
# ## Running the simulation
#
# First, we set current working directory to the root of Spiking Granular Layer and insert the source folder to the python path:

# %%
import os
os.chdir('../../')
os.getcwd()
import sys
import numpy
# %matplotlib inline
import matplotlib.pyplot as plt
sys.path.insert(1,'./src')

# %% [markdown]
# Now start setting a new simulation with the configuration file that we specify:

# %%
config_file = './config/GoCGrC/SimulationConfigNoMFGrC4.cfg'
simulation_time = 500.0
import SpikingSimulation.FrequencySimulation as FrequencySimulation
simulation = FrequencySimulation.FrequencySimulation(config_file=config_file)

# %% [markdown]
# Initialize the simulation

# %%
simulation.config_options['simulation']['verbosity'] = 'Debug'
simulation.config_options['simulation']['seed'] = 123456
simulation.config_options['simulation']['time'] = simulation_time
simulation.config_options['simulation']['register_activity_only_in_test'] = False
simulation.config_options['network']['load_file'] = './results/GoCGrC/network01_4mf_after_noMFGrC_learning.h5'
simulation.config_options['network']['save_file'] = None
simulation.config_options['stimulation']['load_pattern_file'] = './results/GoCGrC/stimulation_noMFGrC4.h5'
simulation.config_options['stimulation']['save_pattern_file'] = None
simulation.config_options['grclayer']['register_activity'] = True
simulation.config_options['goclayer']['register_activity'] = True
simulation.config_options['grclayer']['load_state_vars'] = 'Vth'
simulation.config_options['goclayer']['load_state_vars'] = 'Vth'
simulation.config_options['grclayer']['record_vars'] = None
simulation.config_options['goclayer']['record_vars'] = None
simulation.config_options['grclayer']['record_step'] = 1.0e-1
simulation.config_options['goclayer']['record_step'] = 1.0e-1
simulation.initialize()
# Out:
# 2016-12-24 11:07:50,935 - P9197 - MemTotal:62M - Simulation - DEBUG: Simulation time fixed to 500.0s
# 2016-12-24 11:07:50,953 - P9197 - MemTotal:62M - Simulation - DEBUG: Creating cerebellum generator
# 2016-12-24 11:07:51,029 - P9197 - MemTotal:73M - Simulation - DEBUG: Initializing cerebellum generator
# 2016-12-24 11:07:51,031 - P9197 - MemTotal:73M - Simulation - DEBUG: Cerebellar simulation initialized
# 2016-12-24 11:07:51,039 - P9197 - MemTotal:75M - Simulation - DEBUG: NEST module loaded
# 2016-12-24 11:07:51,050 - P9197 - MemTotal:78M - Simulation - DEBUG: Setting Global NEST Seed: 123467
# 2016-12-24 11:07:51,052 - P9197 - MemTotal:78M - Simulation - DEBUG: Setting Per-Process NEST Seeds: [123468, 123469, 123470, 123471, 123472, 123473, 123474, 123475, 123476, 123477]
# 2016-12-24 11:07:51,083 - P9197 - MemTotal:83M - Simulation - WARNING: Non-specified cell model parameter: tau_minus in layer mflayer. Using default value
# 2016-12-24 11:07:51,085 - P9197 - MemTotal:83M - Simulation - WARNING: Non-specified number of neurons in layer mflayer
# 2016-12-24 11:07:51,087 - P9197 - MemTotal:84M - Simulation - WARNING: Non-specified number of neurons in layer grclayer
# 2016-12-24 11:07:51,090 - P9197 - MemTotal:84M - Simulation - WARNING: Non-specified number of neurons in layer goclayer
# 2016-12-24 11:07:51,094 - P9197 - MemTotal:84M - Simulation - WARNING: tau_minus cannot be calculated in layer mflayer. Variable tau_minus is not defined. Using default value 20.0
# 2016-12-24 11:07:51,096 - P9197 - MemTotal:84M - Simulation - WARNING: tau_minus_triplet cannot be calculated in layer mflayer. Variable tau_istdp is not defined. Using default value 110.0
# 2016-12-24 11:07:51,103 - P9197 - MemTotal:89M - Simulation - DEBUG: Nest Process: 0. Neuron layer created in layer mflayer: 300. Local: 300
# 2016-12-24 11:07:51,202 - P9197 - MemTotal:126M - Simulation - DEBUG: Nest Process: 0. Neuron layer created in layer grclayer: 4000. Local: 4000
# 2016-12-24 11:07:51,205 - P9197 - MemTotal:126M - Simulation - DEBUG: Nest Process: 0. Neuron layer created in layer goclayer: 9. Local: 9
# 2016-12-24 11:07:51,824 - P9197 - MemTotal:134M - Simulation - DEBUG: Nest Process: 0. Connections created in layer mfgrcsynapsis: 16133
# 2016-12-24 11:07:51,894 - P9197 - MemTotal:134M - Simulation - DEBUG: Nest Process: 0. Connections created in layer mfgocsynapsis: 1897
# /Users/jgarrido/NEST/nest210/ins_nompi/lib/python2.7/site-packages/nest/lib/hl_api_helper.py:61: UserWarning:
# OneToOneConnect is deprecated and will be removed in a future version of NEST.
# Please use Connect instead!
# For details, see http://www.nest-simulator.org/connection_management
# 2016-12-24 11:07:53,110 - P9197 - MemTotal:137M - Simulation - DEBUG: Nest Process: 0. Connections created in layer grcgocsynapsis: 35915
# 2016-12-24 11:07:53,379 - P9197 - MemTotal:137M - Simulation - DEBUG: Nest Process: 0. Connections created in layer gocgrcsynapsis: 8091
# 2016-12-24 11:07:53,384 - P9197 - MemTotal:137M - Simulation - DEBUG: Nest Process: 0. Connections created in layer gocgocsynapsis: 81
# 2016-12-24 11:07:54,180 - P9197 - MemTotal:169M - Simulation - DEBUG: Creating AC Current generator
# 2016-12-24 11:07:54,185 - P9197 - MemTotal:171M - Simulation - DEBUG: Creating DC Current generator
# 2016-12-24 11:07:54,209 - P9197 - MemTotal:171M - Simulation - INFO: Loading activation patterns from hdf5 file ./results/GoCGrC/stimulation_noMFGrC4.h5
# 2016-12-24 11:07:54,211 - P9197 - MemTotal:171M - Simulation - DEBUG: Loading stimulation pattern 0
# 2016-12-24 11:07:54,213 - P9197 - MemTotal:171M - Simulation - DEBUG: Loading stimulation pattern 1
# 2016-12-24 11:07:54,215 - P9197 - MemTotal:171M - Simulation - DEBUG: Loading stimulation pattern 2
# 2016-12-24 11:07:54,216 - P9197 - MemTotal:171M - Simulation - DEBUG: Loading stimulation pattern 3
# 2016-12-24 11:07:54,218 - P9197 - MemTotal:171M - Simulation - DEBUG: File reading ended
# 2016-12-24 11:07:54,237 - P9197 - MemTotal:181M - Simulation - DEBUG: Pattern 0 and 1 share 14 input cells: [ 21  23  57 117 124 129 130 170 177 203 212 218 257 267]
# 2016-12-24 11:07:54,239 - P9197 - MemTotal:181M - Simulation - DEBUG: Activation level of pattern 0 in shared cells: [ 0.34068122  0.8303853   0.38571678  0.89137674  0.12763536  0.83570461
#   0.1410593   0.3326859   0.0674158   0.60151048  0.2998598   0.33836937
#   0.85379178  0.71448165]
# 2016-12-24 11:07:54,242 - P9197 - MemTotal:181M - Simulation - DEBUG: Activation level of pattern 1 in shared cells: [ 0.34008524  0.82893265  0.38504202  0.88981739  0.12741208  0.83424265
#   0.14081253  0.33210391  0.06729787  0.60045822  0.29933524  0.33777744
#   0.85229818  0.71323176]
# 2016-12-24 11:07:54,244 - P9197 - MemTotal:181M - Simulation - DEBUG: Pattern 0 and 2 share 10 input cells: [ 23  29  84  95 139 145 162 196 257 292]
# 2016-12-24 11:07:54,246 - P9197 - MemTotal:181M - Simulation - DEBUG: Activation level of pattern 0 in shared cells: [ 0.8303853   0.15504614  0.86694866  0.28622573  0.75400601  0.23101361
#   0.17337945  0.31420051  0.85379178  0.11217031]
# 2016-12-24 11:07:54,248 - P9197 - MemTotal:181M - Simulation - DEBUG: Activation level of pattern 2 in shared cells: [ 0.63866165  0.23106996  0.21157761  0.16828267  0.75512947  0.79871826
#   0.95792019  0.59242694  0.86388809  0.9057407 ]
# 2016-12-24 11:07:54,249 - P9197 - MemTotal:181M - Simulation - DEBUG: Pattern 0 and 3 share 10 input cells: [ 21  29  38  48 120 130 170 212 259 296]
# 2016-12-24 11:07:54,251 - P9197 - MemTotal:181M - Simulation - DEBUG: Activation level of pattern 0 in shared cells: [ 0.34068122  0.15504614  0.00417051  0.67977813  0.8261344   0.1410593
#   0.3326859   0.2998598   0.85811197  0.66930593]
# 2016-12-24 11:07:54,253 - P9197 - MemTotal:181M - Simulation - DEBUG: Activation level of pattern 3 in shared cells: [ 0.73399331  0.23477455  0.1485904   0.52735329  0.94058318  0.4615828
#   0.31697336  0.92400491  0.63483266  0.16727316]
# 2016-12-24 11:07:54,255 - P9197 - MemTotal:181M - Simulation - DEBUG: Pattern 1 and 2 share 13 input cells: [  6  23  27  34  52  69 153 209 237 257 258 283 287]
# 2016-12-24 11:07:54,257 - P9197 - MemTotal:181M - Simulation - DEBUG: Activation level of pattern 1 in shared cells: [ 0.57515863  0.82893265  0.48411497  0.77599409  0.60775252  0.5900738
#   0.19453639  0.87536028  0.61477839  0.85229818  0.28079927  0.38065906
#   0.72925231]
# 2016-12-24 11:07:54,258 - P9197 - MemTotal:181M - Simulation - DEBUG: Activation level of pattern 2 in shared cells: [ 0.71545825  0.63866165  0.87591556  0.78527197  0.78769922  0.04754665
#   0.61024484  0.17357738  0.09030359  0.86388809  0.28805784  0.66386081
#   0.96281043]
# 2016-12-24 11:07:54,260 - P9197 - MemTotal:181M - Simulation - DEBUG: Pattern 1 and 3 share 12 input cells: [  6  11  21  35  52  64  68  86 130 170 212 247]
# 2016-12-24 11:07:54,262 - P9197 - MemTotal:181M - Simulation - DEBUG: Activation level of pattern 1 in shared cells: [ 0.57515863  0.46170998  0.34008524  0.44914965  0.60775252  0.24991998
#   1.          0.08749615  0.14081253  0.33210391  0.29933524  0.64729589]
# 2016-12-24 11:07:54,263 - P9197 - MemTotal:181M - Simulation - DEBUG: Activation level of pattern 3 in shared cells: [ 0.25866073  0.58721826  0.73399331  0.41465705  0.21334652  0.5906658
#   0.57394926  0.13198257  0.4615828   0.31697336  0.92400491  0.95313813]
# 2016-12-24 11:07:54,265 - P9197 - MemTotal:181M - Simulation - DEBUG: Pattern 2 and 3 share 8 input cells: [  6  22  29  52  78  89 178 225]
# 2016-12-24 11:07:54,267 - P9197 - MemTotal:181M - Simulation - DEBUG: Activation level of pattern 2 in shared cells: [ 0.71545825  0.00969128  0.23106996  0.78769922  0.03768267  0.62966879
#   0.31107603  0.68151606]
# 2016-12-24 11:07:54,269 - P9197 - MemTotal:181M - Simulation - DEBUG: Activation level of pattern 3 in shared cells: [ 0.25866073  0.05830739  0.23477455  0.21334652  0.2968108   0.84593961
#   0.01793736  0.92545484]
# 2016-12-24 11:07:54,417 - P9197 - MemTotal:210M - Simulation - DEBUG: Normalization on iteration 10
# 2016-12-24 11:07:54,419 - P9197 - MemTotal:210M - Simulation - DEBUG: Average sum per columns 149.998534708
# 2016-12-24 11:07:54,421 - P9197 - MemTotal:210M - Simulation - DEBUG: Average sum per rows 1004.99018254

# %% [markdown]
# Visualize the simulation or only run it.

# %%
#simulation.visualize_animation()
simulation.run_simulation()
# Out:
# 2016-12-24 11:07:54,432 - P9197 - MemTotal:210M - Simulation - INFO: Running the simulation from 0.0s until time 500.0s
# 2016-12-24 11:07:54,439 - P9197 - MemTotal:211M - Simulation - DEBUG: Running the simulation 0.063s until 0.063s
# 2016-12-24 11:07:54,842 - P9197 - MemTotal:213M - Simulation - DEBUG: Simulation time is 0.399889945984 seconds. Real-time rate: 0.157543345695. Spike frequency: 15.880952381
# 2016-12-24 11:07:54,847 - P9197 - MemTotal:213M - Simulation - DEBUG: Running the simulation 0.011s until 0.074s
# 2016-12-24 11:07:54,914 - P9197 - MemTotal:213M - Simulation - DEBUG: Simulation time is 0.0637021064758 seconds. Real-time rate: 0.172678748138. Spike frequency: 6.31818181818
# 2016-12-24 11:07:54,918 - P9197 - MemTotal:213M - Simulation - DEBUG: Running the simulation 0.127s until 0.201s
# 2016-12-24 11:07:55,651 - P9197 - MemTotal:214M - Simulation - DEBUG: Simulation time is 0.729727983475 seconds. Real-time rate: 0.174037453511. Spike frequency: 10.8720472441
# 2016-12-24 11:07:55,655 - P9197 - MemTotal:214M - Simulation - DEBUG: Running the simulation 0.229s until 0.43s
# 2016-12-24 11:07:56,943 - P9197 - MemTotal:215M - Simulation - DEBUG: Simulation time is 1.28275299072 seconds. Real-time rate: 0.178522288902. Spike frequency: 15.1626637555
# 2016-12-24 11:07:56,947 - P9197 - MemTotal:215M - Simulation - DEBUG: Running the simulation 0.202s until 0.632s
# 2016-12-24 11:07:58,003 - P9197 - MemTotal:215M - Simulation - DEBUG: Simulation time is 1.05202913284 seconds. Real-time rate: 0.192009891831. Spike frequency: 9.88861386139
# 2016-12-24 11:07:58,008 - P9197 - MemTotal:215M - Simulation - DEBUG: Running the simulation 0.056s until 0.688s
# 2016-12-24 11:07:58,309 - P9197 - MemTotal:210M - Simulation - DEBUG: Simulation time is 0.297065019608 seconds. Real-time rate: 0.188510919508. Spike frequency: 16.40625
# 2016-12-24 11:07:58,313 - P9197 - MemTotal:210M - Simulation - DEBUG: Running the simulation 0.065s until 0.753s
# 2016-12-24 11:07:58,657 - P9197 - MemTotal:193M - Simulation - DEBUG: Simulation time is 0.338479042053 seconds. Real-time rate: 0.192035523398. Spike frequency: 7.22692307692
# 2016-12-24 11:07:58,661 - P9197 - MemTotal:193M - Simulation - DEBUG: Running the simulation 0.018s until 0.771s
# 2016-12-24 11:07:58,760 - P9197 - MemTotal:193M - Simulation - DEBUG: Simulation time is 0.0959119796753 seconds. Real-time rate: 0.187672072466. Spike frequency: 1.34722222222
# 2016-12-24 11:07:58,765 - P9197 - MemTotal:193M - Simulation - DEBUG: Running the simulation 0.448s until 1.219s
# 2016-12-24 11:08:00,129 - P9197 - MemTotal:194M - Simulation - DEBUG: Simulation time is 1.35847711563 seconds. Real-time rate: 0.168571113466. Spike frequency: 13.0556768559
# 2016-12-24 11:08:01,795 - P9197 - MemTotal:202M - Simulation - DEBUG: Simulation time is 1.03344392776 seconds. Real-time rate: 0.211912803507. Spike frequency: 13.5696347032
# 2016-12-24 11:08:01,799 - P9197 - MemTotal:202M - Simulation - DEBUG: Running the simulation 0.206s until 1.425s
# 2016-12-24 11:08:02,897 - P9197 - MemTotal:203M - Simulation - DEBUG: Simulation time is 1.09246897697 seconds. Real-time rate: 0.188563706926. Spike frequency: 13.8701456311
# 2016-12-24 11:08:02,902 - P9197 - MemTotal:203M - Simulation - DEBUG: Running the simulation 0.303s until 1.728s
# 2016-12-24 11:08:04,424 - P9197 - MemTotal:206M - Simulation - DEBUG: Simulation time is 1.51564097404 seconds. Real-time rate: 0.199915418749. Spike frequency: 10.5668316832
# 2016-12-24 11:08:04,428 - P9197 - MemTotal:206M - Simulation - DEBUG: Running the simulation 0.167s until 1.895s
# 2016-12-24 11:08:05,283 - P9197 - MemTotal:206M - Simulation - DEBUG: Simulation time is 0.849508047104 seconds. Real-time rate: 0.196584364997. Spike frequency: 12.1676646707
# 2016-12-24 11:08:05,288 - P9197 - MemTotal:206M - Simulation - DEBUG: Running the simulation 0.145s until 2.04s
# 2016-12-24 11:08:05,853 - P9197 - MemTotal:208M - Simulation - DEBUG: Simulation time is 0.559691905975 seconds. Real-time rate: 0.187603213266. Spike frequency: 13.15
# 2016-12-24 11:08:06,659 - P9197 - MemTotal:211M - Simulation - DEBUG: Simulation time is 0.188425064087 seconds. Real-time rate: 0.212285983257. Spike frequency: 18.35
# 2016-12-24 11:08:06,663 - P9197 - MemTotal:211M - Simulation - DEBUG: Running the simulation 0.254s until 2.294s
# 2016-12-24 11:08:07,976 - P9197 - MemTotal:211M - Simulation - DEBUG: Simulation time is 1.3057050705 seconds. Real-time rate: 0.194530913404. Spike frequency: 16.1653543307
# 2016-12-24 11:08:07,981 - P9197 - MemTotal:209M - Simulation - DEBUG: Running the simulation 0.063s until 2.357s
# 2016-12-24 11:08:18,730 - P9197 - MemTotal:217M - Simulation - DEBUG: Simulation time is 0.532098054886 seconds. Real-time rate: 0.21612557863. Spike frequency: 11.2456521739
# 2016-12-24 11:08:18,734 - P9197 - MemTotal:217M - Simulation - DEBUG: Running the simulation 0.317s until 4.457s
# 2016-12-24 11:08:20,323 - P9197 - MemTotal:217M - Simulation - DEBUG: Simulation time is 1.57623386383 seconds. Real-time rate: 0.201112288775. Spike frequency: 15.2768138801
# 2016-12-24 11:08:20,329 - P9197 - MemTotal:216M - Simulation - DEBUG: Running the simulation 0.4s until 4.857s
# 2016-12-24 11:08:22,374 - P9197 - MemTotal:219M - Simulation - DEBUG: Simulation time is 2.03377985954 seconds. Real-time rate: 0.19667812036. Spike frequency: 10.3075
# 2016-12-24 11:08:22,378 - P9197 - MemTotal:218M - Simulation - DEBUG: Running the simulation 0.407s until 5.264s
# 2016-12-24 11:08:23,079 - P9197 - MemTotal:222M - Simulation - DEBUG: Simulation time is 0.690645933151 seconds. Real-time rate: 0.207052547675. Spike frequency: 10.7097902098
# 2016-12-24 11:08:24,844 - P9197 - MemTotal:221M - Simulation - DEBUG: Simulation time is 1.19578886032 seconds. Real-time rate: 0.220774761131. Spike frequency: 16.34375
# 2016-12-24 11:08:24,848 - P9197 - MemTotal:219M - Simulation - DEBUG: Running the simulation 0.042s until 5.306s
# 2016-12-24 11:08:25,074 - P9197 - MemTotal:222M - Simulation - DEBUG: Simulation time is 0.215426921844 seconds. Real-time rate: 0.194961705066. Spike frequency: 21.2857142857
# 2016-12-24 11:08:25,078 - P9197 - MemTotal:222M - Simulation - DEBUG: Running the simulation 0.019s until 5.325s
# 2016-12-24 11:08:25,173 - P9197 - MemTotal:223M - Simulation - DEBUG: Simulation time is 0.0857820510864 seconds. Real-time rate: 0.221491556326. Spike frequency: 9.80263157895
# 2016-12-24 11:08:25,176 - P9197 - MemTotal:223M - Simulation - DEBUG: Running the simulation 0.163s until 5.488s
# 2016-12-24 11:08:25,938 - P9197 - MemTotal:223M - Simulation - DEBUG: Simulation time is 0.749176979065 seconds. Real-time rate: 0.217572088512. Spike frequency: 11.5444785276
# 2016-12-24 11:08:25,941 - P9197 - MemTotal:223M - Simulation - DEBUG: Running the simulation 0.079s until 5.567s
# 2016-12-24 11:08:26,325 - P9197 - MemTotal:223M - Simulation - DEBUG: Simulation time is 0.371007919312 seconds. Real-time rate: 0.212933460144. Spike frequency: 14.2848101266
# 2016-12-24 11:08:26,329 - P9197 - MemTotal:223M - Simulation - DEBUG: Running the simulation 0.203s until 5.77s
# 2016-12-24 11:08:27,312 - P9197 - MemTotal:224M - Simulation - DEBUG: Simulation time is 0.968369960785 seconds. Real-time rate: 0.209630624886. Spike frequency: 10.7352216749
# 2016-12-24 11:08:27,316 - P9197 - MemTotal:224M - Simulation - DEBUG: Running the simulation 0.267s until 6.037s
# 2016-12-24 11:08:28,483 - P9197 - MemTotal:224M - Simulation - DEBUG: Simulation time is 1.15216588974 seconds. Real-time rate: 0.199624031616. Spike frequency: 13.6836956522
# 2016-12-24 11:09:10,476 - P9197 - MemTotal:267M - Simulation - DEBUG: Running the simulation 0.066s until 13.784s
# 2016-12-24 11:09:10,827 - P9197 - MemTotal:267M - Simulation - DEBUG: Simulation time is 0.316927194595 seconds. Real-time rate: 0.208249721468. Spike frequency: 10.6856060606
# 2016-12-24 11:09:10,831 - P9197 - MemTotal:267M - Simulation - DEBUG: Running the simulation 0.332s until 14.116s
# 2016-12-24 11:09:11,963 - P9197 - MemTotal:268M - Simulation - DEBUG: Simulation time is 1.09726190567 seconds. Real-time rate: 0.19685363985. Spike frequency: 12.4085648148
# 2016-12-24 11:09:13,092 - P9197 - MemTotal:250M - Simulation - DEBUG: Simulation time is 0.514235973358 seconds. Real-time rate: 0.225577373054. Spike frequency: 17.6142241379
# 2016-12-24 11:09:13,097 - P9197 - MemTotal:250M - Simulation - DEBUG: Running the simulation 0.691s until 14.807s
# 2016-12-24 11:09:16,382 - P9197 - MemTotal:256M - Simulation - DEBUG: Simulation time is 3.24388098717 seconds. Real-time rate: 0.213016446267. Spike frequency: 17.8668596237
# 2016-12-24 11:09:16,386 - P9197 - MemTotal:250M - Simulation - DEBUG: Running the simulation 0.042s until 14.849s
# 2016-12-24 11:09:16,629 - P9197 - MemTotal:253M - Simulation - DEBUG: Simulation time is 0.205732107162 seconds. Real-time rate: 0.204148980824. Spike frequency: 20.7738095238
# 2016-12-24 11:09:16,633 - P9197 - MemTotal:253M - Simulation - DEBUG: Running the simulation 0.415s until 15.264s
# 2016-12-24 11:09:17,377 - P9197 - MemTotal:269M - Simulation - DEBUG: Simulation time is 0.7101521492 seconds. Real-time rate: 0.212630490762. Spike frequency: 15.3609271523
# 2016-12-24 11:09:19,138 - P9197 - MemTotal:255M - Simulation - DEBUG: Simulation time is 1.16896700859 seconds. Real-time rate: 0.225840419841. Spike frequency: 17.2149621212
# 2016-12-24 11:09:19,143 - P9197 - MemTotal:249M - Simulation - DEBUG: Running the simulation 0.484s until 15.748s
# 2016-12-24 11:09:21,477 - P9197 - MemTotal:256M - Simulation - DEBUG: Simulation time is 2.29517102242 seconds. Real-time rate: 0.210877531684. Spike frequency: 12.930268595
# 2016-12-24 11:09:21,483 - P9197 - MemTotal:250M - Simulation - DEBUG: Running the simulation 0.054s until 15.802s
# 2016-12-24 11:09:21,814 - P9197 - MemTotal:258M - Simulation - DEBUG: Simulation time is 0.290977954865 seconds. Real-time rate: 0.185581069278. Spike frequency: 15.8564814815
# 2016-12-24 11:09:21,819 - P9197 - MemTotal:258M - Simulation - DEBUG: Running the simulation 0.157s until 15.959s
# 2016-12-24 11:09:22,653 - P9197 - MemTotal:274M - Simulation - DEBUG: Simulation time is 0.791066884995 seconds. Real-time rate: 0.198466151192. Spike frequency: 13.8312101911
# 2016-12-24 11:09:22,657 - P9197 - MemTotal:274M - Simulation - DEBUG: Running the simulation 0.556s until 16.515s
# 2016-12-24 11:10:43,861 - P9197 - MemTotal:357M - Simulation - DEBUG: Running the simulation 0.237s until 28.786s
# 2016-12-24 11:10:45,443 - P9197 - MemTotal:358M - Simulation - DEBUG: Simulation time is 1.51872396469 seconds. Real-time rate: 0.156052057853. Spike frequency: 13.3797468354
# 2016-12-24 11:10:45,447 - P9197 - MemTotal:358M - Simulation - DEBUG: Running the simulation 0.196s until 28.982s
# 2016-12-24 11:10:46,629 - P9197 - MemTotal:359M - Simulation - DEBUG: Simulation time is 1.11735200882 seconds. Real-time rate: 0.175414729157. Spike frequency: 11.8890306122
# 2016-12-24 11:10:46,634 - P9197 - MemTotal:359M - Simulation - DEBUG: Running the simulation 1.051s until 30.033s
# 2016-12-24 11:10:46,791 - P9197 - MemTotal:359M - Simulation - DEBUG: Simulation time is 0.102267980576 seconds. Real-time rate: 0.176008168917. Spike frequency: 0.833333333334
# 2016-12-24 11:10:53,339 - P9197 - MemTotal:314M - Simulation - DEBUG: Simulation time is 5.85346198082 seconds. Real-time rate: 0.170839069815. Spike frequency: 13.68275
# 2016-12-24 11:10:54,341 - P9197 - MemTotal:326M - Simulation - DEBUG: Simulation time is 0.196223020554 seconds. Real-time rate: 0.168175986217. Spike frequency: 17.6287878788
# 2016-12-24 11:10:54,345 - P9197 - MemTotal:326M - Simulation - DEBUG: Running the simulation 0.364s until 30.397s
# 2016-12-24 11:10:56,507 - P9197 - MemTotal:319M - Simulation - DEBUG: Simulation time is 2.08686280251 seconds. Real-time rate: 0.174424499571. Spike frequency: 12.4210164835
# 2016-12-24 11:10:56,513 - P9197 - MemTotal:309M - Simulation - DEBUG: Running the simulation 0.299s until 30.696s
# 2016-12-24 11:10:58,346 - P9197 - MemTotal:306M - Simulation - DEBUG: Simulation time is 1.75008201599 seconds. Real-time rate: 0.170849135794. Spike frequency: 15.5234113712
# 2016-12-24 11:10:58,351 - P9197 - MemTotal:299M - Simulation - DEBUG: Running the simulation 0.267s until 30.963s
# 2016-12-24 11:10:59,897 - P9197 - MemTotal:317M - Simulation - DEBUG: Simulation time is 1.47164487839 seconds. Real-time rate: 0.181429639665. Spike frequency: 11.5327715356
# 2016-12-24 11:10:59,902 - P9197 - MemTotal:316M - Simulation - DEBUG: Running the simulation 0.112s until 31.075s
# 2016-12-24 11:11:00,183 - P9197 - MemTotal:347M - Simulation - DEBUG: Simulation time is 0.205904960632 seconds. Real-time rate: 0.179694553674. Spike frequency: 4.80405405406
# 2016-12-24 11:11:01,248 - P9197 - MemTotal:324M - Simulation - DEBUG: Simulation time is 0.400713205338 seconds. Real-time rate: 0.187166280025. Spike frequency: 20.83
# 2016-12-24 11:11:01,253 - P9197 - MemTotal:324M - Simulation - DEBUG: Running the simulation 0.326s until 31.401s
# 2016-12-24 11:11:03,121 - P9197 - MemTotal:349M - Simulation - DEBUG: Simulation time is 1.79585504532 seconds. Real-time rate: 0.181529127782. Spike frequency: 10.2400306748
# 2016-12-24 11:11:03,126 - P9197 - MemTotal:349M - Simulation - DEBUG: Running the simulation 0.109s until 31.51s
# 2016-12-24 12:28:03,969 - P9197 - MemTotal:1695M - Simulation - DEBUG: Simulation time is 0.0899419784546 seconds. Real-time rate: 0.222365577731. Spike frequency: 1.09999999993
# 2016-12-24 12:28:06,539 - P9197 - MemTotal:1172M - Simulation - DEBUG: Simulation time is 0.671627998352 seconds. Real-time rate: 0.208448725101. Spike frequency: 13.4017857144
# 2016-12-24 12:28:06,543 - P9197 - MemTotal:1172M - Simulation - DEBUG: Running the simulation 0.303s until 495.443s
# 2016-12-24 12:28:09,377 - P9197 - MemTotal:1313M - Simulation - DEBUG: Simulation time is 1.52241396904 seconds. Real-time rate: 0.199026024565. Spike frequency: 16.4628712871
# 2016-12-24 12:28:09,392 - P9197 - MemTotal:1171M - Simulation - DEBUG: Running the simulation 0.607s until 496.05s
# 2016-12-24 12:28:13,775 - P9197 - MemTotal:1213M - Simulation - DEBUG: Simulation time is 2.97307109833 seconds. Real-time rate: 0.187348361872. Spike frequency: 13.9528725314
# 2016-12-24 12:28:15,884 - P9197 - MemTotal:1174M - Simulation - DEBUG: Simulation time is 0.242707014084 seconds. Real-time rate: 0.206009703459. Spike frequency: 20.3050000005
# 2016-12-24 12:28:15,888 - P9197 - MemTotal:1174M - Simulation - DEBUG: Running the simulation 0.163s until 496.213s
# 2016-12-24 12:28:18,006 - P9197 - MemTotal:1457M - Simulation - DEBUG: Simulation time is 0.800798892975 seconds. Real-time rate: 0.203546734929. Spike frequency: 19.463190184
# 2016-12-24 12:28:18,009 - P9197 - MemTotal:1457M - Simulation - DEBUG: Running the simulation 0.081s until 496.294s
# 2016-12-24 12:28:19,730 - P9197 - MemTotal:1497M - Simulation - DEBUG: Simulation time is 0.400887012482 seconds. Real-time rate: 0.20205194351. Spike frequency: 13.225308642
# 2016-12-24 12:28:19,734 - P9197 - MemTotal:1497M - Simulation - DEBUG: Running the simulation 0.549s until 496.843s
# 2016-12-24 12:28:24,188 - P9197 - MemTotal:1316M - Simulation - DEBUG: Simulation time is 2.90677714348 seconds. Real-time rate: 0.188868968243. Spike frequency: 12.8775045537
# 2016-12-24 12:28:24,202 - P9197 - MemTotal:1174M - Simulation - DEBUG: Running the simulation 0.042s until 496.885s
# 2016-12-24 12:28:25,704 - P9197 - MemTotal:1214M - Simulation - DEBUG: Simulation time is 0.190435886383 seconds. Real-time rate: 0.2205466669. Spike frequency: 2.70238095238
# 2016-12-24 12:28:25,707 - P9197 - MemTotal:1214M - Simulation - DEBUG: Running the simulation 0.112s until 496.997s
# 2016-12-24 12:28:27,542 - P9197 - MemTotal:1498M - Simulation - DEBUG: Simulation time is 0.536875009537 seconds. Real-time rate: 0.208614664513. Spike frequency: 13.6830357143
# 2016-12-24 12:28:27,546 - P9197 - MemTotal:1498M - Simulation - DEBUG: Running the simulation 0.197s until 497.194s
# 2016-12-24 12:28:28,774 - P9197 - MemTotal:1498M - Simulation - DEBUG: Simulation time is 0.0135889053345 seconds. Real-time rate: 0.220768334711. Spike frequency: 0.0
# 2016-12-24 12:28:31,608 - P9197 - MemTotal:1177M - Simulation - DEBUG: Simulation time is 0.947335004807 seconds. Real-time rate: 0.204785001097. Spike frequency: 17.5579896908
# 2016-12-24 12:28:31,612 - P9197 - MemTotal:1177M - Simulation - DEBUG: Running the simulation 0.388s until 497.582s
# 2016-12-24 12:28:34,950 - P9197 - MemTotal:1318M - Simulation - DEBUG: Simulation time is 1.93843698502 seconds. Real-time rate: 0.200161265493. Spike frequency: 12.0805412371
# 2016-12-24 12:28:34,964 - P9197 - MemTotal:1176M - Simulation - DEBUG: Running the simulation 0.342s until 497.924s
# 2016-12-24 12:28:38,153 - P9197 - MemTotal:1217M - Simulation - DEBUG: Simulation time is 1.77992296219 seconds. Real-time rate: 0.192143147353. Spike frequency: 15.682748538
# 2016-12-24 12:28:38,160 - P9197 - MemTotal:1176M - Simulation - DEBUG: Running the simulation 0.129s until 498.053s
# 2016-12-24 12:28:39,875 - P9197 - MemTotal:1216M - Simulation - DEBUG: Simulation time is 0.369297027588 seconds. Real-time rate: 0.20579640323. Spike frequency: 14.5197368419
# 2016-12-24 12:28:42,010 - P9197 - MemTotal:1177M - Simulation - DEBUG: Simulation time is 0.2573158741 seconds. Real-time rate: 0.205972523787. Spike frequency: 21.6320754722
# 2016-12-24 12:28:42,014 - P9197 - MemTotal:1177M - Simulation - DEBUG: Running the simulation 0.488s until 498.541s
# 2016-12-24 12:28:46,082 - P9197 - MemTotal:1320M - Simulation - DEBUG: Simulation time is 2.57392096519 seconds. Real-time rate: 0.189594011082. Spike frequency: 18.0230532787
# 2016-12-24 12:28:46,096 - P9197 - MemTotal:1178M - Simulation - DEBUG: Running the simulation 0.011s until 498.552s
# 2016-12-24 12:28:47,494 - P9197 - MemTotal:1218M - Simulation - DEBUG: Simulation time is 0.0537919998169 seconds. Real-time rate: 0.204491374879. Spike frequency: 25.0227272727
# 2016-12-24 12:28:47,498 - P9197 - MemTotal:1218M - Simulation - DEBUG: Running the simulation 0.107s until 498.659s
# 2016-12-24 12:28:49,324 - P9197 - MemTotal:1502M - Simulation - DEBUG: Simulation time is 0.512744903564 seconds. Real-time rate: 0.208680767485. Spike frequency: 15.5
# 2016-12-24 12:28:49,328 - P9197 - MemTotal:1502M - Simulation - DEBUG: Running the simulation 0.084s until 498.743s
# 2016-12-24 12:28:51,174 - P9197 - MemTotal:1706M - Simulation - DEBUG: Simulation time is 0.397752046585 seconds. Real-time rate: 0.211186845476. Spike frequency: 9.15773809524
# 2016-12-24 12:28:51,178 - P9197 - MemTotal:1706M - Simulation - DEBUG: Running the simulation 0.039s until 498.782s
# 2016-12-24 12:28:52,693 - P9197 - MemTotal:1706M - Simulation - DEBUG: Simulation time is 0.181527853012 seconds. Real-time rate: 0.214843063215. Spike frequency: 18.8717948718
# 2016-12-24 12:28:52,697 - P9197 - MemTotal:1706M - Simulation - DEBUG: Running the simulation 0.688s until 499.47s
# 2016-12-24 12:28:55,101 - P9197 - MemTotal:1707M - Simulation - DEBUG: Simulation time is 1.06287097931 seconds. Real-time rate: 0.205104856794. Spike frequency: 14.7018348623
# 2016-12-24 12:28:59,685 - P9197 - MemTotal:1180M - Simulation - DEBUG: Simulation time is 2.47216510773 seconds. Real-time rate: 0.190116751721. Spike frequency: 14.9265957447
# 2016-12-24 12:28:59,689 - P9197 - MemTotal:1179M - Simulation - DEBUG: Running the simulation 0.075s until 499.545s
# 2016-12-24 12:29:01,381 - P9197 - MemTotal:1219M - Simulation - DEBUG: Simulation time is 0.365487098694 seconds. Real-time rate: 0.205205601697. Spike frequency: 14.87
# 2016-12-24 12:29:01,385 - P9197 - MemTotal:1219M - Simulation - DEBUG: Running the simulation 0.233s until 499.778s
# 2016-12-24 12:29:03,894 - P9197 - MemTotal:1504M - Simulation - DEBUG: Simulation time is 1.14276504517 seconds. Real-time rate: 0.203891430689. Spike frequency: 12.1276824034
# 2016-12-24 12:29:03,898 - P9197 - MemTotal:1504M - Simulation - DEBUG: Running the simulation 0.207s until 499.985s
# 2016-12-24 12:29:06,283 - P9197 - MemTotal:1709M - Simulation - DEBUG: Simulation time is 1.01502609253 seconds. Real-time rate: 0.203935644141. Spike frequency: 12.5096618357
# 2016-12-24 12:29:06,287 - P9197 - MemTotal:1709M - Simulation - DEBUG: Running the simulation 0.0150000000012s until 500.0s
# 2016-12-24 12:29:07,574 - P9197 - MemTotal:1709M - Simulation - DEBUG: Simulation time is 0.0652461051941 seconds. Real-time rate: 0.229898780266. Spike frequency: 0.0666666666612

# %% [markdown]
# Save the network state after the simulation

# %%
simulation.cerebellum.update_network_weights()
#simulation.cerebellum.save_network()

# %% [markdown]
# ## GrC activity analysis

# %% [markdown]
# Calculate the average firing frequency of each granular cells during the ending 100 seconds

# %%
gtime,gcell_id = simulation.cerebellum.get_spike_activity(neuron_layer = 'grclayer',
                                                          init_time = simulation.current_time-simulation_time, 
                                                          end_time = simulation.current_time)
import numpy
firing_frequency = numpy.bincount(gcell_id) / (simulation_time*8.0)
# %matplotlib inline
import matplotlib.pyplot as plt
plt.hist(firing_frequency, bins=20)
plt.ylabel('Number of GrC cells')
plt.xlabel('Av. Spikes per Oscillatory Cycle')

# %% [markdown]
# Get the histogram of input synapses for the granular cells

# %%
target_cell_index = simulation.cerebellum.layer_map['mfgrcsynapsis'].target_index
cell_number = simulation.cerebellum.layer_map['grclayer'].number_of_neurons
number_of_inputs = numpy.bincount(target_cell_index)
plt.hist(number_of_inputs, bins=30)
plt.ylabel('Number of GrC cells')
plt.xlabel('Number of input synapses from glomeruli')

# %% [markdown]
# Plot the histogram of non-zero weights between MF and GrC

# %%
target_cell_index = simulation.cerebellum.layer_map['mfgrcsynapsis'].target_index
source_cell_index = simulation.cerebellum.layer_map['mfgrcsynapsis'].source_index
weight = simulation.cerebellum.layer_map['mfgrcsynapsis'].weights
plt.figure()
plt.hist(weight, bins=20)
plt.ylabel('Synaptic Weight')
plt.xlabel('Number of MF-GrC synapses')
max_weight = numpy.max(weight)
active_synapses = weight>max_weight*0.2
number_of_active_inputs = numpy.bincount(target_cell_index[active_synapses])
plt.figure()
plt.hist(number_of_active_inputs, bins=10)
plt.ylabel('Number of GrC cells')
plt.xlabel('Number of active inputs')
print 'Number of active synapses MF-GrC:',numpy.count_nonzero(active_synapses)
# Out:
# Number of active synapses MF-GrC: 9676

# %% [markdown]
# Histogram of active synapses connecting input fibers included in the pattern

# %%
for pat_id in range(simulation.pattern_generator.number_of_patterns):
    included_in_pattern = numpy.in1d(source_cell_index, simulation.pattern_generator.fibers_in_pattern[pat_id,:])
    included_and_active = numpy.logical_and(included_in_pattern,active_synapses)
    number_of_active_inputs_in_pattern = numpy.bincount(target_cell_index[included_and_active])
    plt.figure()
    plt.hist(number_of_active_inputs_in_pattern, bins=10)
    plt.ylabel('Number of GrC cells')
    plt.xlabel('Number of active inputs in pattern')
    print 'Number of active MF-GrC synapses also included in pattern',pat_id,':', numpy.count_nonzero(included_and_active)
    plt.figure()
    simulation.pattern_generator.fibers_in_pattern[0,:]
    activation_level = [simulation.pattern_generator.pattern_activation[pat_id,numpy.where(simulation.pattern_generator.fibers_in_pattern[pat_id,:]==source)[0][0]] 
                    for source in source_cell_index[included_and_active]]
    plt.hist(activation_level, bins=20)
    plt.ylabel('Number of active synapses')
    plt.xlabel('Activation level')
# Out:
# Number of active MF-GrC synapses also included in pattern 0 : 1957
# Number of active MF-GrC synapses also included in pattern 1 : 1896
# Number of active MF-GrC synapses also included in pattern 2 : 1974
# Number of active MF-GrC synapses also included in pattern 3 : 1859

# %% [markdown]
# Define some auxiliar functions:

# %%
def calc_Ind_Pattern_Hit_Matrix(cell_firing, pattern_present):
    '''
    Calculate the correct rejection, hit, miss and false alarm matrisses with 1 line for each cell and 1 column for each pattern (including noise).
    @param cell_firing Boolean matrix including 1 line for each cell and 1 column for each time bin.
    @param pattern_present Boolean matrix including 1 line for each pattern and 1 column for each time bin.
    '''
    hit_matrix = numpy.empty((len(pattern_present),len(cell_firing)))
    cr_matrix = numpy.empty((len(pattern_present),len(cell_firing)))
    miss_matrix = numpy.empty((len(pattern_present),len(cell_firing)))
    fa_matrix = numpy.empty((len(pattern_present),len(cell_firing)))
    faa_matrix = numpy.empty((len(cell_firing)))
    
    for index_pat, pattern in enumerate(pattern_present):
        if (numpy.count_nonzero(pattern)):
            for index_cell, firing in enumerate(cell_firing):
                hit_matrix[index_pat,index_cell] = numpy.count_nonzero(firing&pattern)/float(numpy.count_nonzero(pattern))
                cr_matrix[index_pat,index_cell] = numpy.count_nonzero(~firing&~pattern)/float(numpy.count_nonzero(~pattern))
                miss_matrix[index_pat,index_cell] = numpy.count_nonzero(~firing&pattern)/float(numpy.count_nonzero(pattern))
                fa_matrix[index_pat,index_cell] = numpy.count_nonzero(firing&~pattern)/float(numpy.count_nonzero(~pattern))
        else:
            print 'Pattern',index_pat,'never occurs. Statistics will not be calculated'
               
    any_pattern = numpy.any(pattern_present, axis=0)
    for index_cell, firing in enumerate(cell_firing):
        faa_matrix[index_cell] = numpy.count_nonzero(firing&~any_pattern)/float(numpy.count_nonzero(~any_pattern))
        
    return cr_matrix, hit_matrix, miss_matrix, fa_matrix, faa_matrix

def analyze_activity(layer, window_length, time_bin):

    cell_index = range(simulation.cerebellum.get_number_of_elements(layer=layer))
    pattern_generator = simulation.pattern_generator
    inv_time_bin = 1./time_bin

    # Generate the time bin matrix
    total_time = pattern_generator.simulation_time
    bin_time_init = numpy.linspace(0.0, window_length-time_bin, num=window_length*inv_time_bin)
    bin_time_end = numpy.linspace(time_bin,window_length,num=window_length*inv_time_bin)

    # Initialize a matrix
    pattern_index = range(0,pattern_generator.number_of_patterns)
    num_patterns = len(pattern_index)
    num_bins = len(bin_time_init)
    num_cells = len(cell_index)

    # Calculate the time of each pattern interval
    time_end_of_pattern = pattern_generator.pattern_length_cum
    time_init_of_pattern = numpy.append([0.0],time_end_of_pattern[:-1])

    # Calculate the bin of each pattern interval. Check the round of the last bin to avoid out of range
    bin_end_of_pattern = numpy.floor(time_end_of_pattern * inv_time_bin).astype(int)
    if (bin_end_of_pattern[-1]>=num_bins):
        bin_end_of_pattern[-1]=num_bins-1
    bin_init_of_pattern = numpy.append([0],bin_end_of_pattern[:-1])
    if (bin_init_of_pattern[-1]>=num_bins):
        bin_init_of_pattern[-1]=num_bins-1

    # Final matrix indicating which bins are considered of each pattern
    bin_is_pattern = numpy.empty((num_patterns, num_bins),dtype='bool')
    bin_is_pattern[:,:] = False
    bin_pattern = numpy.zeros(num_bins)

    # Final matrix indicating which bins are registered spikes
    bin_has_fired = numpy.empty((num_cells, num_bins), dtype='bool')
    bin_has_fired[:,:] = False

    for key, value in enumerate(pattern_index):
        time_of_pattern_in_bin = numpy.zeros(num_bins)
        for index in pattern_generator.pattern_id_index[value]:
            init_bin = bin_init_of_pattern[index]
            end_bin = bin_end_of_pattern[index]

            list_of_bins = range(init_bin,end_bin+1)

            # Add the time of the initial bin (if exists)
            if init_bin!=end_bin:
                time_of_pattern_in_bin[list_of_bins[0]] += (bin_time_end[init_bin] - time_init_of_pattern[index])

            # Add the time of the intermediate bins (if exist)
            time_of_pattern_in_bin[list_of_bins[1:-1]] += time_bin

            # Add the time of the final bin
            time_of_pattern_in_bin[list_of_bins[-1]] += (time_end_of_pattern[index] - max(time_init_of_pattern[index],bin_time_init[end_bin]))

        # Those bins where the time in the pattern is longer than half of the bin are set to part of that pattern    
        bin_is_pattern[key,time_of_pattern_in_bin>(time_bin/2.)] = True
        bin_pattern[bin_is_pattern[key,:]] = bin_pattern[bin_is_pattern[key,:]] + 2**value

    # Create a map of cells to index
    cell_map = dict()
    for key, value in enumerate(cell_index):
        cell_map[value] = key

    # Load data from the data provider
    gtime,gcell_id = simulation.cerebellum.get_spike_activity(neuron_layer = layer, init_time = 0.0, end_time = window_length)


    spike_bin_index = numpy.floor(gtime*inv_time_bin).astype(int)

    av_firing_rate = float(len(gtime))/(len(cell_index)*(window_length))
    print 'Average firing rate in MI analysis:',av_firing_rate,'Hz'

    cell_index = numpy.array([cell_map[value] for value in gcell_id])

    # Final matrix indicating which bins are registered spikes
    if len(spike_bin_index) and len(cell_index):
        bin_has_fired[cell_index,spike_bin_index] = True

    # Calculate mutual information in the time window
    init_bin = int(0 * inv_time_bin)
    end_bin = int(window_length * inv_time_bin)


    # Calculate hit matrix for each pattern
    cr_matrix, hit_matrix, miss_matrix, fa_matrix, faa_matrix = calc_Ind_Pattern_Hit_Matrix(bin_has_fired[:,init_bin:end_bin], bin_is_pattern[:,init_bin:end_bin])

    return cr_matrix, hit_matrix, miss_matrix, fa_matrix, faa_matrix

# %% [markdown]
# Represent the hit rate matrix of each GrC to each pattern

# %%
layer = 'grclayer'
window_length = simulation.config_options['hit_analysis']['window_length'] = simulation_time
time_bin = simulation.config_options['hit_analysis']['time_bin'] = 0.125

cr_matrix, hit_matrix, miss_matrix, fa_matrix, faa_matrix = analyze_activity(layer, window_length, time_bin)

#numpy.set_printoptions(threshold=numpy.nan)
#print 'Individual pattern hit matrix:'
#print hit_matrix
#print 'Individual pattern correct rejection matrix:'
#print cr_matrix
#print 'Individual pattern miss matrix:'
#print miss_matrix
#print 'Individual pattern false alarm matrix:'
#print fa_matrix
#print 'All patterns false alarm array:'
#print faa_matrix

extended_hit = numpy.append(hit_matrix, [faa_matrix], axis=0)
selected_pattern = numpy.argmax(extended_hit, axis=0)
plt.figure()
plt.hist(selected_pattern, bins=simulation.pattern_generator.number_of_patterns+1)
plt.ylabel('Count GrCs')
plt.xlabel('Favourite pattern')
cell_sorted = numpy.argsort(selected_pattern)
plt.figure()
plt.matshow(extended_hit[:,cell_sorted], extent=[0,simulation.cerebellum.get_number_of_elements(layer=layer),
                                                 simulation.pattern_generator.number_of_patterns+1,0], 
            vmin=0, vmax=1.0, aspect='auto')
plt.ylabel('Pattern')
plt.xlabel('GrC neuron')
plt.colorbar()
# Out:
# Average firing rate in MI analysis: 13.484809 Hz

# %% [markdown]
# Estimate the goodness of the matrix

# %%
extended_hit = numpy.append(hit_matrix, [faa_matrix], axis=0)
selected_pattern = numpy.argmax(extended_hit, axis=0)

# Select those cells mainly responding to one of the patterns
ind = numpy.where(selected_pattern<simulation.pattern_generator.number_of_patterns)

diagonal = hit_matrix[selected_pattern[ind],ind]

# Create a new matrix setting the diagonal values to zero
zero_matrix = numpy.copy(hit_matrix)
zero_matrix[selected_pattern[ind],ind] = 0.0

# Calculate the average of the diagonal elements
av_selected = numpy.average(diagonal)
av_nonselected = numpy.sum(zero_matrix[:])/(simulation.cerebellum.get_number_of_elements(layer=layer)*(simulation.pattern_generator.number_of_patterns))
print 'Average hits of selected elements:',av_selected
print 'Average hits of non-selected elements:',av_nonselected
hit_index = av_selected - av_nonselected
print 'Hit index:',hit_index
# Out:
# Average hits of selected elements: 0.942513089129
# Average hits of non-selected elements: 0.650633925249
# Hit index: 0.29187916388

# %% [markdown]
# ## GoC activity analysis

# %% [markdown]
# Calculate the average firing frequency of each Golgi cells during the ending 100 seconds

# %%
gtime,gcell_id = simulation.cerebellum.get_spike_activity(neuron_layer = 'goclayer',
                                                          init_time = simulation.current_time-simulation_time, 
                                                          end_time = simulation.current_time)
import numpy
firing_frequency = numpy.bincount(gcell_id) / (simulation_time*8.0)
# %matplotlib inline
import matplotlib.pyplot as plt
plt.hist(firing_frequency, bins=20)
plt.ylabel('Number of GoC cells')
plt.xlabel('Av. Spikes per Oscillatory Cycle')

# %% [markdown]
# Get the histogram of input synapses for the Golgi cells

# %%
target_cell_index = simulation.cerebellum.layer_map['mfgocsynapsis'].target_index
cell_number = simulation.cerebellum.layer_map['goclayer'].number_of_neurons
number_of_inputs = numpy.bincount(target_cell_index)
plt.hist(number_of_inputs, bins=30)
plt.ylabel('Number of GoC cells')
plt.xlabel('Number of input synapses from glomeruli')

# %% [markdown]
# Plot the histogram of non-zero weights between MF and GoC

# %%
target_cell_index = simulation.cerebellum.layer_map['mfgocsynapsis'].target_index
source_cell_index = simulation.cerebellum.layer_map['mfgocsynapsis'].source_index
weight = simulation.cerebellum.layer_map['mfgocsynapsis'].weights
plt.figure()
plt.hist(weight, bins=20)
plt.ylabel('Synaptic Weight')
plt.xlabel('Number of MF-GoC synapses')
max_weight = numpy.max(weight)
active_synapses = weight>max_weight*0.2
number_of_active_inputs = numpy.bincount(target_cell_index[active_synapses])
plt.figure()
plt.hist(number_of_active_inputs, bins=10)
plt.ylabel('Number of GoC cells')
plt.xlabel('Number of active inputs')
print 'Number of active synapses MF-GoC:',numpy.count_nonzero(active_synapses)
# Out:
# Number of active synapses MF-GoC: 90

# %% [markdown]
# Histogram of active synapses connecting input fibers included in the pattern

# %%
for pat_id in range(simulation.pattern_generator.number_of_patterns):
    included_in_pattern = numpy.in1d(source_cell_index, simulation.pattern_generator.fibers_in_pattern[pat_id,:])
    included_and_active = numpy.logical_and(included_in_pattern,active_synapses)
    number_of_active_inputs_in_pattern = numpy.bincount(target_cell_index[included_and_active])
    plt.figure()
    plt.hist(number_of_active_inputs_in_pattern, bins=10)
    plt.ylabel('Number of GoC cells')
    plt.xlabel('Number of active inputs in pattern')
    print 'Number of active MF-GoC synapses also included in pattern',pat_id,':', numpy.count_nonzero(included_and_active)
    plt.figure()
    simulation.pattern_generator.fibers_in_pattern[0,:]
    activation_level = [simulation.pattern_generator.pattern_activation[pat_id,numpy.where(simulation.pattern_generator.fibers_in_pattern[pat_id,:]==source)[0][0]] 
                    for source in source_cell_index[included_and_active]]
    plt.hist(activation_level, bins=20)
    plt.ylabel('Number of active synapses')
    plt.xlabel('Activation level')
# Out:
# Number of active MF-GoC synapses also included in pattern 0 : 36
# Number of active MF-GoC synapses also included in pattern 1 : 53
# Number of active MF-GoC synapses also included in pattern 2 : 53
# Number of active MF-GoC synapses also included in pattern 3 : 16

# %% [markdown]
# Represent the hit rate matrix of each GoC to each pattern

# %%
layer = 'goclayer'
window_length = simulation.config_options['hit_analysis']['window_length'] = simulation_time
time_bin = simulation.config_options['hit_analysis']['time_bin'] = 0.125

cr_matrix, hit_matrix, miss_matrix, fa_matrix, faa_matrix = analyze_activity(layer, window_length, time_bin)

#numpy.set_printoptions(threshold=numpy.nan)
#print 'Individual pattern hit matrix:'
#print hit_matrix
#print 'Individual pattern correct rejection matrix:'
#print cr_matrix
#print 'Individual pattern miss matrix:'
#print miss_matrix
#print 'Individual pattern false alarm matrix:'
#print fa_matrix
#print 'All patterns false alarm array:'
#print faa_matrix

extended_hit = numpy.append(hit_matrix, [faa_matrix], axis=0)
selected_pattern = numpy.argmax(extended_hit, axis=0)
plt.figure()
plt.hist(selected_pattern, bins=simulation.pattern_generator.number_of_patterns+1)
plt.ylabel('Count GoCs')
plt.xlabel('Favourite pattern')
cell_sorted = numpy.argsort(selected_pattern)
plt.figure()
plt.matshow(extended_hit[:,cell_sorted], extent=[0,simulation.cerebellum.get_number_of_elements(layer=layer),0,simulation.pattern_generator.number_of_patterns+1], vmin=0, vmax=1.0, aspect='auto')
plt.ylabel('Pattern')
plt.xlabel('GoC neuron')
plt.colorbar()
# Out:
# Average firing rate in MI analysis: 6.60622222222 Hz

# %% [markdown]
# Estimate the goodness of the matrix

# %%
extended_hit = numpy.append(hit_matrix, [faa_matrix], axis=0)
selected_pattern = numpy.argmax(extended_hit, axis=0)

# Select those cells mainly responding to one of the patterns
ind = numpy.where(selected_pattern<simulation.pattern_generator.number_of_patterns)

diagonal = hit_matrix[selected_pattern[ind],ind]

# Create a new matrix setting the diagonal values to zero
zero_matrix = numpy.copy(hit_matrix)
zero_matrix[selected_pattern[ind],ind] = 0.0

# Calculate the average of the diagonal elements
av_selected = numpy.average(diagonal)
av_nonselected = numpy.sum(zero_matrix[:])/(simulation.cerebellum.get_number_of_elements(layer=layer)*(simulation.pattern_generator.number_of_patterns))
print 'Average hits of selected elements:',av_selected
print 'Average hits of non-selected elements:',av_nonselected
hit_index = av_selected - av_nonselected
print 'Hit index:',hit_index
# Out:
# Average hits of selected elements: 0.960193180043
# Average hits of non-selected elements: 0.620967821054
# Hit index: 0.33922535899

# %% [markdown]
# ## PC activity analysis

# %% [markdown]
# Histogram of active synapses GrC-PC

# %%
target_cell_index = simulation.cerebellum.layer_map['grcpcsynapsis'].target_index
source_cell_index = simulation.cerebellum.layer_map['grcpcsynapsis'].source_index
weight = simulation.cerebellum.layer_map['grcpcsynapsis'].weights
plt.figure()
plt.hist(weight, bins=20)
plt.ylabel('Number of GrC-PC synapses')
plt.xlabel('Synaptic Weight')
max_weight = numpy.max(weight)
active_synapses = weight>max_weight*0.2
number_of_active_inputs = numpy.bincount(target_cell_index[active_synapses])
plt.figure()
plt.hist(number_of_active_inputs, bins=10)
plt.ylabel('Number of PC cells')
plt.xlabel('Number of active inputs')
print 'Number of active synapses GrC-PC:',numpy.count_nonzero(active_synapses)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-173f00ce56f7> in <module>()
# ----> 1 target_cell_index = simulation.cerebellum.layer_map['grcpcsynapsis'].target_index
#       2 source_cell_index = simulation.cerebellum.layer_map['grcpcsynapsis'].source_index
#       3 weight = simulation.cerebellum.layer_map['grcpcsynapsis'].weights
#       4 plt.figure()
#       5 plt.hist(weight, bins=20)
#
# KeyError: 'grcpcsynapsis'
