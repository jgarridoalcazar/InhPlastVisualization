# %% [markdown]
# # Data anaylsis in cerebellar granular layer simulations
# ## Running the simulation
#
# First, we set current working directory to the root of Spiking Granular Layer and insert the source folder to the python path:

# %%
import os
os.chdir('../../')
os.getcwd()
import sys
import numpy
# %matplotlib inline
import matplotlib.pyplot as plt
sys.path.insert(1,'./src')

# %% [markdown]
# Now start setting a new simulation with the configuration file that we specify:

# %%
config_file = './config/GoCGrC/SimulationConfigNPR.cfg'
simulation_time = 100.0
import SpikingSimulation.FrequencySimulation as FrequencySimulation
simulation = FrequencySimulation.FrequencySimulation(config_file=config_file)

# %% [markdown]
# Initialize the simulation

# %%
simulation.config_options['simulation']['verbosity'] = 'Debug'
simulation.config_options['simulation']['seed'] = 123456
simulation.config_options['simulation']['time'] = simulation_time
simulation.config_options['network']['load_file'] = './results/GoCGrC/network01_NPR.h5'
simulation.config_options['network']['save_file'] = None
simulation.config_options['stimulation']['load_pattern_file'] = './results/GoCGrC/stimulation_NPR.h5'
simulation.config_options['stimulation']['save_pattern_file'] = None
simulation.config_options['grclayer']['register_activity'] = True
simulation.config_options['goclayer']['register_activity'] = True
simulation.config_options['grclayer']['load_state_vars'] = 'Vth'
simulation.config_options['goclayer']['load_state_vars'] = 'Vth'
simulation.config_options['grclayer']['load_state_vars'] = None
simulation.config_options['goclayer']['load_state_vars'] = None
simulation.initialize()
# Out:
# 2016-11-21 13:42:51,214 - P46085 - Simulation - DEBUG: Simulation time fixed to 100.0s
# 2016-11-21 13:42:51,217 - P46085 - Simulation - DEBUG: Creating cerebellum generator
# 2016-11-21 13:42:51,484 - P46085 - Simulation - DEBUG: Initializing cerebellum generator
# 2016-11-21 13:42:51,487 - P46085 - Simulation - DEBUG: Cerebellar simulation initialized
# 2016-11-21 13:42:51,509 - P46085 - Simulation - DEBUG: NEST module loaded
# 2016-11-21 13:42:51,535 - P46085 - Simulation - DEBUG: Setting Global NEST Seed: 12356
# 2016-11-21 13:42:51,537 - P46085 - Simulation - DEBUG: Setting Per-Process NEST Seeds: [12357, 12358, 12359, 12360, 12361, 12362, 12363, 12364, 12365, 12366]
# 2016-11-21 13:42:51,647 - P46085 - Simulation - WARNING: Non-specified cell model parameter: tau_minus in layer mflayer. Using default value
# 2016-11-21 13:42:51,648 - P46085 - Simulation - WARNING: Non-specified number of neurons in layer mflayer
# 2016-11-21 13:42:51,652 - P46085 - Simulation - WARNING: Non-specified number of neurons in layer grclayer
# 2016-11-21 13:42:51,656 - P46085 - Simulation - WARNING: Non-specified number of neurons in layer goclayer
# 2016-11-21 13:42:51,665 - P46085 - Simulation - WARNING: tau_minus cannot be calculated in layer mflayer. Variable tau_minus is not defined. Using default value 20.0
# 2016-11-21 13:42:51,669 - P46085 - Simulation - WARNING: tau_minus_triplet cannot be calculated in layer mflayer. Variable tau_istdp is not defined. Using default value 110.0
# 2016-11-21 13:42:51,690 - P46085 - Simulation - DEBUG: Nest Process: 0. Neuron layer created in layer mflayer: 300. Local: 300
# 2016-11-21 13:42:51,870 - P46085 - Simulation - DEBUG: Nest Process: 0. Neuron layer created in layer grclayer: 4000. Local: 4000
# 2016-11-21 13:42:51,877 - P46085 - Simulation - DEBUG: Nest Process: 0. Neuron layer created in layer goclayer: 9. Local: 9
# /Users/jgarrido/NEST/nest210/ins_nompi/lib/python2.7/site-packages/nest/lib/hl_api_helper.py:61: UserWarning:
# OneToOneConnect is deprecated and will be removed in a future version of NEST.
# Please use Connect instead!
# For details, see http://www.nest-simulator.org/connection_management
# 2016-11-21 13:42:57,114 - P46085 - Simulation - DEBUG: Nest Process: 0. Connections created in layer mfgrcsynapsis: 80133
# 2016-11-21 13:42:57,173 - P46085 - Simulation - DEBUG: Nest Process: 0. Connections created in layer mfgocsynapsis: 1941
# 2016-11-21 13:42:59,235 - P46085 - Simulation - DEBUG: Nest Process: 0. Connections created in layer grcgocsynapsis: 35917
# 2016-11-21 13:43:00,353 - P46085 - Simulation - DEBUG: Nest Process: 0. Connections created in layer gocgrcsynapsis: 14877
# 2016-11-21 13:43:00,366 - P46085 - Simulation - DEBUG: Nest Process: 0. Connections created in layer gocgocsynapsis: 81
# 2016-11-21 13:43:00,367 - P46085 - Simulation - DEBUG: Creating AC Current generator
# 2016-11-21 13:43:00,374 - P46085 - Simulation - DEBUG: Creating DC Current generator
# 2016-11-21 13:43:00,419 - P46085 - Simulation - INFO: Loading activation patterns from hdf5 file ./results/GoCGrC/stimulation_NPR.h5
# 2016-11-21 13:43:00,421 - P46085 - Simulation - DEBUG: Loading stimulation pattern 0
# 2016-11-21 13:43:00,423 - P46085 - Simulation - DEBUG: Loading stimulation pattern 1
# 2016-11-21 13:43:00,428 - P46085 - Simulation - DEBUG: Loading stimulation pattern 2
# 2016-11-21 13:43:00,430 - P46085 - Simulation - DEBUG: Loading stimulation pattern 3
# 2016-11-21 13:43:00,437 - P46085 - Simulation - DEBUG: File reading ended
# 2016-11-21 13:43:00,447 - P46085 - Simulation - DEBUG: Pattern 0 and 1 share 9 input cells: [  3  10  63  97  98 166 225 250 291]
# 2016-11-21 13:43:00,453 - P46085 - Simulation - DEBUG: Activation level of pattern 0 in shared cells: [ 0.31384434  0.57676696  0.16831371  0.42600163  0.8247      0.94795745
#   0.12610996  0.33126451  0.30310977]
# 2016-11-21 13:43:00,458 - P46085 - Simulation - DEBUG: Activation level of pattern 1 in shared cells: [ 0.27535109  0.95452754  0.39605282  0.84281578  0.79400769  0.01264391
#   0.66262406  0.68188127  0.56055618]
# 2016-11-21 13:43:00,461 - P46085 - Simulation - DEBUG: Pattern 0 and 2 share 10 input cells: [  6  17  42 108 151 166 192 232 249 287]
# 2016-11-21 13:43:00,470 - P46085 - Simulation - DEBUG: Activation level of pattern 0 in shared cells: [ 0.36215377  0.93545104  0.4321796   0.20337727  0.8763047   0.94795745
#   0.02412733  0.46506151  0.6692381   0.7452776 ]
# 2016-11-21 13:43:00,477 - P46085 - Simulation - DEBUG: Activation level of pattern 2 in shared cells: [ 0.74963008  0.70697753  0.70971614  0.95603006  0.91893935  0.48986737
#   0.65290225  0.31420186  0.50351634  0.92865547]
# 2016-11-21 13:43:00,479 - P46085 - Simulation - DEBUG: Pattern 0 and 3 share 10 input cells: [ 17  42  43  63  98 101 144 151 172 192]
# 2016-11-21 13:43:00,485 - P46085 - Simulation - DEBUG: Activation level of pattern 0 in shared cells: [ 0.93545104  0.4321796   0.75142018  0.16831371  0.8247      0.16729703
#   0.36877867  0.8763047   0.7439374   0.02412733]
# 2016-11-21 13:43:00,492 - P46085 - Simulation - DEBUG: Activation level of pattern 3 in shared cells: [ 1.          0.76985416  0.21513196  0.5976772   0.46424307  0.02378312
#   0.90314845  0.01046952  0.48201751  0.58944637]
# 2016-11-21 13:43:00,495 - P46085 - Simulation - DEBUG: Pattern 1 and 2 share 8 input cells: [  5  15 150 162 166 219 242 255]
# 2016-11-21 13:43:00,502 - P46085 - Simulation - DEBUG: Activation level of pattern 1 in shared cells: [ 0.54752595  0.57425288  0.7430636   0.43275778  0.01264391  0.24871644
#   0.70156692  0.14088301]
# 2016-11-21 13:43:00,508 - P46085 - Simulation - DEBUG: Activation level of pattern 2 in shared cells: [ 0.23014886  0.13830816  0.08593616  0.89562755  0.48986737  0.21630022
#   0.50686006  0.66718018]
# 2016-11-21 13:43:00,510 - P46085 - Simulation - DEBUG: Pattern 1 and 3 share 12 input cells: [ 19  63  98 112 129 155 160 188 245 272 279 284]
# 2016-11-21 13:43:00,517 - P46085 - Simulation - DEBUG: Activation level of pattern 1 in shared cells: [ 0.1587538   0.39605282  0.79400769  0.87871829  0.1899886   0.08618984
#   0.04889717  0.85506368  0.91141739  0.08174307  0.61748296  0.11539903]
# 2016-11-21 13:43:00,524 - P46085 - Simulation - DEBUG: Activation level of pattern 3 in shared cells: [ 0.61557826  0.5976772   0.46424307  0.38925199  0.62303051  0.71416198
#   0.03702566  1.          0.88081103  0.23334569  0.90276667  0.47727511]
# 2016-11-21 13:43:00,530 - P46085 - Simulation - DEBUG: Pattern 2 and 3 share 15 input cells: [ 17  23  42  56  59 119 136 151 192 217 247 252 263 270 289]
# 2016-11-21 13:43:00,535 - P46085 - Simulation - DEBUG: Activation level of pattern 2 in shared cells: [ 0.70697753  0.73999847  0.70971614  0.46204165  0.13040329  0.95618846
#   0.7980752   0.91893935  0.65290225  0.1757998   0.6119256   0.30097695
#   0.69812818  0.28068602  0.34511541]
# 2016-11-21 13:43:00,544 - P46085 - Simulation - DEBUG: Activation level of pattern 3 in shared cells: [ 1.          0.11101392  0.76985416  0.69811594  1.          0.80404384
#   0.24560298  0.01046952  0.58944637  0.87940841  1.          0.15007137
#   0.93464438  0.32819368  0.04236616]
# 2016-11-21 13:43:00,597 - P46085 - Simulation - DEBUG: Normalization on iteration 10
# 2016-11-21 13:43:00,599 - P46085 - Simulation - DEBUG: Average sum per columns 149.954633897
# 2016-11-21 13:43:00,603 - P46085 - Simulation - DEBUG: Average sum per rows 199.439663083

# %% [markdown]
# Visualize the simulation or only run it.

# %%
#simulation.visualize_animation()
simulation.run_simulation()
# Out:
# 2016-11-21 13:43:00,615 - P46085 - Simulation - INFO: Running the simulation from 0.0s until time 100.0s
# 2016-11-21 13:43:00,634 - P46085 - Simulation - DEBUG: Running the simulation 0.177s until 0.177s
# 2016-11-21 13:43:02,462 - P46085 - Simulation - DEBUG: Running the simulation 0.113s until 0.29s
# 2016-11-21 13:43:03,674 - P46085 - Simulation - DEBUG: Running the simulation 0.964s until 1.254s
# 2016-11-21 13:43:13,637 - P46085 - Simulation - DEBUG: Running the simulation 0.38s until 1.634s
# 2016-11-21 13:43:16,758 - P46085 - Simulation - DEBUG: Running the simulation 0.076s until 1.71s
# 2016-11-21 13:43:17,548 - P46085 - Simulation - DEBUG: Running the simulation 0.125s until 1.835s
# 2016-11-21 13:43:18,794 - P46085 - Simulation - DEBUG: Running the simulation 0.024s until 1.859s
# 2016-11-21 13:43:19,044 - P46085 - Simulation - DEBUG: Running the simulation 0.021s until 1.88s
# 2016-11-21 13:43:19,221 - P46085 - Simulation - DEBUG: Running the simulation 0.063s until 1.943s
# 2016-11-21 13:43:19,901 - P46085 - Simulation - DEBUG: Running the simulation 0.352s until 2.295s
# 2016-11-21 13:43:23,973 - P46085 - Simulation - DEBUG: Running the simulation 0.04s until 2.335s
# 2016-11-21 13:43:24,686 - P46085 - Simulation - DEBUG: Running the simulation 0.793s until 3.128s
# 2016-11-21 13:43:33,746 - P46085 - Simulation - DEBUG: Running the simulation 0.393s until 3.521s
# 2016-11-21 13:43:37,369 - P46085 - Simulation - DEBUG: Running the simulation 0.102s until 3.623s
# 2016-11-21 13:43:38,627 - P46085 - Simulation - DEBUG: Running the simulation 0.122s until 3.745s
# 2016-11-21 13:43:40,108 - P46085 - Simulation - DEBUG: Running the simulation 0.084s until 3.829s
# 2016-11-21 13:43:41,147 - P46085 - Simulation - DEBUG: Running the simulation 0.552s until 4.381s
# 2016-11-21 13:43:46,893 - P46085 - Simulation - DEBUG: Running the simulation 0.191s until 4.572s
# 2016-11-21 13:43:48,857 - P46085 - Simulation - DEBUG: Running the simulation 0.344s until 4.916s
# 2016-11-21 13:43:52,221 - P46085 - Simulation - DEBUG: Running the simulation 0.05s until 4.966s
# 2016-11-21 13:43:52,578 - P46085 - Simulation - DEBUG: Running the simulation 0.007s until 4.973s
# 2016-11-21 13:43:52,626 - P46085 - Simulation - DEBUG: Running the simulation 0.321s until 5.294s
# 2016-11-21 13:43:54,698 - P46085 - Simulation - DEBUG: Running the simulation 0.087s until 5.381s
# 2016-11-21 13:43:55,235 - P46085 - Simulation - DEBUG: Running the simulation 0.139s until 5.52s
# 2016-11-21 13:43:56,501 - P46085 - Simulation - DEBUG: Running the simulation 0.122s until 5.642s
# 2016-11-21 13:43:57,877 - P46085 - Simulation - DEBUG: Running the simulation 0.081s until 5.723s
# 2016-11-21 13:43:58,770 - P46085 - Simulation - DEBUG: Running the simulation 0.482s until 6.205s
# 2016-11-21 13:44:03,632 - P46085 - Simulation - DEBUG: Running the simulation 0.369s until 6.574s
# 2016-11-21 13:44:07,808 - P46085 - Simulation - DEBUG: Running the simulation 0.103s until 6.677s
# 2016-11-21 13:44:09,063 - P46085 - Simulation - DEBUG: Running the simulation 0.732s until 7.409s
# 2016-11-21 13:44:14,347 - P46085 - Simulation - DEBUG: Running the simulation 0.047s until 7.456s
# 2016-11-21 13:44:14,854 - P46085 - Simulation - DEBUG: Running the simulation 0.217s until 7.673s
# 2016-11-21 13:44:16,926 - P46085 - Simulation - DEBUG: Running the simulation 0.07s until 7.743s
# 2016-11-21 13:44:17,575 - P46085 - Simulation - DEBUG: Running the simulation 0.032s until 7.775s
# 2016-11-21 13:44:17,854 - P46085 - Simulation - DEBUG: Running the simulation 0.247s until 8.022s
# 2016-11-21 13:44:20,199 - P46085 - Simulation - DEBUG: Running the simulation 0.144s until 8.166s
# 2016-11-21 13:44:21,601 - P46085 - Simulation - DEBUG: Running the simulation 0.054s until 8.22s
# 2016-11-21 13:44:22,145 - P46085 - Simulation - DEBUG: Running the simulation 0.554s until 8.774s
# 2016-11-21 13:44:26,937 - P46085 - Simulation - DEBUG: Running the simulation 0.12s until 8.894s
# 2016-11-21 13:44:27,654 - P46085 - Simulation - DEBUG: Running the simulation 0.017s until 8.911s
# 2016-11-21 13:44:27,770 - P46085 - Simulation - DEBUG: Running the simulation 0.473s until 9.384s
# 2016-11-21 13:44:31,650 - P46085 - Simulation - DEBUG: Running the simulation 0.066s until 9.45s
# 2016-11-21 13:44:32,296 - P46085 - Simulation - DEBUG: Running the simulation 0.571s until 10.021s
# 2016-11-21 13:44:37,682 - P46085 - Simulation - DEBUG: Running the simulation 0.45s until 10.471s
# 2016-11-21 13:44:42,202 - P46085 - Simulation - DEBUG: Running the simulation 0.197s until 10.668s
# 2016-11-21 13:44:43,663 - P46085 - Simulation - DEBUG: Running the simulation 0.046s until 10.714s
# 2016-11-21 13:44:43,963 - P46085 - Simulation - DEBUG: Running the simulation 0.27s until 10.984s
# 2016-11-21 13:44:45,533 - P46085 - Simulation - DEBUG: Running the simulation 0.134s until 11.118s
# 2016-11-21 13:44:46,494 - P46085 - Simulation - DEBUG: Running the simulation 0.445s until 11.563s
# 2016-11-21 13:44:50,788 - P46085 - Simulation - DEBUG: Running the simulation 0.272s until 11.835s
# 2016-11-21 13:44:53,297 - P46085 - Simulation - DEBUG: Running the simulation 0.005s until 11.84s
# 2016-11-21 13:44:53,362 - P46085 - Simulation - DEBUG: Running the simulation 0.346s until 12.186s
# 2016-11-21 13:44:56,990 - P46085 - Simulation - DEBUG: Running the simulation 0.101s until 12.287s
# 2016-11-21 13:44:57,971 - P46085 - Simulation - DEBUG: Running the simulation 0.207s until 12.494s
# 2016-11-21 13:45:00,172 - P46085 - Simulation - DEBUG: Running the simulation 0.002s until 12.496s
# 2016-11-21 13:45:00,191 - P46085 - Simulation - DEBUG: Running the simulation 0.222s until 12.718s
# 2016-11-21 13:45:01,916 - P46085 - Simulation - DEBUG: Running the simulation 0.254s until 12.972s
# 2016-11-21 13:45:03,484 - P46085 - Simulation - DEBUG: Running the simulation 0.714s until 13.686s
# 2016-11-21 13:45:10,403 - P46085 - Simulation - DEBUG: Running the simulation 0.111s until 13.797s
# 2016-11-21 13:45:11,519 - P46085 - Simulation - DEBUG: Running the simulation 0.24s until 14.037s
# 2016-11-21 13:45:13,807 - P46085 - Simulation - DEBUG: Running the simulation 0.047s until 14.084s
# 2016-11-21 13:45:14,291 - P46085 - Simulation - DEBUG: Running the simulation 0.023s until 14.107s
# 2016-11-21 13:45:14,502 - P46085 - Simulation - DEBUG: Running the simulation 0.093s until 14.2s
# 2016-11-21 13:45:15,348 - P46085 - Simulation - DEBUG: Running the simulation 0.09s until 14.29s
# 2016-11-21 13:45:16,140 - P46085 - Simulation - DEBUG: Running the simulation 0.139s until 14.429s
# 2016-11-21 13:45:17,327 - P46085 - Simulation - DEBUG: Running the simulation 0.533s until 14.962s
# 2016-11-21 13:45:20,652 - P46085 - Simulation - DEBUG: Running the simulation 0.314s until 15.276s
# 2016-11-21 13:45:23,535 - P46085 - Simulation - DEBUG: Running the simulation 0.038s until 15.314s
# 2016-11-21 13:45:23,933 - P46085 - Simulation - DEBUG: Running the simulation 0.167s until 15.481s
# 2016-11-21 13:45:25,481 - P46085 - Simulation - DEBUG: Running the simulation 0.206s until 15.687s
# 2016-11-21 13:45:27,430 - P46085 - Simulation - DEBUG: Running the simulation 0.42s until 16.107s
# 2016-11-21 13:45:31,355 - P46085 - Simulation - DEBUG: Running the simulation 0.655s until 16.762s
# 2016-11-21 13:45:35,849 - P46085 - Simulation - DEBUG: Running the simulation 0.246s until 17.008s
# 2016-11-21 13:45:37,972 - P46085 - Simulation - DEBUG: Running the simulation 0.214s until 17.222s
# 2016-11-21 13:45:40,143 - P46085 - Simulation - DEBUG: Running the simulation 0.218s until 17.44s
# 2016-11-21 13:45:42,407 - P46085 - Simulation - DEBUG: Running the simulation 0.211s until 17.651s
# 2016-11-21 13:45:44,511 - P46085 - Simulation - DEBUG: Running the simulation 0.14s until 17.791s
# 2016-11-21 13:45:46,174 - P46085 - Simulation - DEBUG: Running the simulation 0.02s until 17.811s
# 2016-11-21 13:45:46,416 - P46085 - Simulation - DEBUG: Running the simulation 0.414s until 18.225s
# 2016-11-21 13:45:50,812 - P46085 - Simulation - DEBUG: Running the simulation 0.302s until 18.527s
# 2016-11-21 13:45:53,070 - P46085 - Simulation - DEBUG: Running the simulation 0.24s until 18.767s
# 2016-11-21 13:45:55,035 - P46085 - Simulation - DEBUG: Running the simulation 0.395s until 19.162s
# 2016-11-21 13:45:58,576 - P46085 - Simulation - DEBUG: Running the simulation 0.239s until 19.401s
# 2016-11-21 13:46:00,889 - P46085 - Simulation - DEBUG: Running the simulation 0.072s until 19.473s
# 2016-11-21 13:46:01,586 - P46085 - Simulation - DEBUG: Running the simulation 0.231s until 19.704s
# 2016-11-21 13:46:03,729 - P46085 - Simulation - DEBUG: Running the simulation 0.117s until 19.821s
# 2016-11-21 13:46:04,802 - P46085 - Simulation - DEBUG: Running the simulation 0.103s until 19.924s
# 2016-11-21 13:46:05,718 - P46085 - Simulation - DEBUG: Running the simulation 0.073s until 19.997s
# 2016-11-21 13:46:06,393 - P46085 - Simulation - DEBUG: Running the simulation 0.225s until 20.222s
# 2016-11-21 13:46:08,393 - P46085 - Simulation - DEBUG: Running the simulation 0.226s until 20.448s
# 2016-11-21 13:46:09,712 - P46085 - Simulation - DEBUG: Running the simulation 0.27s until 20.718s
# 2016-11-21 13:46:11,445 - P46085 - Simulation - DEBUG: Running the simulation 0.022s until 20.74s
# 2016-11-21 13:46:11,627 - P46085 - Simulation - DEBUG: Running the simulation 0.113s until 20.853s
# 2016-11-21 13:46:12,639 - P46085 - Simulation - DEBUG: Running the simulation 0.225s until 21.078s
# 2016-11-21 13:46:14,781 - P46085 - Simulation - DEBUG: Running the simulation 0.562s until 21.64s
# 2016-11-21 13:46:20,058 - P46085 - Simulation - DEBUG: Running the simulation 0.072s until 21.712s
# 2016-11-21 13:46:20,747 - P46085 - Simulation - DEBUG: Running the simulation 0.021s until 21.733s
# 2016-11-21 13:46:20,939 - P46085 - Simulation - DEBUG: Running the simulation 0.623s until 22.356s
# 2016-11-21 13:46:25,938 - P46085 - Simulation - DEBUG: Running the simulation 0.11s until 22.466s
# 2016-11-21 13:46:26,581 - P46085 - Simulation - DEBUG: Running the simulation 0.005s until 22.471s
# 2016-11-21 13:46:26,614 - P46085 - Simulation - DEBUG: Running the simulation 0.162s until 22.633s
# 2016-11-21 13:46:27,734 - P46085 - Simulation - DEBUG: Running the simulation 0.302s until 22.935s
# 2016-11-21 13:46:30,645 - P46085 - Simulation - DEBUG: Running the simulation 0.208s until 23.143s
# 2016-11-21 13:46:32,510 - P46085 - Simulation - DEBUG: Running the simulation 0.011s until 23.154s
# 2016-11-21 13:46:32,646 - P46085 - Simulation - DEBUG: Running the simulation 0.223s until 23.377s
# 2016-11-21 13:46:34,708 - P46085 - Simulation - DEBUG: Running the simulation 0.488s until 23.865s
# 2016-11-21 13:46:39,279 - P46085 - Simulation - DEBUG: Running the simulation 0.618s until 24.483s
# 2016-11-21 13:46:43,440 - P46085 - Simulation - DEBUG: Running the simulation 0.03s until 24.513s
# 2016-11-21 13:46:43,594 - P46085 - Simulation - DEBUG: Running the simulation 0.145s until 24.658s
# 2016-11-21 13:46:44,805 - P46085 - Simulation - DEBUG: Running the simulation 0.049s until 24.707s
# 2016-11-21 13:46:45,289 - P46085 - Simulation - DEBUG: Running the simulation 0.231s until 24.938s
# 2016-11-21 13:46:47,407 - P46085 - Simulation - DEBUG: Running the simulation 0.045s until 24.983s
# 2016-11-21 13:46:47,851 - P46085 - Simulation - DEBUG: Running the simulation 0.017s until 25.0s
# 2016-11-21 13:46:48,001 - P46085 - Simulation - DEBUG: Running the simulation 0.168s until 25.168s
# 2016-11-21 13:46:49,610 - P46085 - Simulation - DEBUG: Running the simulation 0.227s until 25.395s
# 2016-11-21 13:46:51,632 - P46085 - Simulation - DEBUG: Running the simulation 0.075s until 25.47s
# 2016-11-21 13:46:52,326 - P46085 - Simulation - DEBUG: Running the simulation 0.016s until 25.486s
# 2016-11-21 13:46:52,469 - P46085 - Simulation - DEBUG: Running the simulation 0.057s until 25.543s
# 2016-11-21 13:46:52,993 - P46085 - Simulation - DEBUG: Running the simulation 0.501s until 26.044s
# 2016-11-21 13:46:57,569 - P46085 - Simulation - DEBUG: Running the simulation 0.326s until 26.37s
# 2016-11-21 13:46:59,691 - P46085 - Simulation - DEBUG: Running the simulation 0.073s until 26.443s
# 2016-11-21 13:47:00,137 - P46085 - Simulation - DEBUG: Running the simulation 0.489s until 26.932s
# 2016-11-21 13:47:04,120 - P46085 - Simulation - DEBUG: Running the simulation 0.057s until 26.989s
# 2016-11-21 13:47:04,607 - P46085 - Simulation - DEBUG: Running the simulation 0.015s until 27.004s
# 2016-11-21 13:47:04,743 - P46085 - Simulation - DEBUG: Running the simulation 0.003s until 27.007s
# 2016-11-21 13:47:04,776 - P46085 - Simulation - DEBUG: Running the simulation 0.235s until 27.242s
# 2016-11-21 13:47:06,969 - P46085 - Simulation - DEBUG: Running the simulation 0.061s until 27.303s
# 2016-11-21 13:47:07,529 - P46085 - Simulation - DEBUG: Running the simulation 0.16s until 27.463s
# 2016-11-21 13:47:09,039 - P46085 - Simulation - DEBUG: Running the simulation 0.013s until 27.476s
# 2016-11-21 13:47:09,162 - P46085 - Simulation - DEBUG: Running the simulation 0.113s until 27.589s
# 2016-11-21 13:47:10,165 - P46085 - Simulation - DEBUG: Running the simulation 0.062s until 27.651s
# 2016-11-21 13:47:10,716 - P46085 - Simulation - DEBUG: Running the simulation 0.18s until 27.831s
# 2016-11-21 13:47:12,463 - P46085 - Simulation - DEBUG: Running the simulation 0.022s until 27.853s
# 2016-11-21 13:47:12,659 - P46085 - Simulation - DEBUG: Running the simulation 0.057s until 27.91s
# 2016-11-21 13:47:13,143 - P46085 - Simulation - DEBUG: Running the simulation 0.222s until 28.132s
# 2016-11-21 13:47:15,095 - P46085 - Simulation - DEBUG: Running the simulation 0.081s until 28.213s
# 2016-11-21 13:47:15,597 - P46085 - Simulation - DEBUG: Running the simulation 0.096s until 28.309s
# 2016-11-21 13:47:16,152 - P46085 - Simulation - DEBUG: Running the simulation 0.156s until 28.465s
# 2016-11-21 13:47:17,041 - P46085 - Simulation - DEBUG: Running the simulation 0.23s until 28.695s
# 2016-11-21 13:47:18,934 - P46085 - Simulation - DEBUG: Running the simulation 0.437s until 29.132s
# 2016-11-21 13:47:22,931 - P46085 - Simulation - DEBUG: Running the simulation 0.734s until 29.866s
# 2016-11-21 13:47:29,652 - P46085 - Simulation - DEBUG: Running the simulation 0.048s until 29.914s
# 2016-11-21 13:47:30,093 - P46085 - Simulation - DEBUG: Running the simulation 0.71s until 30.624s
# 2016-11-21 13:47:34,949 - P46085 - Simulation - DEBUG: Running the simulation 0.151s until 30.775s
# 2016-11-21 13:47:36,333 - P46085 - Simulation - DEBUG: Running the simulation 0.053s until 30.828s
# 2016-11-21 13:47:36,893 - P46085 - Simulation - DEBUG: Running the simulation 0.282s until 31.11s
# 2016-11-21 13:47:39,582 - P46085 - Simulation - DEBUG: Running the simulation 0.312s until 31.422s
# 2016-11-21 13:47:42,379 - P46085 - Simulation - DEBUG: Running the simulation 0.025s until 31.447s
# 2016-11-21 13:47:42,640 - P46085 - Simulation - DEBUG: Running the simulation 0.499s until 31.946s
# 2016-11-21 13:47:47,053 - P46085 - Simulation - DEBUG: Running the simulation 0.465s until 32.411s
# 2016-11-21 13:47:49,732 - P46085 - Simulation - DEBUG: Running the simulation 0.024s until 32.435s
# 2016-11-21 13:47:50,012 - P46085 - Simulation - DEBUG: Running the simulation 0.406s until 32.841s
# 2016-11-21 13:47:53,762 - P46085 - Simulation - DEBUG: Running the simulation 0.077s until 32.918s
# 2016-11-21 13:47:54,449 - P46085 - Simulation - DEBUG: Running the simulation 0.068s until 32.986s
# 2016-11-21 13:47:55,136 - P46085 - Simulation - DEBUG: Running the simulation 0.494s until 33.48s
# 2016-11-21 13:47:59,780 - P46085 - Simulation - DEBUG: Running the simulation 0.046s until 33.526s
# 2016-11-21 13:48:00,198 - P46085 - Simulation - DEBUG: Running the simulation 0.002s until 33.528s
# 2016-11-21 13:48:00,224 - P46085 - Simulation - DEBUG: Running the simulation 0.209s until 33.737s
# 2016-11-21 13:48:02,201 - P46085 - Simulation - DEBUG: Running the simulation 0.334s until 34.071s
# 2016-11-21 13:48:04,395 - P46085 - Simulation - DEBUG: Running the simulation 0.14s until 34.211s
# 2016-11-21 13:48:05,170 - P46085 - Simulation - DEBUG: Running the simulation 0.089s until 34.3s
# 2016-11-21 13:48:05,689 - P46085 - Simulation - DEBUG: Running the simulation 0.192s until 34.492s
# 2016-11-21 13:48:07,491 - P46085 - Simulation - DEBUG: Running the simulation 0.142s until 34.634s
# 2016-11-21 13:48:08,824 - P46085 - Simulation - DEBUG: Running the simulation 0.038s until 34.672s
# 2016-11-21 13:48:09,215 - P46085 - Simulation - DEBUG: Running the simulation 0.019s until 34.691s
# 2016-11-21 13:48:09,432 - P46085 - Simulation - DEBUG: Running the simulation 0.135s until 34.826s
# 2016-11-21 13:48:10,732 - P46085 - Simulation - DEBUG: Running the simulation 0.645s until 35.471s
# 2016-11-21 13:48:16,809 - P46085 - Simulation - DEBUG: Running the simulation 0.276s until 35.747s
# 2016-11-21 13:48:19,351 - P46085 - Simulation - DEBUG: Running the simulation 0.431s until 36.178s
# 2016-11-21 13:48:21,852 - P46085 - Simulation - DEBUG: Running the simulation 0.049s until 36.227s
# 2016-11-21 13:48:22,208 - P46085 - Simulation - DEBUG: Running the simulation 0.347s until 36.574s
# 2016-11-21 13:48:25,447 - P46085 - Simulation - DEBUG: Running the simulation 0.17s until 36.744s
# 2016-11-21 13:48:27,058 - P46085 - Simulation - DEBUG: Running the simulation 0.509s until 37.253s
# 2016-11-21 13:48:31,787 - P46085 - Simulation - DEBUG: Running the simulation 0.113s until 37.366s
# 2016-11-21 13:48:32,840 - P46085 - Simulation - DEBUG: Running the simulation 0.06s until 37.426s
# 2016-11-21 13:48:33,369 - P46085 - Simulation - DEBUG: Running the simulation 0.969s until 38.395s
# 2016-11-21 13:48:40,540 - P46085 - Simulation - DEBUG: Running the simulation 0.15s until 38.545s
# 2016-11-21 13:48:41,943 - P46085 - Simulation - DEBUG: Running the simulation 0.47s until 39.015s
# 2016-11-21 13:48:46,271 - P46085 - Simulation - DEBUG: Running the simulation 0.031s until 39.046s
# 2016-11-21 13:48:46,580 - P46085 - Simulation - DEBUG: Running the simulation 0.873s until 39.919s
# 2016-11-21 13:48:53,618 - P46085 - Simulation - DEBUG: Running the simulation 0.188s until 40.107s
# 2016-11-21 13:48:54,702 - P46085 - Simulation - DEBUG: Running the simulation 0.916s until 41.023s
# 2016-11-21 13:49:02,928 - P46085 - Simulation - DEBUG: Running the simulation 0.448s until 41.471s
# 2016-11-21 13:49:07,108 - P46085 - Simulation - DEBUG: Running the simulation 0.118s until 41.589s
# 2016-11-21 13:49:08,116 - P46085 - Simulation - DEBUG: Running the simulation 0.071s until 41.66s
# 2016-11-21 13:49:08,535 - P46085 - Simulation - DEBUG: Running the simulation 0.072s until 41.732s
# 2016-11-21 13:49:08,957 - P46085 - Simulation - DEBUG: Running the simulation 0.345s until 42.077s
# 2016-11-21 13:49:11,101 - P46085 - Simulation - DEBUG: Running the simulation 0.029s until 42.106s
# 2016-11-21 13:49:11,351 - P46085 - Simulation - DEBUG: Running the simulation 0.849s until 42.955s
# 2016-11-21 13:49:19,164 - P46085 - Simulation - DEBUG: Running the simulation 0.692s until 43.647s
# 2016-11-21 13:49:24,848 - P46085 - Simulation - DEBUG: Running the simulation 0.011s until 43.658s
# 2016-11-21 13:49:24,920 - P46085 - Simulation - DEBUG: Running the simulation 0.002s until 43.66s
# 2016-11-21 13:49:24,939 - P46085 - Simulation - DEBUG: Running the simulation 0.133s until 43.793s
# 2016-11-21 13:49:25,706 - P46085 - Simulation - DEBUG: Running the simulation 0.239s until 44.032s
# 2016-11-21 13:49:27,320 - P46085 - Simulation - DEBUG: Running the simulation 1.351s until 45.383s
# 2016-11-21 13:49:39,929 - P46085 - Simulation - DEBUG: Running the simulation 0.206s until 45.589s
# 2016-11-21 13:49:41,461 - P46085 - Simulation - DEBUG: Running the simulation 0.235s until 45.824s
# 2016-11-21 13:49:43,302 - P46085 - Simulation - DEBUG: Running the simulation 0.073s until 45.897s
# 2016-11-21 13:49:43,792 - P46085 - Simulation - DEBUG: Running the simulation 0.032s until 45.929s
# 2016-11-21 13:49:44,061 - P46085 - Simulation - DEBUG: Running the simulation 0.218s until 46.147s
# 2016-11-21 13:49:45,950 - P46085 - Simulation - DEBUG: Running the simulation 0.132s until 46.279s
# 2016-11-21 13:49:47,305 - P46085 - Simulation - DEBUG: Running the simulation 0.572s until 46.851s
# 2016-11-21 13:49:53,331 - P46085 - Simulation - DEBUG: Running the simulation 0.573s until 47.424s
# 2016-11-21 13:49:58,633 - P46085 - Simulation - DEBUG: Running the simulation 0.284s until 47.708s
# 2016-11-21 13:50:00,980 - P46085 - Simulation - DEBUG: Running the simulation 0.232s until 47.94s
# 2016-11-21 13:50:02,327 - P46085 - Simulation - DEBUG: Running the simulation 0.026s until 47.966s
# 2016-11-21 13:50:02,489 - P46085 - Simulation - DEBUG: Running the simulation 0.461s until 48.427s
# 2016-11-21 13:50:06,377 - P46085 - Simulation - DEBUG: Running the simulation 0.831s until 49.258s
# 2016-11-21 13:50:14,699 - P46085 - Simulation - DEBUG: Running the simulation 0.416s until 49.674s
# 2016-11-21 13:50:18,372 - P46085 - Simulation - DEBUG: Running the simulation 0.369s until 50.043s
# 2016-11-21 13:50:20,728 - P46085 - Simulation - DEBUG: Running the simulation 0.473s until 50.516s
# 2016-11-21 13:50:24,576 - P46085 - Simulation - DEBUG: Running the simulation 0.304s until 50.82s
# 2016-11-21 13:50:27,409 - P46085 - Simulation - DEBUG: Running the simulation 0.000999999999998s until 50.821s
# 2016-11-21 13:50:27,426 - P46085 - Simulation - DEBUG: Running the simulation 0.175s until 50.996s
# 2016-11-21 13:50:29,068 - P46085 - Simulation - DEBUG: Running the simulation 0.269s until 51.265s
# 2016-11-21 13:50:31,568 - P46085 - Simulation - DEBUG: Running the simulation 0.082s until 51.347s
# 2016-11-21 13:50:32,375 - P46085 - Simulation - DEBUG: Running the simulation 0.389s until 51.736s
# 2016-11-21 13:50:36,191 - P46085 - Simulation - DEBUG: Running the simulation 0.03s until 51.766s
# 2016-11-21 13:50:36,417 - P46085 - Simulation - DEBUG: Running the simulation 1.463s until 53.229s
# 2016-11-21 13:50:50,154 - P46085 - Simulation - DEBUG: Running the simulation 0.046s until 53.275s
# 2016-11-21 13:50:50,663 - P46085 - Simulation - DEBUG: Running the simulation 0.124s until 53.399s
# 2016-11-21 13:50:52,007 - P46085 - Simulation - DEBUG: Running the simulation 0.189s until 53.588s
# 2016-11-21 13:50:53,828 - P46085 - Simulation - DEBUG: Running the simulation 0.054s until 53.642s
# 2016-11-21 13:50:54,341 - P46085 - Simulation - DEBUG: Running the simulation 0.233s until 53.875s
# 2016-11-21 13:50:56,109 - P46085 - Simulation - DEBUG: Running the simulation 0.135s until 54.01s
# 2016-11-21 13:50:56,928 - P46085 - Simulation - DEBUG: Running the simulation 0.275s until 54.285s
# 2016-11-21 13:50:58,877 - P46085 - Simulation - DEBUG: Running the simulation 0.585s until 54.87s
# 2016-11-21 13:51:04,339 - P46085 - Simulation - DEBUG: Running the simulation 0.707s until 55.577s
# 2016-11-21 13:51:10,982 - P46085 - Simulation - DEBUG: Running the simulation 0.619s until 56.196s
# 2016-11-21 13:51:14,946 - P46085 - Simulation - DEBUG: Running the simulation 0.232s until 56.428s
# 2016-11-21 13:51:17,062 - P46085 - Simulation - DEBUG: Running the simulation 0.063s until 56.491s
# 2016-11-21 13:51:17,680 - P46085 - Simulation - DEBUG: Running the simulation 0.071s until 56.562s
# 2016-11-21 13:51:18,390 - P46085 - Simulation - DEBUG: Running the simulation 0.508s until 57.07s
# 2016-11-21 13:51:23,173 - P46085 - Simulation - DEBUG: Running the simulation 0.129s until 57.199s
# 2016-11-21 13:51:24,677 - P46085 - Simulation - DEBUG: Running the simulation 0.508s until 57.707s
# 2016-11-21 13:51:29,707 - P46085 - Simulation - DEBUG: Running the simulation 0.101s until 57.808s
# 2016-11-21 13:51:30,397 - P46085 - Simulation - DEBUG: Running the simulation 0.095s until 57.903s
# 2016-11-21 13:51:30,936 - P46085 - Simulation - DEBUG: Running the simulation 0.044s until 57.947s
# 2016-11-21 13:51:31,210 - P46085 - Simulation - DEBUG: Running the simulation 0.15s until 58.097s
# 2016-11-21 13:51:32,047 - P46085 - Simulation - DEBUG: Running the simulation 0.058s until 58.155s
# 2016-11-21 13:51:32,371 - P46085 - Simulation - DEBUG: Running the simulation 0.621s until 58.776s
# 2016-11-21 13:51:37,636 - P46085 - Simulation - DEBUG: Running the simulation 0.41s until 59.186s
# 2016-11-21 13:51:41,465 - P46085 - Simulation - DEBUG: Running the simulation 0.346s until 59.532s
# 2016-11-21 13:51:45,291 - P46085 - Simulation - DEBUG: Running the simulation 0.155s until 59.687s
# 2016-11-21 13:51:47,042 - P46085 - Simulation - DEBUG: Running the simulation 0.084s until 59.771s
# 2016-11-21 13:51:48,052 - P46085 - Simulation - DEBUG: Running the simulation 0.771s until 60.542s
# 2016-11-21 13:51:53,561 - P46085 - Simulation - DEBUG: Running the simulation 0.5s until 61.042s
# 2016-11-21 13:51:58,340 - P46085 - Simulation - DEBUG: Running the simulation 0.06s until 61.102s
# 2016-11-21 13:51:59,076 - P46085 - Simulation - DEBUG: Running the simulation 0.258s until 61.36s
# 2016-11-21 13:52:01,991 - P46085 - Simulation - DEBUG: Running the simulation 0.193s until 61.553s
# 2016-11-21 13:52:04,048 - P46085 - Simulation - DEBUG: Running the simulation 0.298s until 61.851s
# 2016-11-21 13:52:06,896 - P46085 - Simulation - DEBUG: Running the simulation 0.004s until 61.855s
# 2016-11-21 13:52:06,922 - P46085 - Simulation - DEBUG: Running the simulation 0.472s until 62.327s
# 2016-11-21 13:52:09,682 - P46085 - Simulation - DEBUG: Running the simulation 0.119s until 62.446s
# 2016-11-21 13:52:10,858 - P46085 - Simulation - DEBUG: Running the simulation 0.403s until 62.849s
# 2016-11-21 13:52:15,172 - P46085 - Simulation - DEBUG: Running the simulation 0.018s until 62.867s
# 2016-11-21 13:52:15,348 - P46085 - Simulation - DEBUG: Running the simulation 0.018s until 62.885s
# 2016-11-21 13:52:15,539 - P46085 - Simulation - DEBUG: Running the simulation 0.145s until 63.03s
# 2016-11-21 13:52:17,134 - P46085 - Simulation - DEBUG: Running the simulation 0.665s until 63.695s
# 2016-11-21 13:52:24,101 - P46085 - Simulation - DEBUG: Running the simulation 0.146s until 63.841s
# 2016-11-21 13:52:25,732 - P46085 - Simulation - DEBUG: Running the simulation 0.121s until 63.962s
# 2016-11-21 13:52:26,798 - P46085 - Simulation - DEBUG: Running the simulation 0.079s until 64.041s
# 2016-11-21 13:52:27,328 - P46085 - Simulation - DEBUG: Running the simulation 0.09s until 64.131s
# 2016-11-21 13:52:27,964 - P46085 - Simulation - DEBUG: Running the simulation 0.083s until 64.214s
# 2016-11-21 13:52:28,626 - P46085 - Simulation - DEBUG: Running the simulation 0.158s until 64.372s
# 2016-11-21 13:52:29,927 - P46085 - Simulation - DEBUG: Running the simulation 0.141s until 64.513s
# 2016-11-21 13:52:30,914 - P46085 - Simulation - DEBUG: Running the simulation 0.09s until 64.603s
# 2016-11-21 13:52:31,649 - P46085 - Simulation - DEBUG: Running the simulation 0.051s until 64.654s
# 2016-11-21 13:52:32,143 - P46085 - Simulation - DEBUG: Running the simulation 0.39s until 65.044s
# 2016-11-21 13:52:36,038 - P46085 - Simulation - DEBUG: Running the simulation 0.466s until 65.51s
# 2016-11-21 13:52:40,455 - P46085 - Simulation - DEBUG: Running the simulation 0.002s until 65.512s
# 2016-11-21 13:52:40,479 - P46085 - Simulation - DEBUG: Running the simulation 0.052s until 65.564s
# 2016-11-21 13:52:40,985 - P46085 - Simulation - DEBUG: Running the simulation 0.041s until 65.605s
# 2016-11-21 13:52:41,393 - P46085 - Simulation - DEBUG: Running the simulation 0.726s until 66.331s
# 2016-11-21 13:52:47,334 - P46085 - Simulation - DEBUG: Running the simulation 0.075s until 66.406s
# 2016-11-21 13:52:47,774 - P46085 - Simulation - DEBUG: Running the simulation 0.159s until 66.565s
# 2016-11-21 13:52:48,766 - P46085 - Simulation - DEBUG: Running the simulation 0.315s until 66.88s
# 2016-11-21 13:52:51,466 - P46085 - Simulation - DEBUG: Running the simulation 0.493s until 67.373s
# 2016-11-21 13:52:56,311 - P46085 - Simulation - DEBUG: Running the simulation 0.547s until 67.92s
# 2016-11-21 13:53:01,472 - P46085 - Simulation - DEBUG: Running the simulation 0.382s until 68.302s
# 2016-11-21 13:53:04,421 - P46085 - Simulation - DEBUG: Running the simulation 0.223s until 68.525s
# 2016-11-21 13:53:05,764 - P46085 - Simulation - DEBUG: Running the simulation 0.059s until 68.584s
# 2016-11-21 13:53:06,119 - P46085 - Simulation - DEBUG: Running the simulation 0.053s until 68.637s
# 2016-11-21 13:53:06,434 - P46085 - Simulation - DEBUG: Running the simulation 1.285s until 69.922s
# 2016-11-21 13:53:18,658 - P46085 - Simulation - DEBUG: Running the simulation 0.649s until 70.571s
# 2016-11-21 13:53:23,440 - P46085 - Simulation - DEBUG: Running the simulation 0.152s until 70.723s
# 2016-11-21 13:53:24,358 - P46085 - Simulation - DEBUG: Running the simulation 0.531s until 71.254s
# 2016-11-21 13:53:29,262 - P46085 - Simulation - DEBUG: Running the simulation 0.484s until 71.738s
# 2016-11-21 13:53:34,683 - P46085 - Simulation - DEBUG: Running the simulation 0.946s until 72.684s
# 2016-11-21 13:53:43,111 - P46085 - Simulation - DEBUG: Running the simulation 0.47s until 73.154s
# 2016-11-21 13:53:47,283 - P46085 - Simulation - DEBUG: Running the simulation 0.175s until 73.329s
# 2016-11-21 13:53:49,114 - P46085 - Simulation - DEBUG: Running the simulation 0.48s until 73.809s
# 2016-11-21 13:53:54,558 - P46085 - Simulation - DEBUG: Running the simulation 0.155s until 73.964s
# 2016-11-21 13:53:56,055 - P46085 - Simulation - DEBUG: Running the simulation 0.215s until 74.179s
# 2016-11-21 13:53:58,037 - P46085 - Simulation - DEBUG: Running the simulation 0.298s until 74.477s
# 2016-11-21 13:54:00,724 - P46085 - Simulation - DEBUG: Running the simulation 0.443s until 74.92s
# 2016-11-21 13:54:03,463 - P46085 - Simulation - DEBUG: Running the simulation 0.22s until 75.14s
# 2016-11-21 13:54:05,108 - P46085 - Simulation - DEBUG: Running the simulation 0.246s until 75.386s
# 2016-11-21 13:54:07,346 - P46085 - Simulation - DEBUG: Running the simulation 0.158s until 75.544s
# 2016-11-21 13:54:08,804 - P46085 - Simulation - DEBUG: Running the simulation 1.269s until 76.813s
# 2016-11-21 13:54:21,242 - P46085 - Simulation - DEBUG: Running the simulation 0.015s until 76.828s
# 2016-11-21 13:54:21,358 - P46085 - Simulation - DEBUG: Running the simulation 0.062s until 76.89s
# 2016-11-21 13:54:21,760 - P46085 - Simulation - DEBUG: Running the simulation 0.00700000000001s until 76.897s
# 2016-11-21 13:54:21,818 - P46085 - Simulation - DEBUG: Running the simulation 0.481s until 77.378s
# 2016-11-21 13:54:25,385 - P46085 - Simulation - DEBUG: Running the simulation 0.019s until 77.397s
# 2016-11-21 13:54:25,557 - P46085 - Simulation - DEBUG: Running the simulation 0.377s until 77.774s
# 2016-11-21 13:54:29,977 - P46085 - Simulation - DEBUG: Running the simulation 0.02s until 77.794s
# 2016-11-21 13:54:30,293 - P46085 - Simulation - DEBUG: Running the simulation 0.238s until 78.032s
# 2016-11-21 13:54:33,155 - P46085 - Simulation - DEBUG: Running the simulation 0.103s until 78.135s
# 2016-11-21 13:54:34,261 - P46085 - Simulation - DEBUG: Running the simulation 0.083s until 78.218s
# 2016-11-21 13:54:35,114 - P46085 - Simulation - DEBUG: Running the simulation 0.864s until 79.082s
# 2016-11-21 13:54:43,429 - P46085 - Simulation - DEBUG: Running the simulation 1.063s until 80.145s
# 2016-11-21 13:54:53,227 - P46085 - Simulation - DEBUG: Running the simulation 0.123s until 80.268s
# 2016-11-21 13:54:54,709 - P46085 - Simulation - DEBUG: Running the simulation 0.058s until 80.326s
# 2016-11-21 13:54:55,363 - P46085 - Simulation - DEBUG: Running the simulation 0.1s until 80.426s
# 2016-11-21 13:54:56,388 - P46085 - Simulation - DEBUG: Running the simulation 0.186s until 80.612s
# 2016-11-21 13:54:58,339 - P46085 - Simulation - DEBUG: Running the simulation 0.204s until 80.816s
# 2016-11-21 13:55:00,748 - P46085 - Simulation - DEBUG: Running the simulation 0.133s until 80.949s
# 2016-11-21 13:55:01,860 - P46085 - Simulation - DEBUG: Running the simulation 0.022s until 80.971s
# 2016-11-21 13:55:01,995 - P46085 - Simulation - DEBUG: Running the simulation 0.023s until 80.994s
# 2016-11-21 13:55:02,129 - P46085 - Simulation - DEBUG: Running the simulation 0.053s until 81.047s
# 2016-11-21 13:55:02,470 - P46085 - Simulation - DEBUG: Running the simulation 0.288s until 81.335s
# 2016-11-21 13:55:04,072 - P46085 - Simulation - DEBUG: Running the simulation 0.043s until 81.378s
# 2016-11-21 13:55:04,298 - P46085 - Simulation - DEBUG: Running the simulation 0.129s until 81.507s
# 2016-11-21 13:55:05,358 - P46085 - Simulation - DEBUG: Running the simulation 0.168s until 81.675s
# 2016-11-21 13:55:06,971 - P46085 - Simulation - DEBUG: Running the simulation 0.062s until 81.737s
# 2016-11-21 13:55:07,528 - P46085 - Simulation - DEBUG: Running the simulation 0.471s until 82.208s
# 2016-11-21 13:55:12,631 - P46085 - Simulation - DEBUG: Running the simulation 0.127s until 82.335s
# 2016-11-21 13:55:14,066 - P46085 - Simulation - DEBUG: Running the simulation 0.223s until 82.558s
# 2016-11-21 13:55:16,704 - P46085 - Simulation - DEBUG: Running the simulation 0.251s until 82.809s
# 2016-11-21 13:55:19,266 - P46085 - Simulation - DEBUG: Running the simulation 0.148s until 82.957s
# 2016-11-21 13:55:20,654 - P46085 - Simulation - DEBUG: Running the simulation 0.001s until 82.958s
# 2016-11-21 13:55:20,663 - P46085 - Simulation - DEBUG: Running the simulation 0.001s until 82.959s
# 2016-11-21 13:55:20,673 - P46085 - Simulation - DEBUG: Running the simulation 0.648s until 83.607s
# 2016-11-21 13:55:25,614 - P46085 - Simulation - DEBUG: Running the simulation 0.459s until 84.066s
# 2016-11-21 13:55:30,743 - P46085 - Simulation - DEBUG: Running the simulation 0.538s until 84.604s
# 2016-11-21 13:55:37,507 - P46085 - Simulation - DEBUG: Running the simulation 0.215s until 84.819s
# 2016-11-21 13:55:40,428 - P46085 - Simulation - DEBUG: Running the simulation 0.151s until 84.97s
# 2016-11-21 13:55:42,338 - P46085 - Simulation - DEBUG: Running the simulation 0.018s until 84.988s
# 2016-11-21 13:55:42,610 - P46085 - Simulation - DEBUG: Running the simulation 0.246s until 85.234s
# 2016-11-21 13:55:44,932 - P46085 - Simulation - DEBUG: Running the simulation 0.045s until 85.279s
# 2016-11-21 13:55:45,293 - P46085 - Simulation - DEBUG: Running the simulation 0.156s until 85.435s
# 2016-11-21 13:55:46,562 - P46085 - Simulation - DEBUG: Running the simulation 0.177s until 85.612s
# 2016-11-21 13:55:47,696 - P46085 - Simulation - DEBUG: Running the simulation 0.084s until 85.696s
# 2016-11-21 13:55:48,556 - P46085 - Simulation - DEBUG: Running the simulation 0.016s until 85.712s
# 2016-11-21 13:55:48,767 - P46085 - Simulation - DEBUG: Running the simulation 0.214s until 85.926s
# 2016-11-21 13:55:51,586 - P46085 - Simulation - DEBUG: Running the simulation 0.057s until 85.983s
# 2016-11-21 13:55:52,352 - P46085 - Simulation - DEBUG: Running the simulation 0.118s until 86.101s
# 2016-11-21 13:55:53,697 - P46085 - Simulation - DEBUG: Running the simulation 0.197s until 86.298s
# 2016-11-21 13:55:55,805 - P46085 - Simulation - DEBUG: Running the simulation 0.405s until 86.703s
# 2016-11-21 13:56:01,198 - P46085 - Simulation - DEBUG: Running the simulation 0.082s until 86.785s
# 2016-11-21 13:56:02,070 - P46085 - Simulation - DEBUG: Running the simulation 0.031s until 86.816s
# 2016-11-21 13:56:02,428 - P46085 - Simulation - DEBUG: Running the simulation 0.089s until 86.905s
# 2016-11-21 13:56:03,278 - P46085 - Simulation - DEBUG: Running the simulation 0.44s until 87.345s
# 2016-11-21 13:56:07,597 - P46085 - Simulation - DEBUG: Running the simulation 0.036s until 87.381s
# 2016-11-21 13:56:07,940 - P46085 - Simulation - DEBUG: Running the simulation 0.276s until 87.657s
# 2016-11-21 13:56:10,488 - P46085 - Simulation - DEBUG: Running the simulation 0.421s until 88.078s
# 2016-11-21 13:56:15,647 - P46085 - Simulation - DEBUG: Running the simulation 1.004s until 89.082s
# 2016-11-21 13:56:27,232 - P46085 - Simulation - DEBUG: Running the simulation 0.02s until 89.102s
# 2016-11-21 13:56:27,491 - P46085 - Simulation - DEBUG: Running the simulation 0.009s until 89.111s
# 2016-11-21 13:56:27,633 - P46085 - Simulation - DEBUG: Running the simulation 0.075s until 89.186s
# 2016-11-21 13:56:28,760 - P46085 - Simulation - DEBUG: Running the simulation 0.49s until 89.676s
# 2016-11-21 13:56:33,566 - P46085 - Simulation - DEBUG: Running the simulation 0.262s until 89.938s
# 2016-11-21 13:56:35,927 - P46085 - Simulation - DEBUG: Running the simulation 0.156s until 90.094s
# 2016-11-21 13:56:38,062 - P46085 - Simulation - DEBUG: Running the simulation 0.091s until 90.185s
# 2016-11-21 13:56:39,288 - P46085 - Simulation - DEBUG: Running the simulation 0.202s until 90.387s
# 2016-11-21 13:56:41,914 - P46085 - Simulation - DEBUG: Running the simulation 0.088s until 90.475s
# 2016-11-21 13:56:43,041 - P46085 - Simulation - DEBUG: Running the simulation 0.37s until 90.845s
# 2016-11-21 13:56:48,045 - P46085 - Simulation - DEBUG: Running the simulation 0.105s until 90.95s
# 2016-11-21 13:56:49,521 - P46085 - Simulation - DEBUG: Running the simulation 1.178s until 92.128s
# 2016-11-21 13:57:02,471 - P46085 - Simulation - DEBUG: Running the simulation 0.925s until 93.053s
# 2016-11-21 13:57:15,597 - P46085 - Simulation - DEBUG: Running the simulation 0.104s until 93.157s
# 2016-11-21 13:57:17,007 - P46085 - Simulation - DEBUG: Running the simulation 0.304s until 93.461s
# 2016-11-21 13:57:21,445 - P46085 - Simulation - DEBUG: Running the simulation 0.303s until 93.764s
# 2016-11-21 13:57:25,235 - P46085 - Simulation - DEBUG: Running the simulation 0.629s until 94.393s
# 2016-11-21 13:57:31,293 - P46085 - Simulation - DEBUG: Running the simulation 0.421s until 94.814s
# 2016-11-21 13:57:37,472 - P46085 - Simulation - DEBUG: Running the simulation 0.093s until 94.907s
# 2016-11-21 13:57:38,881 - P46085 - Simulation - DEBUG: Running the simulation 0.198s until 95.105s
# 2016-11-21 13:57:41,926 - P46085 - Simulation - DEBUG: Running the simulation 0.072s until 95.177s
# 2016-11-21 13:57:43,127 - P46085 - Simulation - DEBUG: Running the simulation 0.19s until 95.367s
# 2016-11-21 13:57:45,791 - P46085 - Simulation - DEBUG: Running the simulation 0.337s until 95.704s
# 2016-11-21 13:57:50,655 - P46085 - Simulation - DEBUG: Running the simulation 0.063s until 95.767s
# 2016-11-21 13:57:51,459 - P46085 - Simulation - DEBUG: Running the simulation 0.243s until 96.01s
# 2016-11-21 13:57:53,716 - P46085 - Simulation - DEBUG: Running the simulation 0.383s until 96.393s
# 2016-11-21 13:57:57,329 - P46085 - Simulation - DEBUG: Running the simulation 0.388s until 96.781s
# 2016-11-21 13:58:02,881 - P46085 - Simulation - DEBUG: Running the simulation 0.052s until 96.833s
# 2016-11-21 13:58:03,690 - P46085 - Simulation - DEBUG: Running the simulation 0.027s until 96.86s
# 2016-11-21 13:58:04,043 - P46085 - Simulation - DEBUG: Running the simulation 0.366s until 97.226s
# 2016-11-21 13:58:09,380 - P46085 - Simulation - DEBUG: Running the simulation 0.11s until 97.336s
# 2016-11-21 13:58:10,985 - P46085 - Simulation - DEBUG: Running the simulation 0.369s until 97.705s
# 2016-11-21 13:58:16,156 - P46085 - Simulation - DEBUG: Running the simulation 0.028s until 97.733s
# 2016-11-21 13:58:16,586 - P46085 - Simulation - DEBUG: Running the simulation 0.179s until 97.912s
# 2016-11-21 13:58:19,202 - P46085 - Simulation - DEBUG: Running the simulation 0.407s until 98.319s
# 2016-11-21 13:58:23,739 - P46085 - Simulation - DEBUG: Running the simulation 0.154s until 98.473s
# 2016-11-21 13:58:25,118 - P46085 - Simulation - DEBUG: Running the simulation 0.632s until 99.105s
# 2016-11-21 13:58:32,128 - P46085 - Simulation - DEBUG: Running the simulation 0.337s until 99.442s
# 2016-11-21 13:58:37,185 - P46085 - Simulation - DEBUG: Running the simulation 0.053s until 99.495s
# 2016-11-21 13:58:37,983 - P46085 - Simulation - DEBUG: Running the simulation 0.061s until 99.556s
# 2016-11-21 13:58:38,918 - P46085 - Simulation - DEBUG: Running the simulation 0.444s until 100.0s

# %% [markdown]
# Save the network state after the simulation

# %%
#simulation.cerebellum.update_network_weights()
#simulation.cerebellum.save_network()

# %% [markdown]
# ## GrC activity analysis

# %% [markdown]
# Calculate the average firing frequency of each granular cells during the ending 100 seconds

# %%
gtime,gcell_id = simulation.cerebellum.get_spike_activity(neuron_layer = 'grclayer',
                                                          init_time = simulation.current_time-200.0, 
                                                          end_time = simulation.current_time)
import numpy
firing_frequency = numpy.bincount(gcell_id) / (simulation_time*8.0)
# %matplotlib inline
import matplotlib.pyplot as plt
plt.hist(firing_frequency, bins=20)
plt.ylabel('Number of GrC cells')
plt.xlabel('Av. Spikes per Oscillatory Cycle')

# %% [markdown]
# Get the histogram of input synapses for the granular cells

# %%
target_cell_index = simulation.cerebellum.layer_map['mfgrcsynapsis'].target_index
cell_number = simulation.cerebellum.layer_map['grclayer'].number_of_neurons
number_of_inputs = numpy.bincount(target_cell_index)
plt.hist(number_of_inputs, bins=30)
plt.ylabel('Number of GrC cells')
plt.xlabel('Number of input synapses from glomeruli')

# %% [markdown]
# Plot the histogram of non-zero weights between MF and GrC

# %%
target_cell_index = simulation.cerebellum.layer_map['mfgrcsynapsis'].target_index
source_cell_index = simulation.cerebellum.layer_map['mfgrcsynapsis'].source_index
weight = simulation.cerebellum.layer_map['mfgrcsynapsis'].weights
plt.figure()
plt.hist(weight, bins=20)
plt.ylabel('Synaptic Weight')
plt.xlabel('Number of MF-GrC synapses')
max_weight = numpy.max(weight)
active_synapses = weight>max_weight*0.2
number_of_active_inputs = numpy.bincount(target_cell_index[active_synapses])
plt.figure()
plt.hist(number_of_active_inputs, bins=10)
plt.ylabel('Number of GrC cells')
plt.xlabel('Number of active inputs')
print 'Number of active synapses MF-GrC:',numpy.count_nonzero(active_synapses)
# Out:
# Number of active synapses MF-GrC: 80133

# %% [markdown]
# Histogram of active synapses connecting input fibers included in the pattern

# %%
for pat_id in range(simulation.pattern_generator.number_of_patterns):
    included_in_pattern = numpy.in1d(source_cell_index, simulation.pattern_generator.fibers_in_pattern[pat_id,:])
    included_and_active = numpy.logical_and(included_in_pattern,active_synapses)
    number_of_active_inputs_in_pattern = numpy.bincount(target_cell_index[included_and_active])
    plt.figure()
    plt.hist(number_of_active_inputs_in_pattern, bins=10)
    plt.ylabel('Number of GrC cells')
    plt.xlabel('Number of active inputs in pattern')
    print 'Number of active MF-GrC synapses also included in pattern',pat_id,':', numpy.count_nonzero(included_and_active)
    plt.figure()
    simulation.pattern_generator.fibers_in_pattern[0,:]
    activation_level = [simulation.pattern_generator.pattern_activation[pat_id,numpy.where(simulation.pattern_generator.fibers_in_pattern[pat_id,:]==source)[0][0]] 
                    for source in source_cell_index[included_and_active]]
    plt.hist(activation_level, bins=20)
    plt.ylabel('Number of active synapses')
    plt.xlabel('Activation level')
# Out:
# Number of active MF-GrC synapses also included in pattern 0 : 15714
# Number of active MF-GrC synapses also included in pattern 1 : 15663
# Number of active MF-GrC synapses also included in pattern 2 : 15322
# Number of active MF-GrC synapses also included in pattern 3 : 15611

# %% [markdown]
# Define some auxiliar functions:

# %%
def calc_Ind_Pattern_Hit_Matrix(cell_firing, pattern_present):
    '''
    Calculate the correct rejection, hit, miss and false alarm matrisses with 1 line for each cell and 1 column for each pattern (including noise).
    @param cell_firing Boolean matrix including 1 line for each cell and 1 column for each time bin.
    @param pattern_present Boolean matrix including 1 line for each pattern and 1 column for each time bin.
    '''
    hit_matrix = numpy.empty((len(pattern_present),len(cell_firing)))
    cr_matrix = numpy.empty((len(pattern_present),len(cell_firing)))
    miss_matrix = numpy.empty((len(pattern_present),len(cell_firing)))
    fa_matrix = numpy.empty((len(pattern_present),len(cell_firing)))
    faa_matrix = numpy.empty((len(cell_firing)))
    
    for index_pat, pattern in enumerate(pattern_present):
        if (numpy.count_nonzero(pattern)):
            for index_cell, firing in enumerate(cell_firing):
                hit_matrix[index_pat,index_cell] = numpy.count_nonzero(firing&pattern)/float(numpy.count_nonzero(pattern))
                cr_matrix[index_pat,index_cell] = numpy.count_nonzero(~firing&~pattern)/float(numpy.count_nonzero(~pattern))
                miss_matrix[index_pat,index_cell] = numpy.count_nonzero(~firing&pattern)/float(numpy.count_nonzero(pattern))
                fa_matrix[index_pat,index_cell] = numpy.count_nonzero(firing&~pattern)/float(numpy.count_nonzero(~pattern))
        else:
            print 'Pattern',index_pat,'never occurs. Statistics will not be calculated'
               
    any_pattern = numpy.any(pattern_present, axis=0)
    for index_cell, firing in enumerate(cell_firing):
        faa_matrix[index_cell] = numpy.count_nonzero(firing&~any_pattern)/float(numpy.count_nonzero(~any_pattern))
        
    return cr_matrix, hit_matrix, miss_matrix, fa_matrix, faa_matrix

def analyze_activity(layer, window_length, time_bin):

    cell_index = range(simulation.cerebellum.get_number_of_elements(layer=layer))
    pattern_generator = simulation.pattern_generator
    inv_time_bin = 1./time_bin

    # Generate the time bin matrix
    total_time = pattern_generator.simulation_time
    bin_time_init = numpy.linspace(0.0, window_length-time_bin, num=window_length*inv_time_bin)
    bin_time_end = numpy.linspace(time_bin,window_length,num=window_length*inv_time_bin)

    # Initialize a matrix
    pattern_index = range(0,pattern_generator.number_of_patterns)
    num_patterns = len(pattern_index)
    num_bins = len(bin_time_init)
    num_cells = len(cell_index)

    # Calculate the time of each pattern interval
    time_end_of_pattern = pattern_generator.pattern_length_cum
    time_init_of_pattern = numpy.append([0.0],time_end_of_pattern[:-1])

    # Calculate the bin of each pattern interval. Check the round of the last bin to avoid out of range
    bin_end_of_pattern = numpy.floor(time_end_of_pattern * inv_time_bin).astype(int)
    if (bin_end_of_pattern[-1]>=num_bins):
        bin_end_of_pattern[-1]=num_bins-1
    bin_init_of_pattern = numpy.append([0],bin_end_of_pattern[:-1])
    if (bin_init_of_pattern[-1]>=num_bins):
        bin_init_of_pattern[-1]=num_bins-1

    # Final matrix indicating which bins are considered of each pattern
    bin_is_pattern = numpy.empty((num_patterns, num_bins),dtype='bool')
    bin_is_pattern[:,:] = False
    bin_pattern = numpy.zeros(num_bins)

    # Final matrix indicating which bins are registered spikes
    bin_has_fired = numpy.empty((num_cells, num_bins), dtype='bool')
    bin_has_fired[:,:] = False

    for key, value in enumerate(pattern_index):
        time_of_pattern_in_bin = numpy.zeros(num_bins)
        for index in pattern_generator.pattern_id_index[value]:
            init_bin = bin_init_of_pattern[index]
            end_bin = bin_end_of_pattern[index]

            list_of_bins = range(init_bin,end_bin+1)

            # Add the time of the initial bin (if exists)
            if init_bin!=end_bin:
                time_of_pattern_in_bin[list_of_bins[0]] += (bin_time_end[init_bin] - time_init_of_pattern[index])

            # Add the time of the intermediate bins (if exist)
            time_of_pattern_in_bin[list_of_bins[1:-1]] += time_bin

            # Add the time of the final bin
            time_of_pattern_in_bin[list_of_bins[-1]] += (time_end_of_pattern[index] - max(time_init_of_pattern[index],bin_time_init[end_bin]))

        # Those bins where the time in the pattern is longer than half of the bin are set to part of that pattern    
        bin_is_pattern[key,time_of_pattern_in_bin>(time_bin/2.)] = True
        bin_pattern[bin_is_pattern[key,:]] = bin_pattern[bin_is_pattern[key,:]] + 2**value

    # Create a map of cells to index
    cell_map = dict()
    for key, value in enumerate(cell_index):
        cell_map[value] = key

    # Load data from the data provider
    gtime,gcell_id = simulation.cerebellum.get_spike_activity(neuron_layer = layer, init_time = 0.0, end_time = window_length)


    spike_bin_index = numpy.floor(gtime*inv_time_bin).astype(int)

    av_firing_rate = float(len(gtime))/(len(cell_index)*(window_length))
    print 'Average firing rate in MI analysis:',av_firing_rate,'Hz'

    cell_index = numpy.array([cell_map[value] for value in gcell_id])

    # Final matrix indicating which bins are registered spikes
    if len(spike_bin_index) and len(cell_index):
        bin_has_fired[cell_index,spike_bin_index] = True

    # Calculate mutual information in the time window
    init_bin = int(0 * inv_time_bin)
    end_bin = int(window_length * inv_time_bin)


    # Calculate hit matrix for each pattern
    cr_matrix, hit_matrix, miss_matrix, fa_matrix, faa_matrix = calc_Ind_Pattern_Hit_Matrix(bin_has_fired[:,init_bin:end_bin], bin_is_pattern[:,init_bin:end_bin])

    return cr_matrix, hit_matrix, miss_matrix, fa_matrix, faa_matrix

# %% [markdown]
# Represent the hit rate matrix of each GrC to each pattern

# %%
layer = 'grclayer'
window_length = simulation.config_options['hit_analysis']['window_length'] = 200.0
time_bin = simulation.config_options['hit_analysis']['time_bin'] = 0.125

cr_matrix, hit_matrix, miss_matrix, fa_matrix, faa_matrix = analyze_activity(layer, window_length, time_bin)

#numpy.set_printoptions(threshold=numpy.nan)
#print 'Individual pattern hit matrix:'
#print hit_matrix
#print 'Individual pattern correct rejection matrix:'
#print cr_matrix
#print 'Individual pattern miss matrix:'
#print miss_matrix
#print 'Individual pattern false alarm matrix:'
#print fa_matrix
#print 'All patterns false alarm array:'
#print faa_matrix

extended_hit = numpy.append(hit_matrix, [faa_matrix], axis=0)
selected_pattern = numpy.argmax(extended_hit, axis=0)
plt.figure()
plt.hist(selected_pattern, bins=simulation.pattern_generator.number_of_patterns+1)
plt.ylabel('Count GrCs')
plt.xlabel('Favourite pattern')
cell_sorted = numpy.argsort(selected_pattern)
plt.figure()
plt.matshow(extended_hit[:,cell_sorted], extent=[0,simulation.cerebellum.get_number_of_elements(layer=layer),
                                                 simulation.pattern_generator.number_of_patterns+1,0], 
            vmin=0, vmax=1.0, aspect='auto')
plt.ylabel('Pattern')
plt.xlabel('GrC neuron')
plt.colorbar()
# Out:
# Average firing rate in MI analysis: 3.18621125 Hz

# %% [markdown]
# Estimate the goodness of the matrix

# %%
extended_hit = numpy.append(hit_matrix, [faa_matrix], axis=0)
selected_pattern = numpy.argmax(extended_hit, axis=0)

# Select those cells mainly responding to one of the patterns
ind = numpy.where(selected_pattern<simulation.pattern_generator.number_of_patterns)

diagonal = hit_matrix[selected_pattern[ind],ind]

# Create a new matrix setting the diagonal values to zero
zero_matrix = hit_matrix
zero_matrix[selected_pattern[ind],ind] = 0.0

# Calculate the average of the diagonal elements
av_selected = numpy.average(diagonal)
av_nonselected = numpy.sum(zero_matrix[:])/(simulation.cerebellum.get_number_of_elements(layer=layer)*(simulation.pattern_generator.number_of_patterns-1))
print 'Average hits of selected elements:',av_selected
print 'Average hits of non-selected elements:',av_nonselected
hit_index = av_selected - av_nonselected
print 'Hit index:',hit_index
# Out:
# Average hits of selected elements: 0.432856946885
# Average hits of non-selected elements: 0.35998706348
# Hit index: 0.0728698834048

# %% [markdown]
# ## GoC activity analysis

# %% [markdown]
# Calculate the average firing frequency of each Golgi cells during the ending 100 seconds

# %%
gtime,gcell_id = simulation.cerebellum.get_spike_activity(neuron_layer = 'goclayer',
                                                          init_time = simulation.current_time-200.0, 
                                                          end_time = simulation.current_time)
import numpy
firing_frequency = numpy.bincount(gcell_id) / (simulation_time*8.0)
# %matplotlib inline
import matplotlib.pyplot as plt
plt.hist(firing_frequency, bins=20)
plt.ylabel('Number of GoC cells')
plt.xlabel('Av. Spikes per Oscillatory Cycle')

# %% [markdown]
# Get the histogram of input synapses for the Golgi cells

# %%
target_cell_index = simulation.cerebellum.layer_map['mfgocsynapsis'].target_index
cell_number = simulation.cerebellum.layer_map['goclayer'].number_of_neurons
number_of_inputs = numpy.bincount(target_cell_index)
plt.hist(number_of_inputs, bins=30)
plt.ylabel('Number of GoC cells')
plt.xlabel('Number of input synapses from glomeruli')

# %% [markdown]
# Plot the histogram of non-zero weights between MF and GoC

# %%
target_cell_index = simulation.cerebellum.layer_map['mfgocsynapsis'].target_index
source_cell_index = simulation.cerebellum.layer_map['mfgocsynapsis'].source_index
weight = simulation.cerebellum.layer_map['mfgocsynapsis'].weights
plt.figure()
plt.hist(weight, bins=20)
plt.ylabel('Synaptic Weight')
plt.xlabel('Number of MF-GoC synapses')
max_weight = numpy.max(weight)
active_synapses = weight>max_weight*0.2
number_of_active_inputs = numpy.bincount(target_cell_index[active_synapses])
plt.figure()
plt.hist(number_of_active_inputs, bins=10)
plt.ylabel('Number of GoC cells')
plt.xlabel('Number of active inputs')
print 'Number of active synapses MF-GoC:',numpy.count_nonzero(active_synapses)
# Out:
# Number of active synapses MF-GoC: 1941

# %% [markdown]
# Histogram of active synapses connecting input fibers included in the pattern

# %%
for pat_id in range(simulation.pattern_generator.number_of_patterns):
    included_in_pattern = numpy.in1d(source_cell_index, simulation.pattern_generator.fibers_in_pattern[pat_id,:])
    included_and_active = numpy.logical_and(included_in_pattern,active_synapses)
    number_of_active_inputs_in_pattern = numpy.bincount(target_cell_index[included_and_active])
    plt.figure()
    plt.hist(number_of_active_inputs_in_pattern, bins=10)
    plt.ylabel('Number of GoC cells')
    plt.xlabel('Number of active inputs in pattern')
    print 'Number of active MF-GoC synapses also included in pattern',pat_id,':', numpy.count_nonzero(included_and_active)
    plt.figure()
    simulation.pattern_generator.fibers_in_pattern[0,:]
    activation_level = [simulation.pattern_generator.pattern_activation[pat_id,numpy.where(simulation.pattern_generator.fibers_in_pattern[pat_id,:]==source)[0][0]] 
                    for source in source_cell_index[included_and_active]]
    plt.hist(activation_level, bins=20)
    plt.ylabel('Number of active synapses')
    plt.xlabel('Activation level')
# Out:
# Number of active MF-GoC synapses also included in pattern 0 : 398
# Number of active MF-GoC synapses also included in pattern 1 : 387
# Number of active MF-GoC synapses also included in pattern 2 : 365
# Number of active MF-GoC synapses also included in pattern 3 : 368

# %% [markdown]
# Represent the hit rate matrix of each GoC to each pattern

# %%
layer = 'goclayer'
window_length = simulation.config_options['hit_analysis']['window_length'] = 200.0
time_bin = simulation.config_options['hit_analysis']['time_bin'] = 0.125

cr_matrix, hit_matrix, miss_matrix, fa_matrix, faa_matrix = analyze_activity(layer, window_length, time_bin)

#numpy.set_printoptions(threshold=numpy.nan)
#print 'Individual pattern hit matrix:'
#print hit_matrix
#print 'Individual pattern correct rejection matrix:'
#print cr_matrix
#print 'Individual pattern miss matrix:'
#print miss_matrix
#print 'Individual pattern false alarm matrix:'
#print fa_matrix
#print 'All patterns false alarm array:'
#print faa_matrix

extended_hit = numpy.append(hit_matrix, [faa_matrix], axis=0)
selected_pattern = numpy.argmax(extended_hit, axis=0)
plt.figure()
plt.hist(selected_pattern, bins=simulation.pattern_generator.number_of_patterns+1)
plt.ylabel('Count GoCs')
plt.xlabel('Favourite pattern')
cell_sorted = numpy.argsort(selected_pattern)
plt.figure()
plt.matshow(extended_hit[:,cell_sorted], extent=[0,simulation.cerebellum.get_number_of_elements(layer=layer),0,simulation.pattern_generator.number_of_patterns+1], vmin=0, vmax=1.0, aspect='auto')
plt.ylabel('Pattern')
plt.xlabel('GoC neuron')
plt.colorbar()
# Out:
# Average firing rate in MI analysis: 8.25833333333 Hz

# %% [markdown]
# Estimate the goodness of the matrix

# %%
extended_hit = numpy.append(hit_matrix, [faa_matrix], axis=0)
selected_pattern = numpy.argmax(extended_hit, axis=0)

# Select those cells mainly responding to one of the patterns
ind = numpy.where(selected_pattern<simulation.pattern_generator.number_of_patterns)

diagonal = hit_matrix[selected_pattern[ind],ind]

# Create a new matrix setting the diagonal values to zero
zero_matrix = hit_matrix
zero_matrix[selected_pattern[ind],ind] = 0.0

# Calculate the average of the diagonal elements
av_selected = numpy.average(diagonal)
av_nonselected = numpy.sum(zero_matrix[:])/(simulation.cerebellum.get_number_of_elements(layer=layer)*(simulation.pattern_generator.number_of_patterns-1))
print 'Average hits of selected elements:',av_selected
print 'Average hits of non-selected elements:',av_nonselected
hit_index = av_selected - av_nonselected
print 'Hit index:',hit_index
# Out:
# Average hits of selected elements: 0.998758515752
# Average hits of non-selected elements: 0.99800653015
# Hit index: 0.000751985601994

# %% [markdown]
# ## PC activity analysis

# %% [markdown]
# Histogram of active synapses GrC-PC

# %%
target_cell_index = simulation.cerebellum.layer_map['grcpcsynapsis'].target_index
source_cell_index = simulation.cerebellum.layer_map['grcpcsynapsis'].source_index
weight = simulation.cerebellum.layer_map['grcpcsynapsis'].weights
plt.figure()
plt.hist(weight, bins=20)
plt.ylabel('Number of GrC-PC synapses')
plt.xlabel('Synaptic Weight')
max_weight = numpy.max(weight)
active_synapses = weight>max_weight*0.2
number_of_active_inputs = numpy.bincount(target_cell_index[active_synapses])
plt.figure()
plt.hist(number_of_active_inputs, bins=10)
plt.ylabel('Number of PC cells')
plt.xlabel('Number of active inputs')
print 'Number of active synapses GrC-PC:',numpy.count_nonzero(active_synapses)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-173f00ce56f7> in <module>()
# ----> 1 target_cell_index = simulation.cerebellum.layer_map['grcpcsynapsis'].target_index
#       2 source_cell_index = simulation.cerebellum.layer_map['grcpcsynapsis'].source_index
#       3 weight = simulation.cerebellum.layer_map['grcpcsynapsis'].weights
#       4 plt.figure()
#       5 plt.hist(weight, bins=20)
#
# KeyError: 'grcpcsynapsis'
