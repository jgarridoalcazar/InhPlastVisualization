# %% [markdown]
# # Data anaylsis in cerebellar granular layer simulations
# ## Running the simulation
#
# First, we set current working directory to the root of Spiking Granular Layer and insert the source folder to the python path:

# %%
import os
os.chdir('../../')
os.getcwd()
import sys
import numpy
# %matplotlib inline
import matplotlib.pyplot as plt
sys.path.insert(1,'./src')

# %% [markdown]
# Now start setting a new simulation with the configuration file that we specify:

# %%
config_file = './config/GoCGrC/SimulationConfigAll.cfg'
simulation_time = 500.0
import SpikingSimulation.FrequencySimulation as FrequencySimulation
simulation = FrequencySimulation.FrequencySimulation(config_file=config_file)

# %% [markdown]
# Initialize the simulation

# %%
simulation.config_options['simulation']['verbosity'] = 'Debug'
simulation.config_options['simulation']['seed'] = 12345
simulation.config_options['simulation']['time'] = simulation_time
simulation.config_options['simulation']['register_activity_only_in_test'] = False
simulation.config_options['network']['load_file'] = './results/GoCGrC/network01_20mf_after_all_learning.h5'
simulation.config_options['network']['save_file'] = None
simulation.config_options['stimulation']['load_pattern_file'] = './results/GoCGrC/stimulation_all.h5'
simulation.config_options['stimulation']['save_pattern_file'] = None
simulation.config_options['grclayer']['register_activity'] = True
simulation.config_options['goclayer']['register_activity'] = True
simulation.config_options['grclayer']['load_state_vars'] = 'Vth'
simulation.config_options['goclayer']['load_state_vars'] = 'Vth'
simulation.initialize()
# Out:
# 2016-12-24 01:06:35,902 - P5989 - MemTotal:62M - Simulation - DEBUG: Simulation time fixed to 500.0s
# 2016-12-24 01:06:35,922 - P5989 - MemTotal:62M - Simulation - DEBUG: Creating cerebellum generator
# 2016-12-24 01:06:36,031 - P5989 - MemTotal:73M - Simulation - DEBUG: Initializing cerebellum generator
# 2016-12-24 01:06:36,032 - P5989 - MemTotal:73M - Simulation - DEBUG: Cerebellar simulation initialized
# 2016-12-24 01:06:36,043 - P5989 - MemTotal:74M - Simulation - DEBUG: NEST module loaded
# 2016-12-24 01:06:36,055 - P5989 - MemTotal:78M - Simulation - DEBUG: Setting Global NEST Seed: 12356
# 2016-12-24 01:06:36,056 - P5989 - MemTotal:78M - Simulation - DEBUG: Setting Per-Process NEST Seeds: [12357, 12358, 12359, 12360, 12361, 12362, 12363, 12364, 12365, 12366]
# 2016-12-24 01:06:36,129 - P5989 - MemTotal:83M - Simulation - WARNING: Non-specified cell model parameter: tau_minus in layer mflayer. Using default value
# 2016-12-24 01:06:36,131 - P5989 - MemTotal:83M - Simulation - WARNING: Non-specified number of neurons in layer mflayer
# 2016-12-24 01:06:36,134 - P5989 - MemTotal:84M - Simulation - WARNING: Non-specified number of neurons in layer grclayer
# 2016-12-24 01:06:36,138 - P5989 - MemTotal:84M - Simulation - WARNING: Non-specified number of neurons in layer goclayer
# 2016-12-24 01:06:36,142 - P5989 - MemTotal:84M - Simulation - WARNING: tau_minus cannot be calculated in layer mflayer. Variable tau_minus is not defined. Using default value 20.0
# 2016-12-24 01:06:36,143 - P5989 - MemTotal:84M - Simulation - WARNING: tau_minus_triplet cannot be calculated in layer mflayer. Variable tau_istdp is not defined. Using default value 110.0
# 2016-12-24 01:06:36,150 - P5989 - MemTotal:89M - Simulation - DEBUG: Nest Process: 0. Neuron layer created in layer mflayer: 300. Local: 300
# 2016-12-24 01:06:36,246 - P5989 - MemTotal:125M - Simulation - DEBUG: Nest Process: 0. Neuron layer created in layer grclayer: 4000. Local: 4000
# 2016-12-24 01:06:36,249 - P5989 - MemTotal:126M - Simulation - DEBUG: Nest Process: 0. Neuron layer created in layer goclayer: 9. Local: 9
# /Users/jgarrido/NEST/nest210/ins_nompi/lib/python2.7/site-packages/nest/lib/hl_api_helper.py:61: UserWarning:
# OneToOneConnect is deprecated and will be removed in a future version of NEST.
# Please use Connect instead!
# For details, see http://www.nest-simulator.org/connection_management
# 2016-12-24 01:06:39,102 - P5989 - MemTotal:145M - Simulation - DEBUG: Nest Process: 0. Connections created in layer mfgrcsynapsis: 80133
# 2016-12-24 01:06:39,169 - P5989 - MemTotal:145M - Simulation - DEBUG: Nest Process: 0. Connections created in layer mfgocsynapsis: 1941
# 2016-12-24 01:06:40,340 - P5989 - MemTotal:146M - Simulation - DEBUG: Nest Process: 0. Connections created in layer grcgocsynapsis: 35917
# 2016-12-24 01:06:40,826 - P5989 - MemTotal:148M - Simulation - DEBUG: Nest Process: 0. Connections created in layer gocgrcsynapsis: 14877
# 2016-12-24 01:06:40,831 - P5989 - MemTotal:148M - Simulation - DEBUG: Nest Process: 0. Connections created in layer gocgocsynapsis: 81
# 2016-12-24 01:06:42,643 - P5989 - MemTotal:197M - Simulation - DEBUG: Creating AC Current generator
# 2016-12-24 01:06:42,645 - P5989 - MemTotal:198M - Simulation - DEBUG: Creating DC Current generator
# 2016-12-24 01:06:42,671 - P5989 - MemTotal:198M - Simulation - INFO: Loading activation patterns from hdf5 file ./results/GoCGrC/stimulation_all.h5
# 2016-12-24 01:06:42,674 - P5989 - MemTotal:198M - Simulation - DEBUG: Loading stimulation pattern 0
# 2016-12-24 01:06:42,675 - P5989 - MemTotal:198M - Simulation - DEBUG: Loading stimulation pattern 1
# 2016-12-24 01:06:42,677 - P5989 - MemTotal:198M - Simulation - DEBUG: Loading stimulation pattern 2
# 2016-12-24 01:06:42,679 - P5989 - MemTotal:198M - Simulation - DEBUG: Loading stimulation pattern 3
# 2016-12-24 01:06:42,681 - P5989 - MemTotal:198M - Simulation - DEBUG: File reading ended
# 2016-12-24 01:06:42,699 - P5989 - MemTotal:207M - Simulation - DEBUG: Pattern 0 and 1 share 14 input cells: [ 21  23  57 117 124 129 130 170 177 203 212 218 257 267]
# 2016-12-24 01:06:42,701 - P5989 - MemTotal:207M - Simulation - DEBUG: Activation level of pattern 0 in shared cells: [ 0.34068122  0.8303853   0.38571678  0.89137674  0.12763536  0.83570461
#   0.1410593   0.3326859   0.0674158   0.60151048  0.2998598   0.33836937
#   0.85379178  0.71448165]
# 2016-12-24 01:06:42,703 - P5989 - MemTotal:207M - Simulation - DEBUG: Activation level of pattern 1 in shared cells: [ 0.34008524  0.82893265  0.38504202  0.88981739  0.12741208  0.83424265
#   0.14081253  0.33210391  0.06729787  0.60045822  0.29933524  0.33777744
#   0.85229818  0.71323176]
# 2016-12-24 01:06:42,705 - P5989 - MemTotal:207M - Simulation - DEBUG: Pattern 0 and 2 share 10 input cells: [ 23  29  84  95 139 145 162 196 257 292]
# 2016-12-24 01:06:42,707 - P5989 - MemTotal:207M - Simulation - DEBUG: Activation level of pattern 0 in shared cells: [ 0.8303853   0.15504614  0.86694866  0.28622573  0.75400601  0.23101361
#   0.17337945  0.31420051  0.85379178  0.11217031]
# 2016-12-24 01:06:42,709 - P5989 - MemTotal:207M - Simulation - DEBUG: Activation level of pattern 2 in shared cells: [ 0.63866165  0.23106996  0.21157761  0.16828267  0.75512947  0.79871826
#   0.95792019  0.59242694  0.86388809  0.9057407 ]
# 2016-12-24 01:06:42,711 - P5989 - MemTotal:207M - Simulation - DEBUG: Pattern 0 and 3 share 10 input cells: [ 21  29  38  48 120 130 170 212 259 296]
# 2016-12-24 01:06:42,713 - P5989 - MemTotal:207M - Simulation - DEBUG: Activation level of pattern 0 in shared cells: [ 0.34068122  0.15504614  0.00417051  0.67977813  0.8261344   0.1410593
#   0.3326859   0.2998598   0.85811197  0.66930593]
# 2016-12-24 01:06:42,715 - P5989 - MemTotal:207M - Simulation - DEBUG: Activation level of pattern 3 in shared cells: [ 0.73399331  0.23477455  0.1485904   0.52735329  0.94058318  0.4615828
#   0.31697336  0.92400491  0.63483266  0.16727316]
# 2016-12-24 01:06:42,716 - P5989 - MemTotal:207M - Simulation - DEBUG: Pattern 1 and 2 share 13 input cells: [  6  23  27  34  52  69 153 209 237 257 258 283 287]
# 2016-12-24 01:06:42,718 - P5989 - MemTotal:207M - Simulation - DEBUG: Activation level of pattern 1 in shared cells: [ 0.57515863  0.82893265  0.48411497  0.77599409  0.60775252  0.5900738
#   0.19453639  0.87536028  0.61477839  0.85229818  0.28079927  0.38065906
#   0.72925231]
# 2016-12-24 01:06:42,720 - P5989 - MemTotal:207M - Simulation - DEBUG: Activation level of pattern 2 in shared cells: [ 0.71545825  0.63866165  0.87591556  0.78527197  0.78769922  0.04754665
#   0.61024484  0.17357738  0.09030359  0.86388809  0.28805784  0.66386081
#   0.96281043]
# 2016-12-24 01:06:42,722 - P5989 - MemTotal:207M - Simulation - DEBUG: Pattern 1 and 3 share 12 input cells: [  6  11  21  35  52  64  68  86 130 170 212 247]
# 2016-12-24 01:06:42,723 - P5989 - MemTotal:207M - Simulation - DEBUG: Activation level of pattern 1 in shared cells: [ 0.57515863  0.46170998  0.34008524  0.44914965  0.60775252  0.24991998
#   1.          0.08749615  0.14081253  0.33210391  0.29933524  0.64729589]
# 2016-12-24 01:06:42,725 - P5989 - MemTotal:207M - Simulation - DEBUG: Activation level of pattern 3 in shared cells: [ 0.25866073  0.58721826  0.73399331  0.41465705  0.21334652  0.5906658
#   0.57394926  0.13198257  0.4615828   0.31697336  0.92400491  0.95313813]
# 2016-12-24 01:06:42,727 - P5989 - MemTotal:207M - Simulation - DEBUG: Pattern 2 and 3 share 8 input cells: [  6  22  29  52  78  89 178 225]
# 2016-12-24 01:06:42,728 - P5989 - MemTotal:207M - Simulation - DEBUG: Activation level of pattern 2 in shared cells: [ 0.71545825  0.00969128  0.23106996  0.78769922  0.03768267  0.62966879
#   0.31107603  0.68151606]
# 2016-12-24 01:06:42,730 - P5989 - MemTotal:207M - Simulation - DEBUG: Activation level of pattern 3 in shared cells: [ 0.25866073  0.05830739  0.23477455  0.21334652  0.2968108   0.84593961
#   0.01793736  0.92545484]
# 2016-12-24 01:06:42,876 - P5989 - MemTotal:235M - Simulation - DEBUG: Normalization on iteration 10
# 2016-12-24 01:06:42,878 - P5989 - MemTotal:235M - Simulation - DEBUG: Average sum per columns 150.042946685
# 2016-12-24 01:06:42,879 - P5989 - MemTotal:235M - Simulation - DEBUG: Average sum per rows 991.283734433

# %% [markdown]
# Visualize the simulation or only run it.

# %%
#simulation.visualize_animation()
simulation.run_simulation()
# Out:
# 2016-12-24 01:06:42,891 - P5989 - MemTotal:235M - Simulation - INFO: Running the simulation from 0.0s until time 500.0s
# 2016-12-24 01:06:42,896 - P5989 - MemTotal:237M - Simulation - DEBUG: Running the simulation 0.177s until 0.177s
# 2016-12-24 01:06:43,683 - P5989 - MemTotal:238M - Simulation - DEBUG: Simulation time is 0.784700155258 seconds. Real-time rate: 0.225563865145. Spike frequency: 2.3615819209
# 2016-12-24 01:06:43,687 - P5989 - MemTotal:238M - Simulation - DEBUG: Running the simulation 0.113s until 0.29s
# 2016-12-24 01:06:44,180 - P5989 - MemTotal:238M - Simulation - DEBUG: Simulation time is 0.490277051926 seconds. Real-time rate: 0.230481927629. Spike frequency: 2.78982300885
# 2016-12-24 01:06:44,184 - P5989 - MemTotal:238M - Simulation - DEBUG: Running the simulation 0.964s until 1.254s
# 2016-12-24 01:06:47,651 - P5989 - MemTotal:240M - Simulation - DEBUG: Simulation time is 3.46378302574 seconds. Real-time rate: 0.204978197169. Spike frequency: 4.37218309859
# 2016-12-24 01:06:50,259 - P5989 - MemTotal:248M - Simulation - DEBUG: Simulation time is 1.246062994 seconds. Real-time rate: 0.20384202181. Spike frequency: 4.10531496063
# 2016-12-24 01:06:50,263 - P5989 - MemTotal:248M - Simulation - DEBUG: Running the simulation 0.38s until 1.634s
# 2016-12-24 01:06:52,159 - P5989 - MemTotal:248M - Simulation - DEBUG: Simulation time is 1.89318799973 seconds. Real-time rate: 0.200719632733. Spike frequency: 2.5125
# 2016-12-24 01:06:52,163 - P5989 - MemTotal:248M - Simulation - DEBUG: Running the simulation 0.076s until 1.71s
# 2016-12-24 01:06:52,551 - P5989 - MemTotal:244M - Simulation - DEBUG: Simulation time is 0.384624958038 seconds. Real-time rate: 0.197595081681. Spike frequency: 6.70394736842
# 2016-12-24 01:06:52,554 - P5989 - MemTotal:243M - Simulation - DEBUG: Running the simulation 0.125s until 1.835s
# 2016-12-24 01:06:53,169 - P5989 - MemTotal:239M - Simulation - DEBUG: Simulation time is 0.611523151398 seconds. Real-time rate: 0.20440763316. Spike frequency: 4.056
# 2016-12-24 01:06:53,174 - P5989 - MemTotal:239M - Simulation - DEBUG: Running the simulation 0.024s until 1.859s
# 2016-12-24 01:06:53,305 - P5989 - MemTotal:239M - Simulation - DEBUG: Simulation time is 0.128046989441 seconds. Real-time rate: 0.187431193071. Spike frequency: 0.0416666666667
# 2016-12-24 01:06:53,309 - P5989 - MemTotal:239M - Simulation - DEBUG: Running the simulation 0.021s until 1.88s
# 2016-12-24 01:06:53,418 - P5989 - MemTotal:239M - Simulation - DEBUG: Simulation time is 0.106487989426 seconds. Real-time rate: 0.197205338492. Spike frequency: 0.0
# 2016-12-24 01:06:53,423 - P5989 - MemTotal:239M - Simulation - DEBUG: Running the simulation 0.063s until 1.943s
# 2016-12-24 01:06:53,781 - P5989 - MemTotal:235M - Simulation - DEBUG: Simulation time is 0.354912042618 seconds. Real-time rate: 0.177508769596. Spike frequency: 5.65476190476
# 2016-12-24 01:06:53,785 - P5989 - MemTotal:235M - Simulation - DEBUG: Running the simulation 0.352s until 2.295s
# 2016-12-24 01:06:54,087 - P5989 - MemTotal:235M - Simulation - DEBUG: Simulation time is 0.299274921417 seconds. Real-time rate: 0.190460329018. Spike frequency: 0.574561403509
# 2016-12-24 01:06:57,381 - P5989 - MemTotal:234M - Simulation - DEBUG: Simulation time is 1.78757596016 seconds. Real-time rate: 0.16502795214. Spike frequency: 4.28559322034
# 2016-12-24 01:06:57,387 - P5989 - MemTotal:234M - Simulation - DEBUG: Running the simulation 0.04s until 2.335s
# 2016-12-24 01:06:57,677 - P5989 - MemTotal:228M - Simulation - DEBUG: Simulation time is 0.285089015961 seconds. Real-time rate: 0.14030705415. Spike frequency: 6.2625
# 2016-12-24 01:06:57,681 - P5989 - MemTotal:228M - Simulation - DEBUG: Running the simulation 0.793s until 3.128s
# 2016-12-24 01:07:02,132 - P5989 - MemTotal:228M - Simulation - DEBUG: Simulation time is 4.44680094719 seconds. Real-time rate: 0.149545708903. Spike frequency: 2.96578947368
# 2016-12-24 01:07:04,437 - P5989 - MemTotal:232M - Simulation - DEBUG: Simulation time is 0.694045782089 seconds. Real-time rate: 0.184425874061. Spike frequency: 2.818359375
# 2016-12-24 01:07:04,441 - P5989 - MemTotal:232M - Simulation - DEBUG: Running the simulation 0.393s until 3.521s
# 2016-12-24 01:07:06,694 - P5989 - MemTotal:233M - Simulation - DEBUG: Simulation time is 2.2496099472 seconds. Real-time rate: 0.174696951571. Spike frequency: 3.1641221374
# 2016-12-24 01:07:06,698 - P5989 - MemTotal:233M - Simulation - DEBUG: Running the simulation 0.102s until 3.623s
# 2016-12-24 01:07:07,305 - P5989 - MemTotal:233M - Simulation - DEBUG: Simulation time is 0.603918075562 seconds. Real-time rate: 0.168897080792. Spike frequency: 4.00245098039
# 2016-12-24 01:07:07,309 - P5989 - MemTotal:233M - Simulation - DEBUG: Running the simulation 0.122s until 3.745s
# 2016-12-24 01:07:08,124 - P5989 - MemTotal:233M - Simulation - DEBUG: Simulation time is 0.811753034592 seconds. Real-time rate: 0.150292015923. Spike frequency: 5.06967213115
# 2016-12-24 01:07:08,128 - P5989 - MemTotal:232M - Simulation - DEBUG: Running the simulation 0.084s until 3.829s
# 2016-12-24 01:07:08,679 - P5989 - MemTotal:232M - Simulation - DEBUG: Simulation time is 0.548346996307 seconds. Real-time rate: 0.153187672342. Spike frequency: 6.66666666667
# 2016-12-24 01:07:08,683 - P5989 - MemTotal:232M - Simulation - DEBUG: Running the simulation 0.552s until 4.381s
# 2016-12-24 01:07:09,653 - P5989 - MemTotal:232M - Simulation - DEBUG: Simulation time is 0.966413021088 seconds. Real-time rate: 0.176942980143. Spike frequency: 2.30994152047
# 2016-12-24 01:07:13,044 - P5989 - MemTotal:234M - Simulation - DEBUG: Simulation time is 2.04478192329 seconds. Real-time rate: 0.18632793828. Spike frequency: 2.86089238845
# 2016-12-24 01:07:13,050 - P5989 - MemTotal:233M - Simulation - DEBUG: Running the simulation 0.191s until 4.572s
# 2016-12-24 01:07:14,251 - P5989 - MemTotal:233M - Simulation - DEBUG: Simulation time is 1.19708514214 seconds. Real-time rate: 0.159554231589. Spike frequency: 4.91623036649
# 2016-12-24 01:07:14,255 - P5989 - MemTotal:233M - Simulation - DEBUG: Running the simulation 0.344s until 4.916s
# 2016-12-24 01:07:16,439 - P5989 - MemTotal:233M - Simulation - DEBUG: Simulation time is 2.17951202393 seconds. Real-time rate: 0.15783349494. Spike frequency: 2.0101744186
# 2016-12-24 01:07:16,447 - P5989 - MemTotal:233M - Simulation - DEBUG: Running the simulation 0.05s until 4.966s
# 2016-12-24 01:07:16,751 - P5989 - MemTotal:233M - Simulation - DEBUG: Simulation time is 0.29990196228 seconds. Real-time rate: 0.166721149871. Spike frequency: 2.635
# 2016-12-24 01:07:16,755 - P5989 - MemTotal:233M - Simulation - DEBUG: Running the simulation 0.007s until 4.973s
# 2016-12-24 01:07:16,799 - P5989 - MemTotal:233M - Simulation - DEBUG: Simulation time is 0.0412948131561 seconds. Real-time rate: 0.169512814443. Spike frequency: 0.0
# 2016-12-24 01:07:16,804 - P5989 - MemTotal:233M - Simulation - DEBUG: Running the simulation 0.321s until 5.294s
# 2016-12-24 01:07:16,974 - P5989 - MemTotal:233M - Simulation - DEBUG: Simulation time is 0.16698884964 seconds. Real-time rate: 0.161687442355. Spike frequency: 0.0
# 2016-12-24 01:07:20,264 - P5989 - MemTotal:232M - Simulation - DEBUG: Simulation time is 1.78805804253 seconds. Real-time rate: 0.16442419262. Spike frequency: 2.44897959184
# 2016-12-24 01:07:20,268 - P5989 - MemTotal:232M - Simulation - DEBUG: Running the simulation 0.087s until 5.381s
# 2016-12-24 01:07:20,816 - P5989 - MemTotal:232M - Simulation - DEBUG: Simulation time is 0.544182062149 seconds. Real-time rate: 0.159872965412. Spike frequency: 1.15517241379
# 2016-12-24 01:07:20,819 - P5989 - MemTotal:232M - Simulation - DEBUG: Running the simulation 0.139s until 5.52s
# 2016-12-24 01:07:21,546 - P5989 - MemTotal:233M - Simulation - DEBUG: Simulation time is 0.723418951035 seconds. Real-time rate: 0.1921431555. Spike frequency: 2.46582733813
# 2016-12-24 01:07:21,550 - P5989 - MemTotal:233M - Simulation - DEBUG: Running the simulation 0.122s until 5.642s
# 2016-12-24 01:07:22,189 - P5989 - MemTotal:234M - Simulation - DEBUG: Simulation time is 0.63469004631 seconds. Real-time rate: 0.192219809826. Spike frequency: 3.95491803279
# 2016-12-24 01:07:22,193 - P5989 - MemTotal:234M - Simulation - DEBUG: Running the simulation 0.081s until 5.723s
# 2016-12-24 01:07:22,686 - P5989 - MemTotal:233M - Simulation - DEBUG: Simulation time is 0.489542961121 seconds. Real-time rate: 0.165460452775. Spike frequency: 5.67592592593
# 2016-12-24 01:07:22,690 - P5989 - MemTotal:233M - Simulation - DEBUG: Running the simulation 0.482s until 6.205s
# 2016-12-24 01:07:24,314 - P5989 - MemTotal:235M - Simulation - DEBUG: Simulation time is 1.61957597733 seconds. Real-time rate: 0.171032420756. Spike frequency: 3.83393501805
# 2016-12-24 01:07:26,695 - P5989 - MemTotal:240M - Simulation - DEBUG: Simulation time is 1.01596188545 seconds. Real-time rate: 0.201779223153. Spike frequency: 5.0487804878
# 2016-12-24 01:07:26,699 - P5989 - MemTotal:240M - Simulation - DEBUG: Running the simulation 0.369s until 6.574s
# 2016-12-24 01:07:28,561 - P5989 - MemTotal:241M - Simulation - DEBUG: Simulation time is 1.85807394981 seconds. Real-time rate: 0.198592741714. Spike frequency: 3.37533875339
# 2016-12-24 01:07:28,565 - P5989 - MemTotal:241M - Simulation - DEBUG: Running the simulation 0.103s until 6.677s
# 2016-12-24 01:07:29,078 - P5989 - MemTotal:240M - Simulation - DEBUG: Simulation time is 0.508774995804 seconds. Real-time rate: 0.202447055869. Spike frequency: 2.96601941748
# 2016-12-24 01:07:29,082 - P5989 - MemTotal:240M - Simulation - DEBUG: Running the simulation 0.732s until 7.409s
# 2016-12-24 01:07:30,714 - P5989 - MemTotal:241M - Simulation - DEBUG: Simulation time is 1.62819099426 seconds. Real-time rate: 0.198379674828. Spike frequency: 3.03018575851
# 2016-12-24 01:07:33,953 - P5989 - MemTotal:237M - Simulation - DEBUG: Simulation time is 1.98643612862 seconds. Real-time rate: 0.205896375981. Spike frequency: 2.8771393643
# 2016-12-24 01:07:33,957 - P5989 - MemTotal:237M - Simulation - DEBUG: Running the simulation 0.047s until 7.456s
# 2016-12-24 01:07:34,211 - P5989 - MemTotal:238M - Simulation - DEBUG: Simulation time is 0.25049996376 seconds. Real-time rate: 0.187624777643. Spike frequency: 6.24468085106
# 2016-12-24 01:07:34,216 - P5989 - MemTotal:238M - Simulation - DEBUG: Running the simulation 0.217s until 7.673s
# 2016-12-24 01:07:35,299 - P5989 - MemTotal:239M - Simulation - DEBUG: Simulation time is 1.07817602158 seconds. Real-time rate: 0.201265837542. Spike frequency: 4.26036866359
# 2016-12-24 01:07:35,303 - P5989 - MemTotal:239M - Simulation - DEBUG: Running the simulation 0.07s until 7.743s
# 2016-12-24 01:07:35,655 - P5989 - MemTotal:239M - Simulation - DEBUG: Simulation time is 0.34735918045 seconds. Real-time rate: 0.20152051231. Spike frequency: 2.15
# 2016-12-24 01:07:35,659 - P5989 - MemTotal:239M - Simulation - DEBUG: Running the simulation 0.032s until 7.775s
# 2016-12-24 01:07:35,820 - P5989 - MemTotal:239M - Simulation - DEBUG: Simulation time is 0.157628059387 seconds. Real-time rate: 0.203009541096. Spike frequency: 0.0859375
# 2016-12-24 01:07:35,824 - P5989 - MemTotal:239M - Simulation - DEBUG: Running the simulation 0.247s until 8.022s
# 2016-12-24 01:07:36,939 - P5989 - MemTotal:240M - Simulation - DEBUG: Simulation time is 1.11100912094 seconds. Real-time rate: 0.202518589415. Spike frequency: 3.91888888889
# 2016-12-24 01:07:38,349 - P5989 - MemTotal:241M - Simulation - DEBUG: Simulation time is 0.0932168960571 seconds. Real-time rate: 0.236008716558. Spike frequency: 0.0
# 2016-12-24 01:07:38,353 - P5989 - MemTotal:241M - Simulation - DEBUG: Running the simulation 0.144s until 8.166s
# 2016-12-24 01:07:39,055 - P5989 - MemTotal:241M - Simulation - DEBUG: Simulation time is 0.69751906395 seconds. Real-time rate: 0.206445970358. Spike frequency: 4.19444444444
# 2016-12-24 01:07:39,059 - P5989 - MemTotal:241M - Simulation - DEBUG: Running the simulation 0.054s until 8.22s
# 2016-12-24 01:07:39,337 - P5989 - MemTotal:242M - Simulation - DEBUG: Simulation time is 0.273715019226 seconds. Real-time rate: 0.197285483832. Spike frequency: 7.06481481481
# 2016-12-24 01:07:39,342 - P5989 - MemTotal:242M - Simulation - DEBUG: Running the simulation 0.554s until 8.774s
# 2016-12-24 01:07:42,065 - P5989 - MemTotal:242M - Simulation - DEBUG: Simulation time is 2.71818089485 seconds. Real-time rate: 0.203812778263. Spike frequency: 2.4905234657
# 2016-12-24 01:07:42,069 - P5989 - MemTotal:242M - Simulation - DEBUG: Running the simulation 0.12s until 8.894s
# 2016-12-24 01:07:42,679 - P5989 - MemTotal:243M - Simulation - DEBUG: Simulation time is 0.604466915131 seconds. Real-time rate: 0.198522031556. Spike frequency: 3.62291666667
# 2016-12-24 01:07:42,683 - P5989 - MemTotal:243M - Simulation - DEBUG: Running the simulation 0.017s until 8.911s
# 2016-12-24 01:07:42,778 - P5989 - MemTotal:244M - Simulation - DEBUG: Simulation time is 0.090460062027 seconds. Real-time rate: 0.187928237269. Spike frequency: 0.588235294118
# 2016-12-24 01:07:42,782 - P5989 - MemTotal:244M - Simulation - DEBUG: Running the simulation 0.473s until 9.384s
# 2016-12-24 01:07:43,223 - P5989 - MemTotal:244M - Simulation - DEBUG: Simulation time is 0.435563087463 seconds. Real-time rate: 0.204333201232. Spike frequency: 5.60674157303
# 2016-12-24 01:07:46,335 - P5989 - MemTotal:242M - Simulation - DEBUG: Simulation time is 1.83094000816 seconds. Real-time rate: 0.209728335329. Spike frequency: 3.80729166667
# 2016-12-24 01:07:46,339 - P5989 - MemTotal:242M - Simulation - DEBUG: Running the simulation 0.066s until 9.45s
# 2016-12-24 01:07:46,683 - P5989 - MemTotal:240M - Simulation - DEBUG: Simulation time is 0.338443040848 seconds. Real-time rate: 0.19501065773. Spike frequency: 6.53787878788
# 2016-12-24 01:07:46,687 - P5989 - MemTotal:240M - Simulation - DEBUG: Running the simulation 0.571s until 10.021s
# 2016-12-24 01:07:49,349 - P5989 - MemTotal:240M - Simulation - DEBUG: Simulation time is 2.65715789795 seconds. Real-time rate: 0.206988075652. Spike frequency: 2.78454545455
# 2016-12-24 01:07:50,696 - P5989 - MemTotal:240M - Simulation - DEBUG: Simulation time is 0.0884578227997 seconds. Real-time rate: 0.237401275945. Spike frequency: 0.0
# 2016-12-24 01:07:50,699 - P5989 - MemTotal:240M - Simulation - DEBUG: Running the simulation 0.45s until 10.471s
# 2016-12-24 01:07:52,855 - P5989 - MemTotal:242M - Simulation - DEBUG: Simulation time is 2.1502571106 seconds. Real-time rate: 0.209277298879. Spike frequency: 4.14222222222
# 2016-12-24 01:07:52,859 - P5989 - MemTotal:242M - Simulation - DEBUG: Running the simulation 0.197s until 10.668s
# 2016-12-24 01:07:53,808 - P5989 - MemTotal:243M - Simulation - DEBUG: Simulation time is 0.943993091583 seconds. Real-time rate: 0.208687967906. Spike frequency: 3.68401015228
# 2016-12-24 01:07:53,812 - P5989 - MemTotal:243M - Simulation - DEBUG: Running the simulation 0.046s until 10.714s
# 2016-12-24 01:07:54,048 - P5989 - MemTotal:243M - Simulation - DEBUG: Simulation time is 0.229779005051 seconds. Real-time rate: 0.200192354344. Spike frequency: 7.66847826087
# 2016-12-24 01:07:54,051 - P5989 - MemTotal:243M - Simulation - DEBUG: Running the simulation 0.27s until 10.984s
# 2016-12-24 01:07:55,417 - P5989 - MemTotal:245M - Simulation - DEBUG: Simulation time is 1.36001896858 seconds. Real-time rate: 0.198526642817. Spike frequency: 4.06018518519
# 2016-12-24 01:07:55,421 - P5989 - MemTotal:245M - Simulation - DEBUG: Running the simulation 0.134s until 11.118s
# 2016-12-24 01:07:55,516 - P5989 - MemTotal:245M - Simulation - DEBUG: Simulation time is 0.0898418426514 seconds. Real-time rate: 0.17809073732. Spike frequency: 0.0
# 2016-12-24 01:07:57,443 - P5989 - MemTotal:250M - Simulation - DEBUG: Simulation time is 0.55832695961 seconds. Real-time rate: 0.211345696225. Spike frequency: 3.18008474576
# 2016-12-24 01:07:57,447 - P5989 - MemTotal:250M - Simulation - DEBUG: Running the simulation 0.445s until 11.563s
# 2016-12-24 01:07:59,580 - P5989 - MemTotal:246M - Simulation - DEBUG: Simulation time is 2.1252989769 seconds. Real-time rate: 0.20938230566. Spike frequency: 5.32303370787
# 2016-12-24 01:07:59,584 - P5989 - MemTotal:246M - Simulation - DEBUG: Running the simulation 0.272s until 11.835s
# 2016-12-24 01:08:00,980 - P5989 - MemTotal:246M - Simulation - DEBUG: Simulation time is 1.38832402229 seconds. Real-time rate: 0.195919681308. Spike frequency: 4.49264705882
# 2016-12-24 01:08:00,984 - P5989 - MemTotal:246M - Simulation - DEBUG: Running the simulation 0.005s until 11.84s
# 2016-12-24 01:08:01,016 - P5989 - MemTotal:246M - Simulation - DEBUG: Simulation time is 0.0286159515381 seconds. Real-time rate: 0.174727721122. Spike frequency: 0.6
# 2016-12-24 01:08:01,020 - P5989 - MemTotal:246M - Simulation - DEBUG: Running the simulation 0.346s until 12.186s
# 2016-12-24 01:08:01,848 - P5989 - MemTotal:249M - Simulation - DEBUG: Simulation time is 0.821089029312 seconds. Real-time rate: 0.194863156477. Spike frequency: 2.6609375
# 2016-12-24 01:08:04,007 - P5989 - MemTotal:248M - Simulation - DEBUG: Simulation time is 0.853116035461 seconds. Real-time rate: 0.218024268996. Spike frequency: 3.13440860215
# 2016-12-24 01:08:04,010 - P5989 - MemTotal:248M - Simulation - DEBUG: Running the simulation 0.101s until 12.287s
# 2016-12-24 01:08:04,489 - P5989 - MemTotal:248M - Simulation - DEBUG: Simulation time is 0.473246097565 seconds. Real-time rate: 0.213419615121. Spike frequency: 2.31188118812
# 2016-12-24 01:08:04,493 - P5989 - MemTotal:248M - Simulation - DEBUG: Running the simulation 0.207s until 12.494s
# 2016-12-24 01:08:05,490 - P5989 - MemTotal:247M - Simulation - DEBUG: Simulation time is 0.990432024002 seconds. Real-time rate: 0.208999704153. Spike frequency: 3.3115942029
# 2016-12-24 01:08:05,494 - P5989 - MemTotal:247M - Simulation - DEBUG: Running the simulation 0.002s until 12.496s
# 2016-12-24 01:08:05,511 - P5989 - MemTotal:247M - Simulation - DEBUG: Simulation time is 0.0128800868988 seconds. Real-time rate: 0.155278455473. Spike frequency: 0.0
# 2016-12-24 01:08:05,515 - P5989 - MemTotal:247M - Simulation - DEBUG: Running the simulation 0.222s until 12.718s
# 2016-12-24 01:08:06,601 - P5989 - MemTotal:249M - Simulation - DEBUG: Simulation time is 1.07996106148 seconds. Real-time rate: 0.205562966961. Spike frequency: 2.96396396396
# 2016-12-24 01:08:06,605 - P5989 - MemTotal:248M - Simulation - DEBUG: Running the simulation 0.254s until 12.972s
# 2016-12-24 01:08:07,893 - P5989 - MemTotal:249M - Simulation - DEBUG: Simulation time is 1.27896499634 seconds. Real-time rate: 0.198598085739. Spike frequency: 3.95570866142
# 2016-12-24 01:08:07,897 - P5989 - MemTotal:249M - Simulation - DEBUG: Running the simulation 0.714s until 13.686s
# 2016-12-24 01:08:08,046 - P5989 - MemTotal:249M - Simulation - DEBUG: Simulation time is 0.144321203232 seconds. Real-time rate: 0.194011686246. Spike frequency: 0.0892857142857
# 2016-12-24 01:08:12,549 - P5989 - MemTotal:249M - Simulation - DEBUG: Simulation time is 3.18307185173 seconds. Real-time rate: 0.215515084784. Spike frequency: 4.69679300292
# 2016-12-24 01:08:12,552 - P5989 - MemTotal:249M - Simulation - DEBUG: Running the simulation 0.111s until 13.797s
# 2016-12-24 01:08:13,091 - P5989 - MemTotal:249M - Simulation - DEBUG: Simulation time is 0.532114028931 seconds. Real-time rate: 0.208601904789. Spike frequency: 4.40315315315
# 2016-12-24 01:08:13,094 - P5989 - MemTotal:249M - Simulation - DEBUG: Running the simulation 0.24s until 14.037s
# 2016-12-24 01:08:14,151 - P5989 - MemTotal:249M - Simulation - DEBUG: Simulation time is 1.04822611809 seconds. Real-time rate: 0.193660505589. Spike frequency: 4.71921182266
# 2016-12-24 01:08:15,641 - P5989 - MemTotal:250M - Simulation - DEBUG: Simulation time is 0.159760951996 seconds. Real-time rate: 0.231596016034. Spike frequency: 2.25675675676
# 2016-12-24 01:08:15,645 - P5989 - MemTotal:250M - Simulation - DEBUG: Running the simulation 0.047s until 14.084s
# 2016-12-24 01:08:15,877 - P5989 - MemTotal:252M - Simulation - DEBUG: Simulation time is 0.225208997726 seconds. Real-time rate: 0.208695036497. Spike frequency: 11.1542553191
# 2016-12-24 01:08:15,881 - P5989 - MemTotal:252M - Simulation - DEBUG: Running the simulation 0.023s until 14.107s
# 2016-12-24 01:08:15,995 - P5989 - MemTotal:252M - Simulation - DEBUG: Simulation time is 0.108879089355 seconds. Real-time rate: 0.211243500806. Spike frequency: 0.521739130435
# 2016-12-24 01:08:15,998 - P5989 - MemTotal:252M - Simulation - DEBUG: Running the simulation 0.093s until 14.2s
# 2016-12-24 01:08:16,442 - P5989 - MemTotal:253M - Simulation - DEBUG: Simulation time is 0.435761928558 seconds. Real-time rate: 0.213419286783. Spike frequency: 4.84139784946
# 2016-12-24 01:08:16,447 - P5989 - MemTotal:253M - Simulation - DEBUG: Running the simulation 0.09s until 14.29s
# 2016-12-24 01:08:16,865 - P5989 - MemTotal:253M - Simulation - DEBUG: Simulation time is 0.411413908005 seconds. Real-time rate: 0.218757796586. Spike frequency: 0.961111111111
# 2016-12-24 01:08:16,868 - P5989 - MemTotal:253M - Simulation - DEBUG: Running the simulation 0.139s until 14.429s
# 2016-12-24 01:08:17,544 - P5989 - MemTotal:253M - Simulation - DEBUG: Simulation time is 0.668740987778 seconds. Real-time rate: 0.207853268366. Spike frequency: 4.4190647482
# 2016-12-24 01:08:17,548 - P5989 - MemTotal:253M - Simulation - DEBUG: Running the simulation 0.533s until 14.962s
# 2016-12-24 01:08:20,141 - P5989 - MemTotal:253M - Simulation - DEBUG: Simulation time is 2.58430314064 seconds. Real-time rate: 0.2062451543. Spike frequency: 4.91932457786
# 2016-12-24 01:08:20,145 - P5989 - MemTotal:253M - Simulation - DEBUG: Running the simulation 0.314s until 15.276s
# 2016-12-24 01:08:20,342 - P5989 - MemTotal:253M - Simulation - DEBUG: Simulation time is 0.19105887413 seconds. Real-time rate: 0.19889157294. Spike frequency: 1.26315789474
# 2016-12-24 01:08:22,921 - P5989 - MemTotal:256M - Simulation - DEBUG: Simulation time is 1.26830792427 seconds. Real-time rate: 0.217612769516. Spike frequency: 4.60960144928
# 2016-12-24 01:08:22,925 - P5989 - MemTotal:256M - Simulation - DEBUG: Running the simulation 0.038s until 15.314s
# 2016-12-24 01:08:23,128 - P5989 - MemTotal:257M - Simulation - DEBUG: Simulation time is 0.195123910904 seconds. Real-time rate: 0.194748044071. Spike frequency: 10.0855263158
# 2016-12-24 01:08:23,131 - P5989 - MemTotal:257M - Simulation - DEBUG: Running the simulation 0.167s until 15.481s
# 2016-12-24 01:08:23,922 - P5989 - MemTotal:258M - Simulation - DEBUG: Simulation time is 0.782305002213 seconds. Real-time rate: 0.213471727175. Spike frequency: 3.68862275449
# 2016-12-24 01:08:23,926 - P5989 - MemTotal:258M - Simulation - DEBUG: Running the simulation 0.206s until 15.687s
# 2016-12-24 01:08:24,956 - P5989 - MemTotal:258M - Simulation - DEBUG: Simulation time is 1.02186894417 seconds. Real-time rate: 0.201591408738. Spike frequency: 3.50242718447
# 2016-12-24 01:08:24,960 - P5989 - MemTotal:258M - Simulation - DEBUG: Running the simulation 0.42s until 16.107s
# 2016-12-24 01:08:26,553 - P5989 - MemTotal:259M - Simulation - DEBUG: Simulation time is 1.58439493179 seconds. Real-time rate: 0.197551755386. Spike frequency: 2.32028753994
# 2016-12-24 01:08:28,352 - P5989 - MemTotal:258M - Simulation - DEBUG: Simulation time is 0.495527029037 seconds. Real-time rate: 0.21593171256. Spike frequency: 2.8691588785
# 2016-12-24 01:08:28,355 - P5989 - MemTotal:258M - Simulation - DEBUG: Running the simulation 0.655s until 16.762s
# 2016-12-24 01:08:31,394 - P5989 - MemTotal:258M - Simulation - DEBUG: Simulation time is 3.02954292297 seconds. Real-time rate: 0.216204231679. Spike frequency: 4.32633587786
# 2016-12-24 01:08:31,398 - P5989 - MemTotal:258M - Simulation - DEBUG: Running the simulation 0.246s until 17.008s
# 2016-12-24 01:08:32,619 - P5989 - MemTotal:256M - Simulation - DEBUG: Simulation time is 1.21318984032 seconds. Real-time rate: 0.196177046733. Spike frequency: 2.99579831933
# 2016-12-24 01:08:33,991 - P5989 - MemTotal:256M - Simulation - DEBUG: Simulation time is 0.0349788665771 seconds. Real-time rate: 0.228709526147. Spike frequency: 0.0
# 2016-12-24 01:08:33,995 - P5989 - MemTotal:256M - Simulation - DEBUG: Running the simulation 0.214s until 17.222s
# 2016-12-24 01:08:35,003 - P5989 - MemTotal:256M - Simulation - DEBUG: Simulation time is 0.999747991562 seconds. Real-time rate: 0.2140539434. Spike frequency: 5.60163551402
# 2016-12-24 01:08:35,007 - P5989 - MemTotal:256M - Simulation - DEBUG: Running the simulation 0.218s until 17.44s
# 2016-12-24 01:08:36,047 - P5989 - MemTotal:256M - Simulation - DEBUG: Simulation time is 1.03155589104 seconds. Real-time rate: 0.211331253977. Spike frequency: 4.42660550459
# 2016-12-24 01:08:36,051 - P5989 - MemTotal:256M - Simulation - DEBUG: Running the simulation 0.211s until 17.651s
# 2016-12-24 01:08:37,046 - P5989 - MemTotal:257M - Simulation - DEBUG: Simulation time is 0.985764980316 seconds. Real-time rate: 0.214046962728. Spike frequency: 2.99407582938
# 2016-12-24 01:08:37,049 - P5989 - MemTotal:257M - Simulation - DEBUG: Running the simulation 0.14s until 17.791s
# 2016-12-24 01:08:37,740 - P5989 - MemTotal:255M - Simulation - DEBUG: Simulation time is 0.682455062866 seconds. Real-time rate: 0.205141712059. Spike frequency: 4.03035714286
# 2016-12-24 01:08:37,744 - P5989 - MemTotal:255M - Simulation - DEBUG: Running the simulation 0.02s until 17.811s
# 2016-12-24 01:08:37,864 - P5989 - MemTotal:256M - Simulation - DEBUG: Simulation time is 0.112709999084 seconds. Real-time rate: 0.17744654567. Spike frequency: 16.8875
# 2016-12-24 01:08:37,868 - P5989 - MemTotal:256M - Simulation - DEBUG: Running the simulation 0.414s until 18.225s
# 2016-12-24 01:08:38,851 - P5989 - MemTotal:255M - Simulation - DEBUG: Simulation time is 0.973119974136 seconds. Real-time rate: 0.194220656264. Spike frequency: 2.05555555556
# 2016-12-24 01:08:41,231 - P5989 - MemTotal:261M - Simulation - DEBUG: Simulation time is 1.04836988449 seconds. Real-time rate: 0.214618908201. Spike frequency: 3.11777777778
# 2016-12-24 01:08:41,234 - P5989 - MemTotal:261M - Simulation - DEBUG: Running the simulation 0.302s until 18.527s
# 2016-12-24 01:08:42,654 - P5989 - MemTotal:262M - Simulation - DEBUG: Simulation time is 1.41058397293 seconds. Real-time rate: 0.214095726164. Spike frequency: 2.39817880795
# 2016-12-24 01:08:42,657 - P5989 - MemTotal:262M - Simulation - DEBUG: Running the simulation 0.24s until 18.767s
# 2016-12-24 01:08:43,797 - P5989 - MemTotal:262M - Simulation - DEBUG: Simulation time is 1.13113093376 seconds. Real-time rate: 0.212177028173. Spike frequency: 3.28645833333
# 2016-12-24 01:08:43,801 - P5989 - MemTotal:262M - Simulation - DEBUG: Running the simulation 0.395s until 19.162s
# 2016-12-24 01:08:44,978 - P5989 - MemTotal:262M - Simulation - DEBUG: Simulation time is 1.16692996025 seconds. Real-time rate: 0.199669224321. Spike frequency: 3.6813304721
# 2016-12-24 01:08:47,036 - P5989 - MemTotal:262M - Simulation - DEBUG: Simulation time is 0.732214927673 seconds. Real-time rate: 0.221246513663. Spike frequency: 2.89660493827
# 2016-12-24 01:08:47,040 - P5989 - MemTotal:262M - Simulation - DEBUG: Running the simulation 0.239s until 19.401s
# 2016-12-24 01:08:48,190 - P5989 - MemTotal:261M - Simulation - DEBUG: Simulation time is 1.14033198357 seconds. Real-time rate: 0.209588087894. Spike frequency: 3.05648535565
# 2016-12-24 01:08:48,194 - P5989 - MemTotal:261M - Simulation - DEBUG: Running the simulation 0.072s until 19.473s
# 2016-12-24 01:08:48,553 - P5989 - MemTotal:261M - Simulation - DEBUG: Simulation time is 0.350265979767 seconds. Real-time rate: 0.205558073462. Spike frequency: 6.68402777778
# 2016-12-24 01:08:48,556 - P5989 - MemTotal:261M - Simulation - DEBUG: Running the simulation 0.231s until 19.704s
# 2016-12-24 01:08:49,692 - P5989 - MemTotal:260M - Simulation - DEBUG: Simulation time is 1.12589597702 seconds. Real-time rate: 0.205169931072. Spike frequency: 4.45238095238
# 2016-12-24 01:08:49,696 - P5989 - MemTotal:260M - Simulation - DEBUG: Running the simulation 0.117s until 19.821s
# 2016-12-24 01:08:50,301 - P5989 - MemTotal:260M - Simulation - DEBUG: Simulation time is 0.595671892166 seconds. Real-time rate: 0.196416855552. Spike frequency: 4.00854700855
# 2016-12-24 01:08:50,306 - P5989 - MemTotal:260M - Simulation - DEBUG: Running the simulation 0.103s until 19.924s
# 2016-12-24 01:08:50,833 - P5989 - MemTotal:262M - Simulation - DEBUG: Simulation time is 0.517857074738 seconds. Real-time rate: 0.198896577887. Spike frequency: 2.26699029126
# 2016-12-24 01:08:50,837 - P5989 - MemTotal:262M - Simulation - DEBUG: Running the simulation 0.073s until 19.997s
# 2016-12-24 01:08:51,209 - P5989 - MemTotal:262M - Simulation - DEBUG: Simulation time is 0.362187862396 seconds. Real-time rate: 0.201552861316. Spike frequency: 3.17123287671
# 2016-12-24 01:08:51,213 - P5989 - MemTotal:262M - Simulation - DEBUG: Running the simulation 0.225s until 20.222s
# 2016-12-24 01:08:51,236 - P5989 - MemTotal:262M - Simulation - DEBUG: Simulation time is 0.0163187980652 seconds. Real-time rate: 0.183837068638. Spike frequency: 0.0
# 2016-12-24 01:08:53,569 - P5989 - MemTotal:259M - Simulation - DEBUG: Simulation time is 1.00710201263 seconds. Real-time rate: 0.220434471598. Spike frequency: 4.71283783784
# 2016-12-24 01:08:53,573 - P5989 - MemTotal:259M - Simulation - DEBUG: Running the simulation 0.226s until 20.448s
# 2016-12-24 01:08:54,622 - P5989 - MemTotal:263M - Simulation - DEBUG: Simulation time is 1.0398170948 seconds. Real-time rate: 0.217345917017. Spike frequency: 4.6592920354
# 2016-12-24 01:08:54,626 - P5989 - MemTotal:263M - Simulation - DEBUG: Running the simulation 0.27s until 20.718s
# 2016-12-24 01:08:55,877 - P5989 - MemTotal:263M - Simulation - DEBUG: Simulation time is 1.23985695839 seconds. Real-time rate: 0.21776705625. Spike frequency: 3.62314814815
# 2016-12-24 01:08:55,881 - P5989 - MemTotal:263M - Simulation - DEBUG: Running the simulation 0.022s until 20.74s
# 2016-12-24 01:08:55,994 - P5989 - MemTotal:263M - Simulation - DEBUG: Simulation time is 0.105623006821 seconds. Real-time rate: 0.208287954132. Spike frequency: 0.0
# 2016-12-24 01:08:55,998 - P5989 - MemTotal:263M - Simulation - DEBUG: Running the simulation 0.113s until 20.853s
# 2016-12-24 01:08:56,547 - P5989 - MemTotal:263M - Simulation - DEBUG: Simulation time is 0.538923025131 seconds. Real-time rate: 0.209677439505. Spike frequency: 5.54867256637
# 2016-12-24 01:08:56,551 - P5989 - MemTotal:263M - Simulation - DEBUG: Running the simulation 0.225s until 21.078s
# 2016-12-24 01:08:57,280 - P5989 - MemTotal:261M - Simulation - DEBUG: Simulation time is 0.718016862869 seconds. Real-time rate: 0.204730567765. Spike frequency: 2.79081632653
# 2016-12-24 01:08:58,967 - P5989 - MemTotal:262M - Simulation - DEBUG: Simulation time is 0.353773832321 seconds. Real-time rate: 0.220479845805. Spike frequency: 4.61538461538
# 2016-12-24 01:08:58,971 - P5989 - MemTotal:262M - Simulation - DEBUG: Running the simulation 0.562s until 21.64s
# 2016-12-24 01:09:01,600 - P5989 - MemTotal:261M - Simulation - DEBUG: Simulation time is 2.61699080467 seconds. Real-time rate: 0.214750467979. Spike frequency: 3.35943060498
# 2016-12-24 01:09:01,604 - P5989 - MemTotal:261M - Simulation - DEBUG: Running the simulation 0.072s until 21.712s
# 2016-12-24 01:09:01,986 - P5989 - MemTotal:261M - Simulation - DEBUG: Simulation time is 0.372031927109 seconds. Real-time rate: 0.193531777123. Spike frequency: 7.67708333333
# 2016-12-24 01:09:01,989 - P5989 - MemTotal:261M - Simulation - DEBUG: Running the simulation 0.021s until 21.733s
# 2016-12-24 01:09:02,104 - P5989 - MemTotal:261M - Simulation - DEBUG: Simulation time is 0.10724401474 seconds. Real-time rate: 0.195815123584. Spike frequency: 0.0595238095238
# 2016-12-24 01:09:02,109 - P5989 - MemTotal:261M - Simulation - DEBUG: Running the simulation 0.623s until 22.356s
# 2016-12-24 01:09:03,451 - P5989 - MemTotal:262M - Simulation - DEBUG: Simulation time is 1.33023118973 seconds. Real-time rate: 0.200716989695. Spike frequency: 2.68820224719
# 2016-12-24 01:09:06,374 - P5989 - MemTotal:263M - Simulation - DEBUG: Simulation time is 1.61077713966 seconds. Real-time rate: 0.22101133126. Spike frequency: 2.93328651685
# 2016-12-24 01:09:06,378 - P5989 - MemTotal:263M - Simulation - DEBUG: Running the simulation 0.11s until 22.466s
# 2016-12-24 01:09:06,923 - P5989 - MemTotal:267M - Simulation - DEBUG: Simulation time is 0.533597946167 seconds. Real-time rate: 0.206147720002. Spike frequency: 6.48181818182
# 2016-12-24 01:09:06,926 - P5989 - MemTotal:267M - Simulation - DEBUG: Running the simulation 0.005s until 22.471s
# 2016-12-24 01:09:06,958 - P5989 - MemTotal:267M - Simulation - DEBUG: Simulation time is 0.0239560604095 seconds. Real-time rate: 0.20871545298. Spike frequency: 0.1
# 2016-12-24 01:09:06,962 - P5989 - MemTotal:267M - Simulation - DEBUG: Running the simulation 0.162s until 22.633s
# 2016-12-24 01:09:07,725 - P5989 - MemTotal:270M - Simulation - DEBUG: Simulation time is 0.750820159912 seconds. Real-time rate: 0.215764051965. Spike frequency: 3.01697530864
# 2016-12-24 01:09:07,728 - P5989 - MemTotal:270M - Simulation - DEBUG: Running the simulation 0.302s until 22.935s
# 2016-12-24 01:09:09,309 - P5989 - MemTotal:270M - Simulation - DEBUG: Simulation time is 1.567745924 seconds. Real-time rate: 0.192633254775. Spike frequency: 3.77483443709
# 2016-12-24 01:09:09,313 - P5989 - MemTotal:270M - Simulation - DEBUG: Running the simulation 0.208s until 23.143s
# 2016-12-24 01:09:09,654 - P5989 - MemTotal:270M - Simulation - DEBUG: Simulation time is 0.331640005112 seconds. Real-time rate: 0.195995654921. Spike frequency: 0.103846153846
# 2016-12-24 01:09:11,606 - P5989 - MemTotal:266M - Simulation - DEBUG: Simulation time is 0.649220228195 seconds. Real-time rate: 0.22026423976. Spike frequency: 4.42132867133
# 2016-12-24 01:09:11,610 - P5989 - MemTotal:266M - Simulation - DEBUG: Running the simulation 0.011s until 23.154s
# 2016-12-24 01:09:11,672 - P5989 - MemTotal:267M - Simulation - DEBUG: Simulation time is 0.0537841320038 seconds. Real-time rate: 0.204521288904. Spike frequency: 0.204545454545
# 2016-12-24 01:09:11,676 - P5989 - MemTotal:266M - Simulation - DEBUG: Running the simulation 0.223s until 23.377s
# 2016-12-24 01:09:12,709 - P5989 - MemTotal:270M - Simulation - DEBUG: Simulation time is 1.02084302902 seconds. Real-time rate: 0.218446904823. Spike frequency: 3.7735426009
# 2016-12-24 01:09:12,713 - P5989 - MemTotal:270M - Simulation - DEBUG: Running the simulation 0.488s until 23.865s
# 2016-12-24 01:09:15,037 - P5989 - MemTotal:269M - Simulation - DEBUG: Simulation time is 2.31080198288 seconds. Real-time rate: 0.211182093323. Spike frequency: 4.89036885246
# 2016-12-24 01:09:15,041 - P5989 - MemTotal:269M - Simulation - DEBUG: Running the simulation 0.618s until 24.483s
# 2016-12-24 01:09:15,731 - P5989 - MemTotal:269M - Simulation - DEBUG: Simulation time is 0.677518844604 seconds. Real-time rate: 0.199256450319. Spike frequency: 4.01111111111
# 2016-12-24 01:09:19,285 - P5989 - MemTotal:265M - Simulation - DEBUG: Simulation time is 2.22321105003 seconds. Real-time rate: 0.21725332824. Spike frequency: 3.80486542443
# 2016-12-24 01:09:19,288 - P5989 - MemTotal:265M - Simulation - DEBUG: Running the simulation 0.03s until 24.513s
# 2016-12-24 01:09:19,435 - P5989 - MemTotal:265M - Simulation - DEBUG: Simulation time is 0.137846946716 seconds. Real-time rate: 0.217632676781. Spike frequency: 0.0
# 2016-12-24 01:09:19,438 - P5989 - MemTotal:265M - Simulation - DEBUG: Running the simulation 0.145s until 24.658s
# 2016-12-24 01:09:20,208 - P5989 - MemTotal:271M - Simulation - DEBUG: Simulation time is 0.757121086121 seconds. Real-time rate: 0.191514940817. Spike frequency: 3.15344827586
# 2016-12-24 01:09:20,212 - P5989 - MemTotal:271M - Simulation - DEBUG: Running the simulation 0.049s until 24.707s
# 2016-12-24 01:09:20,495 - P5989 - MemTotal:273M - Simulation - DEBUG: Simulation time is 0.268803834915 seconds. Real-time rate: 0.182289065985. Spike frequency: 8.22959183673
# 2016-12-24 01:09:20,499 - P5989 - MemTotal:273M - Simulation - DEBUG: Running the simulation 0.231s until 24.938s
# 2016-12-24 01:09:21,675 - P5989 - MemTotal:273M - Simulation - DEBUG: Simulation time is 1.16364383698 seconds. Real-time rate: 0.198514350061. Spike frequency: 3.16017316017
# 2016-12-24 01:09:21,680 - P5989 - MemTotal:273M - Simulation - DEBUG: Running the simulation 0.045s until 24.983s
# 2016-12-24 01:09:21,916 - P5989 - MemTotal:273M - Simulation - DEBUG: Simulation time is 0.227246046066 seconds. Real-time rate: 0.198023247396. Spike frequency: 0.444444444444
# 2016-12-24 01:09:21,920 - P5989 - MemTotal:273M - Simulation - DEBUG: Running the simulation 0.017s until 25.0s
# 2016-12-24 01:09:22,015 - P5989 - MemTotal:273M - Simulation - DEBUG: Simulation time is 0.0860321521759 seconds. Real-time rate: 0.197600543169. Spike frequency: 0.0
# 2016-12-24 01:09:23,335 - P5989 - MemTotal:270M - Simulation - DEBUG: Running the simulation 0.168s until 25.168s
# 2016-12-24 01:09:24,102 - P5989 - MemTotal:268M - Simulation - DEBUG: Simulation time is 0.754287004471 seconds. Real-time rate: 0.222726891759. Spike frequency: 2.33630952381
# 2016-12-24 01:09:24,105 - P5989 - MemTotal:268M - Simulation - DEBUG: Running the simulation 0.227s until 25.395s
# 2016-12-24 01:09:25,174 - P5989 - MemTotal:272M - Simulation - DEBUG: Simulation time is 1.05707478523 seconds. Real-time rate: 0.214743557572. Spike frequency: 3.34140969163
# 2016-12-24 01:09:25,179 - P5989 - MemTotal:272M - Simulation - DEBUG: Running the simulation 0.075s until 25.47s
# 2016-12-24 01:09:25,569 - P5989 - MemTotal:275M - Simulation - DEBUG: Simulation time is 0.377150058746 seconds. Real-time rate: 0.198859839103. Spike frequency: 6.28
# 2016-12-24 01:09:25,573 - P5989 - MemTotal:275M - Simulation - DEBUG: Running the simulation 0.016s until 25.486s
# 2016-12-24 01:09:25,662 - P5989 - MemTotal:275M - Simulation - DEBUG: Simulation time is 0.0783591270447 seconds. Real-time rate: 0.204188083806. Spike frequency: 0.015625
# 2016-12-24 01:09:25,666 - P5989 - MemTotal:275M - Simulation - DEBUG: Running the simulation 0.057s until 25.543s
# 2016-12-24 01:09:25,940 - P5989 - MemTotal:275M - Simulation - DEBUG: Simulation time is 0.261822938919 seconds. Real-time rate: 0.217704377757. Spike frequency: 1.67105263158
# 2016-12-24 01:09:25,944 - P5989 - MemTotal:275M - Simulation - DEBUG: Running the simulation 0.501s until 26.044s
# 2016-12-24 01:09:28,149 - P5989 - MemTotal:273M - Simulation - DEBUG: Simulation time is 2.19213700294 seconds. Real-time rate: 0.208472371657. Spike frequency: 3.78336980306
# 2016-12-24 01:09:29,666 - P5989 - MemTotal:267M - Simulation - DEBUG: Simulation time is 0.192562818527 seconds. Real-time rate: 0.228496863187. Spike frequency: 2.13068181818
# 2016-12-24 01:09:29,670 - P5989 - MemTotal:267M - Simulation - DEBUG: Running the simulation 0.326s until 26.37s
# 2016-12-24 01:09:31,233 - P5989 - MemTotal:273M - Simulation - DEBUG: Simulation time is 1.5499920845 seconds. Real-time rate: 0.21032365472. Spike frequency: 3.06134969325
# 2016-12-24 01:09:31,237 - P5989 - MemTotal:273M - Simulation - DEBUG: Running the simulation 0.073s until 26.443s
# 2016-12-24 01:09:31,610 - P5989 - MemTotal:271M - Simulation - DEBUG: Simulation time is 0.360378980637 seconds. Real-time rate: 0.202564533234. Spike frequency: 7.05136986301
# 2016-12-24 01:09:31,614 - P5989 - MemTotal:271M - Simulation - DEBUG: Running the simulation 0.489s until 26.932s
# 2016-12-24 01:09:34,038 - P5989 - MemTotal:274M - Simulation - DEBUG: Simulation time is 2.40933704376 seconds. Real-time rate: 0.202960395793. Spike frequency: 3.99846625767
# 2016-12-24 01:09:34,042 - P5989 - MemTotal:274M - Simulation - DEBUG: Running the simulation 0.057s until 26.989s
# 2016-12-24 01:09:34,355 - P5989 - MemTotal:274M - Simulation - DEBUG: Simulation time is 0.298106908798 seconds. Real-time rate: 0.191206571595. Spike frequency: 4.75438596491
# 2016-12-24 01:09:34,359 - P5989 - MemTotal:274M - Simulation - DEBUG: Running the simulation 0.015s until 27.004s
# 2016-12-24 01:09:34,430 - P5989 - MemTotal:274M - Simulation - DEBUG: Simulation time is 0.0616068840027 seconds. Real-time rate: 0.178551474857. Spike frequency: 0.0
# 2016-12-24 01:09:35,755 - P5989 - MemTotal:270M - Simulation - DEBUG: Simulation time is 0.0179951190948 seconds. Real-time rate: 0.222282496654. Spike frequency: 0.0
# 2016-12-24 01:09:35,759 - P5989 - MemTotal:270M - Simulation - DEBUG: Running the simulation 0.003s until 27.007s
# 2016-12-24 01:09:35,782 - P5989 - MemTotal:270M - Simulation - DEBUG: Simulation time is 0.0143721103668 seconds. Real-time rate: 0.208737612183. Spike frequency: 0.0
# 2016-12-24 01:09:35,785 - P5989 - MemTotal:270M - Simulation - DEBUG: Running the simulation 0.235s until 27.242s
# 2016-12-24 01:09:36,881 - P5989 - MemTotal:277M - Simulation - DEBUG: Simulation time is 1.08073377609 seconds. Real-time rate: 0.217444855707. Spike frequency: 4.14893617021
# 2016-12-24 01:09:36,885 - P5989 - MemTotal:277M - Simulation - DEBUG: Running the simulation 0.061s until 27.303s
# 2016-12-24 01:09:37,197 - P5989 - MemTotal:277M - Simulation - DEBUG: Simulation time is 0.298830032349 seconds. Real-time rate: 0.204129416045. Spike frequency: 4.27459016393
# 2016-12-24 01:09:37,201 - P5989 - MemTotal:277M - Simulation - DEBUG: Running the simulation 0.16s until 27.463s
# 2016-12-24 01:09:37,968 - P5989 - MemTotal:277M - Simulation - DEBUG: Simulation time is 0.751807928085 seconds. Real-time rate: 0.212820314901. Spike frequency: 3.275
# 2016-12-24 01:09:37,971 - P5989 - MemTotal:277M - Simulation - DEBUG: Running the simulation 0.013s until 27.476s
# 2016-12-24 01:09:38,044 - P5989 - MemTotal:277M - Simulation - DEBUG: Simulation time is 0.0627717971802 seconds. Real-time rate: 0.207099375579. Spike frequency: 0.480769230769
# 2016-12-24 01:09:38,048 - P5989 - MemTotal:277M - Simulation - DEBUG: Running the simulation 0.113s until 27.589s
# 2016-12-24 01:09:38,592 - P5989 - MemTotal:277M - Simulation - DEBUG: Simulation time is 0.529359102249 seconds. Real-time rate: 0.213465678629. Spike frequency: 4.16592920354
# 2016-12-24 01:09:38,595 - P5989 - MemTotal:277M - Simulation - DEBUG: Running the simulation 0.062s until 27.651s
# 2016-12-24 01:09:38,890 - P5989 - MemTotal:277M - Simulation - DEBUG: Simulation time is 0.285450935364 seconds. Real-time rate: 0.21720019912. Spike frequency: 0.125
# 2016-12-24 01:09:38,894 - P5989 - MemTotal:277M - Simulation - DEBUG: Running the simulation 0.18s until 27.831s
# 2016-12-24 01:09:39,788 - P5989 - MemTotal:276M - Simulation - DEBUG: Simulation time is 0.878144025803 seconds. Real-time rate: 0.204977765277. Spike frequency: 4.47777777778
# 2016-12-24 01:09:39,792 - P5989 - MemTotal:276M - Simulation - DEBUG: Running the simulation 0.022s until 27.853s
# 2016-12-24 01:09:39,916 - P5989 - MemTotal:276M - Simulation - DEBUG: Simulation time is 0.112408876419 seconds. Real-time rate: 0.195714081493. Spike frequency: 0.0795454545455
# 2016-12-24 01:09:39,920 - P5989 - MemTotal:276M - Simulation - DEBUG: Running the simulation 0.057s until 27.91s
# 2016-12-24 01:09:40,219 - P5989 - MemTotal:276M - Simulation - DEBUG: Simulation time is 0.287363052368 seconds. Real-time rate: 0.198355354073. Spike frequency: 0.25
# 2016-12-24 01:09:40,222 - P5989 - MemTotal:276M - Simulation - DEBUG: Running the simulation 0.222s until 28.132s
# 2016-12-24 01:09:40,712 - P5989 - MemTotal:277M - Simulation - DEBUG: Simulation time is 0.472920894623 seconds. Real-time rate: 0.19030666867. Spike frequency: 6.20555555556
# 2016-12-24 01:09:42,638 - P5989 - MemTotal:271M - Simulation - DEBUG: Simulation time is 0.597529888153 seconds. Real-time rate: 0.220909451756. Spike frequency: 4.33333333333
# 2016-12-24 01:09:42,642 - P5989 - MemTotal:271M - Simulation - DEBUG: Running the simulation 0.081s until 28.213s
# 2016-12-24 01:09:43,050 - P5989 - MemTotal:279M - Simulation - DEBUG: Simulation time is 0.393201112747 seconds. Real-time rate: 0.206001451609. Spike frequency: 6.20679012346
# 2016-12-24 01:09:43,054 - P5989 - MemTotal:279M - Simulation - DEBUG: Running the simulation 0.096s until 28.309s
# 2016-12-24 01:09:43,540 - P5989 - MemTotal:279M - Simulation - DEBUG: Simulation time is 0.469511032104 seconds. Real-time rate: 0.20446803895. Spike frequency: 3.77083333333
# 2016-12-24 01:09:43,545 - P5989 - MemTotal:279M - Simulation - DEBUG: Running the simulation 0.156s until 28.465s
# 2016-12-24 01:09:44,312 - P5989 - MemTotal:279M - Simulation - DEBUG: Simulation time is 0.751504898071 seconds. Real-time rate: 0.207583477367. Spike frequency: 3.19871794872
# 2016-12-24 01:09:44,315 - P5989 - MemTotal:279M - Simulation - DEBUG: Running the simulation 0.23s until 28.695s
# 2016-12-24 01:09:45,415 - P5989 - MemTotal:278M - Simulation - DEBUG: Simulation time is 1.08357787132 seconds. Real-time rate: 0.212259779465. Spike frequency: 3.73152173913
# 2016-12-24 01:09:45,419 - P5989 - MemTotal:278M - Simulation - DEBUG: Running the simulation 0.437s until 29.132s
# 2016-12-24 01:09:46,956 - P5989 - MemTotal:277M - Simulation - DEBUG: Simulation time is 1.51995897293 seconds. Real-time rate: 0.200663310939. Spike frequency: 3.06229508197
# 2016-12-24 01:09:48,909 - P5989 - MemTotal:272M - Simulation - DEBUG: Simulation time is 0.592170953751 seconds. Real-time rate: 0.222908602936. Spike frequency: 3.40909090909
# 2016-12-24 01:09:48,913 - P5989 - MemTotal:272M - Simulation - DEBUG: Running the simulation 0.734s until 29.866s
# 2016-12-24 01:09:52,352 - P5989 - MemTotal:280M - Simulation - DEBUG: Simulation time is 3.42166590691 seconds. Real-time rate: 0.214515391032. Spike frequency: 3.64134877384
# 2016-12-24 01:09:52,357 - P5989 - MemTotal:280M - Simulation - DEBUG: Running the simulation 0.048s until 29.914s
# 2016-12-24 01:09:52,615 - P5989 - MemTotal:284M - Simulation - DEBUG: Simulation time is 0.243500947952 seconds. Real-time rate: 0.197124489262. Spike frequency: 2.15625
# 2016-12-24 01:09:52,619 - P5989 - MemTotal:284M - Simulation - DEBUG: Running the simulation 0.71s until 30.624s
# 2016-12-24 01:09:53,074 - P5989 - MemTotal:280M - Simulation - DEBUG: Simulation time is 0.437477111816 seconds. Real-time rate: 0.19658171291. Spike frequency: 4.56395348837
# 2016-12-24 01:09:57,296 - P5989 - MemTotal:274M - Simulation - DEBUG: Simulation time is 2.88371014595 seconds. Real-time rate: 0.216387906002. Spike frequency: 4.55649038462
# 2016-12-24 01:09:57,300 - P5989 - MemTotal:274M - Simulation - DEBUG: Running the simulation 0.151s until 30.775s
# 2016-12-24 01:09:58,027 - P5989 - MemTotal:283M - Simulation - DEBUG: Simulation time is 0.709995031357 seconds. Real-time rate: 0.212677544674. Spike frequency: 4.41721854305
# 2016-12-24 01:09:58,030 - P5989 - MemTotal:283M - Simulation - DEBUG: Running the simulation 0.053s until 30.828s
# 2016-12-24 01:09:58,334 - P5989 - MemTotal:282M - Simulation - DEBUG: Simulation time is 0.284092187881 seconds. Real-time rate: 0.186559160233. Spike frequency: 6.20283018868
# 2016-12-24 01:09:58,337 - P5989 - MemTotal:282M - Simulation - DEBUG: Running the simulation 0.282s until 31.11s
# 2016-12-24 01:09:59,268 - P5989 - MemTotal:282M - Simulation - DEBUG: Simulation time is 0.913004159927 seconds. Real-time rate: 0.188389064967. Spike frequency: 1.92441860465
# 2016-12-24 01:10:01,102 - P5989 - MemTotal:274M - Simulation - DEBUG: Simulation time is 0.511223077774 seconds. Real-time rate: 0.215170254987. Spike frequency: 2.97727272727
# 2016-12-24 01:10:01,106 - P5989 - MemTotal:274M - Simulation - DEBUG: Running the simulation 0.312s until 31.422s
# 2016-12-24 01:10:02,624 - P5989 - MemTotal:283M - Simulation - DEBUG: Simulation time is 1.50095486641 seconds. Real-time rate: 0.207867676092. Spike frequency: 3.08493589744
# 2016-12-24 01:10:02,627 - P5989 - MemTotal:283M - Simulation - DEBUG: Running the simulation 0.025s until 31.447s
# 2016-12-24 01:10:02,780 - P5989 - MemTotal:287M - Simulation - DEBUG: Simulation time is 0.1366751194 seconds. Real-time rate: 0.182915516077. Spike frequency: 1.0
# 2016-12-24 01:10:02,784 - P5989 - MemTotal:287M - Simulation - DEBUG: Running the simulation 0.499s until 31.946s
# ...
# 2016-12-24 02:05:19,798 - P5989 - MemTotal:1022M - Simulation - DEBUG: Running the simulation 0.067s until 488.005s
# 2016-12-24 02:05:20,449 - P5989 - MemTotal:1022M - Simulation - DEBUG: Simulation time is 0.338768005371 seconds. Real-time rate: 0.183016102514. Spike frequency: 2.57258064518
# 2016-12-24 02:05:22,058 - P5989 - MemTotal:784M - Simulation - DEBUG: Simulation time is 0.0222101211548 seconds. Real-time rate: 0.225122590082. Spike frequency: 0.0
# 2016-12-24 02:05:22,062 - P5989 - MemTotal:784M - Simulation - DEBUG: Running the simulation 0.07s until 488.075s
# 2016-12-24 02:05:22,731 - P5989 - MemTotal:913M - Simulation - DEBUG: Simulation time is 0.393764019012 seconds. Real-time rate: 0.177771448431. Spike frequency: 3.95357142857
# 2016-12-24 02:05:22,734 - P5989 - MemTotal:913M - Simulation - DEBUG: Running the simulation 0.182s until 488.257s
# 2016-12-24 02:05:23,995 - P5989 - MemTotal:1022M - Simulation - DEBUG: Simulation time is 0.972313165665 seconds. Real-time rate: 0.187182490608. Spike frequency: 1.8021978022
# 2016-12-24 02:05:24,000 - P5989 - MemTotal:1022M - Simulation - DEBUG: Running the simulation 0.451s until 488.708s
# 2016-12-24 02:05:26,791 - P5989 - MemTotal:1023M - Simulation - DEBUG: Simulation time is 2.47298002243 seconds. Real-time rate: 0.182371064832. Spike frequency: 4.90022172949
# 2016-12-24 02:05:26,795 - P5989 - MemTotal:1023M - Simulation - DEBUG: Running the simulation 0.783s until 489.491s
# 2016-12-24 02:05:28,670 - P5989 - MemTotal:1023M - Simulation - DEBUG: Simulation time is 1.57983112335 seconds. Real-time rate: 0.184829881931. Spike frequency: 2.69349315069
# 2016-12-24 02:05:32,845 - P5989 - MemTotal:785M - Simulation - DEBUG: Simulation time is 2.55429291725 seconds. Real-time rate: 0.192225408717. Spike frequency: 3.13034623218
# 2016-12-24 02:05:32,849 - P5989 - MemTotal:785M - Simulation - DEBUG: Running the simulation 0.103s until 489.594s
# 2016-12-24 02:05:33,661 - P5989 - MemTotal:915M - Simulation - DEBUG: Simulation time is 0.535018205643 seconds. Real-time rate: 0.192516813285. Spike frequency: 5.03883495146
# 2016-12-24 02:05:33,665 - P5989 - MemTotal:915M - Simulation - DEBUG: Running the simulation 0.567s until 490.161s
# 2016-12-24 02:05:36,066 - P5989 - MemTotal:1025M - Simulation - DEBUG: Simulation time is 2.11158394814 seconds. Real-time rate: 0.192272725107. Spike frequency: 4.3947044335
# 2016-12-24 02:05:38,440 - P5989 - MemTotal:786M - Simulation - DEBUG: Simulation time is 0.787175893784 seconds. Real-time rate: 0.20452862095. Spike frequency: 4.30124223601
# 2016-12-24 02:05:38,444 - P5989 - MemTotal:786M - Simulation - DEBUG: Running the simulation 0.295s until 490.456s
# 2016-12-24 02:05:40,264 - P5989 - MemTotal:917M - Simulation - DEBUG: Simulation time is 1.53297519684 seconds. Real-time rate: 0.192436251159. Spike frequency: 4.78050847458
# 2016-12-24 02:05:40,268 - P5989 - MemTotal:916M - Simulation - DEBUG: Running the simulation 0.24s until 490.696s
# 2016-12-24 02:05:41,868 - P5989 - MemTotal:1026M - Simulation - DEBUG: Simulation time is 1.31375002861 seconds. Real-time rate: 0.182683154918. Spike frequency: 3.71770833333
# 2016-12-24 02:05:41,872 - P5989 - MemTotal:1026M - Simulation - DEBUG: Running the simulation 0.069s until 490.765s
# 2016-12-24 02:05:42,445 - P5989 - MemTotal:1026M - Simulation - DEBUG: Simulation time is 0.341614961624 seconds. Real-time rate: 0.201981785786. Spike frequency: 0.239130434783
# 2016-12-24 02:05:42,449 - P5989 - MemTotal:1026M - Simulation - DEBUG: Running the simulation 0.44s until 491.205s
# 2016-12-24 02:05:44,049 - P5989 - MemTotal:1026M - Simulation - DEBUG: Simulation time is 1.29899501801 seconds. Real-time rate: 0.180909084902. Spike frequency: 5.15638297873
# 2016-12-24 02:05:46,671 - P5989 - MemTotal:787M - Simulation - DEBUG: Simulation time is 1.01643586159 seconds. Real-time rate: 0.201685131101. Spike frequency: 5.86463414633
# 2016-12-24 02:05:46,675 - P5989 - MemTotal:787M - Simulation - DEBUG: Running the simulation 1.23s until 492.435s
# 2016-12-24 02:05:51,413 - P5989 - MemTotal:918M - Simulation - DEBUG: Simulation time is 4.46099591255 seconds. Real-time rate: 0.178211326705. Spike frequency: 4.3786163522
# 2016-12-24 02:05:55,309 - P5989 - MemTotal:789M - Simulation - DEBUG: Simulation time is 2.28395700455 seconds. Real-time rate: 0.190458926825. Spike frequency: 4.94827586206
# 2016-12-24 02:05:55,313 - P5989 - MemTotal:789M - Simulation - DEBUG: Running the simulation 0.219s until 492.654s
# 2016-12-24 02:05:56,733 - P5989 - MemTotal:919M - Simulation - DEBUG: Simulation time is 1.13754105568 seconds. Real-time rate: 0.192520523903. Spike frequency: 2.88470319635
# 2016-12-24 02:05:56,737 - P5989 - MemTotal:919M - Simulation - DEBUG: Running the simulation 0.029s until 492.683s
# 2016-12-24 02:05:57,175 - P5989 - MemTotal:1029M - Simulation - DEBUG: Simulation time is 0.158137083054 seconds. Real-time rate: 0.183385196186. Spike frequency: 12.9310344828
# 2016-12-24 02:05:57,179 - P5989 - MemTotal:1029M - Simulation - DEBUG: Running the simulation 0.217s until 492.9s
# 2016-12-24 02:05:58,596 - P5989 - MemTotal:1029M - Simulation - DEBUG: Simulation time is 1.13020300865 seconds. Real-time rate: 0.192000904562. Spike frequency: 2.62442396313
# 2016-12-24 02:05:58,600 - P5989 - MemTotal:1029M - Simulation - DEBUG: Running the simulation 0.275s until 493.175s
# 2016-12-24 02:05:59,399 - P5989 - MemTotal:1029M - Simulation - DEBUG: Simulation time is 0.510362148285 seconds. Real-time rate: 0.195939295921. Spike frequency: 4.37750000002
# 2016-12-24 02:06:01,921 - P5989 - MemTotal:789M - Simulation - DEBUG: Simulation time is 0.918900966644 seconds. Real-time rate: 0.19044489706. Spike frequency: 3.21285714285
# 2016-12-24 02:06:01,925 - P5989 - MemTotal:789M - Simulation - DEBUG: Running the simulation 0.063s until 493.238s
# 2016-12-24 02:06:02,513 - P5989 - MemTotal:898M - Simulation - DEBUG: Simulation time is 0.320338964462 seconds. Real-time rate: 0.196666678079. Spike frequency: 0.31746031746
# 2016-12-24 02:06:02,517 - P5989 - MemTotal:898M - Simulation - DEBUG: Running the simulation 0.082s until 493.32s
# 2016-12-24 02:06:03,231 - P5989 - MemTotal:1019M - Simulation - DEBUG: Simulation time is 0.437995195389 seconds. Real-time rate: 0.187216665533. Spike frequency: 4.79268292683
# 2016-12-24 02:06:03,235 - P5989 - MemTotal:1019M - Simulation - DEBUG: Running the simulation 0.132s until 493.452s
# 2016-12-24 02:06:04,213 - P5989 - MemTotal:1030M - Simulation - DEBUG: Simulation time is 0.686807870865 seconds. Real-time rate: 0.192193487582. Spike frequency: 2.43181818182
# 2016-12-24 02:06:04,218 - P5989 - MemTotal:1030M - Simulation - DEBUG: Running the simulation 0.758s until 494.21s
# 2016-12-24 02:06:07,443 - P5989 - MemTotal:1030M - Simulation - DEBUG: Simulation time is 2.92261099815 seconds. Real-time rate: 0.187503571411. Spike frequency: 3.73950729927
# 2016-12-24 02:06:10,067 - P5989 - MemTotal:790M - Simulation - DEBUG: Simulation time is 1.00700902939 seconds. Real-time rate: 0.208538348587. Spike frequency: 4.7857142857
# 2016-12-24 02:06:10,071 - P5989 - MemTotal:790M - Simulation - DEBUG: Running the simulation 0.107s until 494.317s
# 2016-12-24 02:06:10,916 - P5989 - MemTotal:899M - Simulation - DEBUG: Simulation time is 0.573376893997 seconds. Real-time rate: 0.186613728457. Spike frequency: 2.52803738318
# 2016-12-24 02:06:10,920 - P5989 - MemTotal:899M - Simulation - DEBUG: Running the simulation 0.012s until 494.329s
# 2016-12-24 02:06:11,230 - P5989 - MemTotal:921M - Simulation - DEBUG: Simulation time is 0.0619320869446 seconds. Real-time rate: 0.193760627036. Spike frequency: 0.833333333333
# 2016-12-24 02:06:11,235 - P5989 - MemTotal:921M - Simulation - DEBUG: Running the simulation 0.305s until 494.634s
# 2016-12-24 02:06:13,130 - P5989 - MemTotal:1031M - Simulation - DEBUG: Simulation time is 1.6030151844 seconds. Real-time rate: 0.19026644474. Spike frequency: 3.27950819672
# 2016-12-24 02:06:13,134 - P5989 - MemTotal:1031M - Simulation - DEBUG: Running the simulation 0.02s until 494.654s
# 2016-12-24 02:06:13,492 - P5989 - MemTotal:1031M - Simulation - DEBUG: Simulation time is 0.104612112045 seconds. Real-time rate: 0.191182451142. Spike frequency: 0.2375
# 2016-12-24 02:06:13,496 - P5989 - MemTotal:1031M - Simulation - DEBUG: Running the simulation 0.348s until 495.002s
# 2016-12-24 02:06:15,669 - P5989 - MemTotal:1032M - Simulation - DEBUG: Simulation time is 1.85942983627 seconds. Real-time rate: 0.186078545826. Spike frequency: 5.25578034683
# 2016-12-24 02:06:17,283 - P5989 - MemTotal:790M - Simulation - DEBUG: Simulation time is 0.0093879699707 seconds. Real-time rate: 0.213038602244. Spike frequency: 0.0
# 2016-12-24 02:06:17,286 - P5989 - MemTotal:790M - Simulation - DEBUG: Running the simulation 0.261s until 495.263s
# 2016-12-24 02:06:18,873 - P5989 - MemTotal:922M - Simulation - DEBUG: Simulation time is 1.29745006561 seconds. Real-time rate: 0.201163811169. Spike frequency: 3.26149425287
# 2016-12-24 02:06:18,877 - P5989 - MemTotal:922M - Simulation - DEBUG: Running the simulation 0.146s until 495.409s
# 2016-12-24 02:06:19,942 - P5989 - MemTotal:1032M - Simulation - DEBUG: Simulation time is 0.773673057556 seconds. Real-time rate: 0.188710203327. Spike frequency: 3.53082191781
# 2016-12-24 02:06:19,947 - P5989 - MemTotal:1032M - Simulation - DEBUG: Running the simulation 0.171s until 495.58s
# 2016-12-24 02:06:21,130 - P5989 - MemTotal:1033M - Simulation - DEBUG: Simulation time is 0.880982160568 seconds. Real-time rate: 0.194101546721. Spike frequency: 6.43859649123
# 2016-12-24 02:06:21,135 - P5989 - MemTotal:1033M - Simulation - DEBUG: Running the simulation 0.135s until 495.715s
# 2016-12-24 02:06:22,142 - P5989 - MemTotal:1033M - Simulation - DEBUG: Simulation time is 0.71372294426 seconds. Real-time rate: 0.189149026363. Spike frequency: 4.22407407407
# 2016-12-24 02:06:22,146 - P5989 - MemTotal:1033M - Simulation - DEBUG: Running the simulation 0.196s until 495.911s
# 2016-12-24 02:06:23,474 - P5989 - MemTotal:1033M - Simulation - DEBUG: Simulation time is 1.03400087357 seconds. Real-time rate: 0.189554965582. Spike frequency: 2.51785714286
# 2016-12-24 02:06:23,478 - P5989 - MemTotal:1033M - Simulation - DEBUG: Running the simulation 0.903s until 496.814s
# 2016-12-24 02:06:24,234 - P5989 - MemTotal:1033M - Simulation - DEBUG: Simulation time is 0.462189912796 seconds. Real-time rate: 0.192561537012. Spike frequency: 5.37359550565
# 2016-12-24 02:06:30,384 - P5989 - MemTotal:792M - Simulation - DEBUG: Simulation time is 4.51206803322 seconds. Real-time rate: 0.180405081219. Spike frequency: 2.99416461916
# 2016-12-24 02:06:30,388 - P5989 - MemTotal:792M - Simulation - DEBUG: Running the simulation 0.092s until 496.906s
# 2016-12-24 02:06:31,061 - P5989 - MemTotal:792M - Simulation - DEBUG: Simulation time is 0.442625999451 seconds. Real-time rate: 0.207850420251. Spike frequency: 0.394021739131
# 2016-12-24 02:06:31,065 - P5989 - MemTotal:792M - Simulation - DEBUG: Running the simulation 0.276s until 497.182s
# 2016-12-24 02:06:31,848 - P5989 - MemTotal:924M - Simulation - DEBUG: Simulation time is 0.506219148636 seconds. Real-time rate: 0.185690328493. Spike frequency: 2.5425531915
# 2016-12-24 02:06:34,337 - P5989 - MemTotal:792M - Simulation - DEBUG: Simulation time is 0.899950027466 seconds. Real-time rate: 0.202233451243. Spike frequency: 2.78159340659
# 2016-12-24 02:06:34,341 - P5989 - MemTotal:792M - Simulation - DEBUG: Running the simulation 0.032s until 497.214s
# 2016-12-24 02:06:34,737 - P5989 - MemTotal:792M - Simulation - DEBUG: Simulation time is 0.17053604126 seconds. Real-time rate: 0.187643619282. Spike frequency: 0.3515625
# 2016-12-24 02:06:34,741 - P5989 - MemTotal:792M - Simulation - DEBUG: Running the simulation 0.352s until 497.566s
# 2016-12-24 02:06:36,897 - P5989 - MemTotal:924M - Simulation - DEBUG: Simulation time is 1.86203312874 seconds. Real-time rate: 0.189040675253. Spike frequency: 3.73224431818
# 2016-12-24 02:06:36,901 - P5989 - MemTotal:924M - Simulation - DEBUG: Running the simulation 0.102s until 497.668s
# 2016-12-24 02:06:37,730 - P5989 - MemTotal:1035M - Simulation - DEBUG: Simulation time is 0.547168970108 seconds. Real-time rate: 0.186414079694. Spike frequency: 3.0
# 2016-12-24 02:06:37,734 - P5989 - MemTotal:1035M - Simulation - DEBUG: Running the simulation 0.578s until 498.246s
# 2016-12-24 02:06:39,781 - P5989 - MemTotal:1035M - Simulation - DEBUG: Simulation time is 1.74249911308 seconds. Real-time rate: 0.190530943463. Spike frequency: 5.21460843374
# 2016-12-24 02:06:42,599 - P5989 - MemTotal:793M - Simulation - DEBUG: Simulation time is 1.18447303772 seconds. Real-time rate: 0.207687293984. Spike frequency: 5.12703252032
# 2016-12-24 02:06:42,603 - P5989 - MemTotal:793M - Simulation - DEBUG: Running the simulation 0.37s until 498.616s
# 2016-12-24 02:06:44,886 - P5989 - MemTotal:925M - Simulation - DEBUG: Simulation time is 1.98974585533 seconds. Real-time rate: 0.185953396515. Spike frequency: 4.01418918919
# 2016-12-24 02:06:44,890 - P5989 - MemTotal:925M - Simulation - DEBUG: Running the simulation 0.167s until 498.783s
# 2016-12-24 02:06:46,086 - P5989 - MemTotal:1037M - Simulation - DEBUG: Simulation time is 0.905687093735 seconds. Real-time rate: 0.18439039394. Spike frequency: 3.67365269461
# 2016-12-24 02:06:46,090 - P5989 - MemTotal:1037M - Simulation - DEBUG: Running the simulation 0.163s until 498.946s
# 2016-12-24 02:06:47,253 - P5989 - MemTotal:1037M - Simulation - DEBUG: Simulation time is 0.871605873108 seconds. Real-time rate: 0.187011130867. Spike frequency: 5.38343558282
# 2016-12-24 02:06:47,257 - P5989 - MemTotal:1037M - Simulation - DEBUG: Running the simulation 0.054s until 499.0s
# 2016-12-24 02:06:47,770 - P5989 - MemTotal:1037M - Simulation - DEBUG: Simulation time is 0.272708892822 seconds. Real-time rate: 0.198013344709. Spike frequency: 0.162037037038
# 2016-12-24 02:06:49,061 - P5989 - MemTotal:637M - Simulation - DEBUG: Running the simulation 0.0330000000004s until 499.033s
# 2016-12-24 02:06:49,526 - P5989 - MemTotal:794M - Simulation - DEBUG: Simulation time is 0.149757862091 seconds. Real-time rate: 0.220355709808. Spike frequency: 1.02272727271
# 2016-12-24 02:06:49,529 - P5989 - MemTotal:794M - Simulation - DEBUG: Running the simulation 0.158s until 499.191s
# 2016-12-24 02:06:50,584 - P5989 - MemTotal:926M - Simulation - DEBUG: Simulation time is 0.783643960953 seconds. Real-time rate: 0.201622175213. Spike frequency: 5.66930379747
# 2016-12-24 02:06:50,587 - P5989 - MemTotal:926M - Simulation - DEBUG: Running the simulation 0.056s until 499.247s
# 2016-12-24 02:06:51,128 - P5989 - MemTotal:1026M - Simulation - DEBUG: Simulation time is 0.270755052567 seconds. Real-time rate: 0.20682901194. Spike frequency: 1.44642857143
# 2016-12-24 02:06:51,132 - P5989 - MemTotal:1026M - Simulation - DEBUG: Running the simulation 0.089s until 499.336s
# 2016-12-24 02:06:51,877 - P5989 - MemTotal:1038M - Simulation - DEBUG: Simulation time is 0.452290058136 seconds. Real-time rate: 0.196776379226. Spike frequency: 4.95786516854
# 2016-12-24 02:06:51,881 - P5989 - MemTotal:1038M - Simulation - DEBUG: Running the simulation 0.093s until 499.429s
# 2016-12-24 02:06:52,649 - P5989 - MemTotal:1038M - Simulation - DEBUG: Simulation time is 0.469044923782 seconds. Real-time rate: 0.198275251014. Spike frequency: 2.30913978495
# 2016-12-24 02:06:52,653 - P5989 - MemTotal:1038M - Simulation - DEBUG: Running the simulation 0.232s until 499.661s
# 2016-12-24 02:06:54,122 - P5989 - MemTotal:1038M - Simulation - DEBUG: Simulation time is 1.16880607605 seconds. Real-time rate: 0.198493150193. Spike frequency: 3.44181034483
# 2016-12-24 02:06:54,126 - P5989 - MemTotal:1038M - Simulation - DEBUG: Running the simulation 0.339s until 500.0s
# 2016-12-24 02:06:56,311 - P5989 - MemTotal:1038M - Simulation - DEBUG: Simulation time is 1.87306308746 seconds. Real-time rate: 0.180986963156. Spike frequency: 3.7883480826

# %% [markdown]
# Save the network state after the simulation

# %%
simulation.cerebellum.update_network_weights()
#simulation.cerebellum.save_network()

# %% [markdown]
# ## GrC activity analysis

# %% [markdown]
# Calculate the average firing frequency of each granular cells during the ending 100 seconds

# %%
gtime,gcell_id = simulation.cerebellum.get_spike_activity(neuron_layer = 'grclayer',
                                                          init_time = simulation.current_time-simulation_time, 
                                                          end_time = simulation.current_time)
import numpy
firing_frequency = numpy.bincount(gcell_id) / (simulation_time*8.0)
# %matplotlib inline
import matplotlib.pyplot as plt
plt.hist(firing_frequency, bins=20)
plt.ylabel('Number of GrC cells')
plt.xlabel('Av. Spikes per Oscillatory Cycle')

# %% [markdown]
# Get the histogram of input synapses for the granular cells

# %%
target_cell_index = simulation.cerebellum.layer_map['mfgrcsynapsis'].target_index
cell_number = simulation.cerebellum.layer_map['grclayer'].number_of_neurons
number_of_inputs = numpy.bincount(target_cell_index)
plt.hist(number_of_inputs, bins=30)
plt.ylabel('Number of GrC cells')
plt.xlabel('Number of input synapses from glomeruli')

# %% [markdown]
# Plot the histogram of non-zero weights between MF and GrC

# %%
target_cell_index = simulation.cerebellum.layer_map['mfgrcsynapsis'].target_index
source_cell_index = simulation.cerebellum.layer_map['mfgrcsynapsis'].source_index
weight = simulation.cerebellum.layer_map['mfgrcsynapsis'].weights
plt.figure()
plt.hist(weight, bins=20)
plt.xlabel('Synaptic Weight')
plt.ylabel('Number of MF-GrC synapses')
max_weight = numpy.max(weight)
active_synapses = weight>max_weight*0.2
number_of_active_inputs = numpy.bincount(target_cell_index[active_synapses])
plt.figure()
plt.hist(number_of_active_inputs, bins=10)
plt.ylabel('Number of GrC cells')
plt.xlabel('Number of active inputs')
print 'Number of active synapses MF-GrC:',numpy.count_nonzero(active_synapses)
# Out:
# Number of active synapses MF-GrC: 8743

# %% [markdown]
# Histogram of active synapses connecting input fibers included in the pattern

# %%
for pat_id in range(simulation.pattern_generator.number_of_patterns):
    included_in_pattern = numpy.in1d(source_cell_index, simulation.pattern_generator.fibers_in_pattern[pat_id,:])
    included_and_active = numpy.logical_and(included_in_pattern,active_synapses)
    number_of_active_inputs_in_pattern = numpy.bincount(target_cell_index[included_and_active])
    plt.figure()
    plt.hist(number_of_active_inputs_in_pattern, bins=10)
    plt.ylabel('Number of GrC cells')
    plt.xlabel('Number of active inputs in pattern')
    print 'Number of active MF-GrC synapses also included in pattern',pat_id,':', numpy.count_nonzero(included_and_active)
    plt.figure()
    simulation.pattern_generator.fibers_in_pattern[0,:]
    activation_level = [simulation.pattern_generator.pattern_activation[pat_id,numpy.where(simulation.pattern_generator.fibers_in_pattern[pat_id,:]==source)[0][0]] 
                    for source in source_cell_index[included_and_active]]
    plt.hist(activation_level, bins=20)
    plt.ylabel('Number of active synapses')
    plt.xlabel('Activation level')
# Out:
# Number of active MF-GrC synapses also included in pattern 0 : 2810
# Number of active MF-GrC synapses also included in pattern 1 : 3112
# Number of active MF-GrC synapses also included in pattern 2 : 2532
# Number of active MF-GrC synapses also included in pattern 3 : 2679

# %% [markdown]
# Define some auxiliar functions:

# %%
def calc_Ind_Pattern_Hit_Matrix(cell_firing, pattern_present):
    '''
    Calculate the correct rejection, hit, miss and false alarm matrisses with 1 line for each cell and 1 column for each pattern (including noise).
    @param cell_firing Boolean matrix including 1 line for each cell and 1 column for each time bin.
    @param pattern_present Boolean matrix including 1 line for each pattern and 1 column for each time bin.
    '''
    hit_matrix = numpy.empty((len(pattern_present),len(cell_firing)))
    cr_matrix = numpy.empty((len(pattern_present),len(cell_firing)))
    miss_matrix = numpy.empty((len(pattern_present),len(cell_firing)))
    fa_matrix = numpy.empty((len(pattern_present),len(cell_firing)))
    faa_matrix = numpy.empty((len(cell_firing)))
    
    for index_pat, pattern in enumerate(pattern_present):
        if (numpy.count_nonzero(pattern)):
            for index_cell, firing in enumerate(cell_firing):
                hit_matrix[index_pat,index_cell] = numpy.count_nonzero(firing&pattern)/float(numpy.count_nonzero(pattern))
                cr_matrix[index_pat,index_cell] = numpy.count_nonzero(~firing&~pattern)/float(numpy.count_nonzero(~pattern))
                miss_matrix[index_pat,index_cell] = numpy.count_nonzero(~firing&pattern)/float(numpy.count_nonzero(pattern))
                fa_matrix[index_pat,index_cell] = numpy.count_nonzero(firing&~pattern)/float(numpy.count_nonzero(~pattern))
        else:
            print 'Pattern',index_pat,'never occurs. Statistics will not be calculated'
               
    any_pattern = numpy.any(pattern_present, axis=0)
    for index_cell, firing in enumerate(cell_firing):
        faa_matrix[index_cell] = numpy.count_nonzero(firing&~any_pattern)/float(numpy.count_nonzero(~any_pattern))
        
    return cr_matrix, hit_matrix, miss_matrix, fa_matrix, faa_matrix

def analyze_activity(layer, window_length, time_bin):

    cell_index = range(simulation.cerebellum.get_number_of_elements(layer=layer))
    pattern_generator = simulation.pattern_generator
    inv_time_bin = 1./time_bin

    # Generate the time bin matrix
    total_time = pattern_generator.simulation_time
    bin_time_init = numpy.linspace(0.0, window_length-time_bin, num=window_length*inv_time_bin)
    bin_time_end = numpy.linspace(time_bin,window_length,num=window_length*inv_time_bin)

    # Initialize a matrix
    pattern_index = range(0,pattern_generator.number_of_patterns)
    num_patterns = len(pattern_index)
    num_bins = len(bin_time_init)
    num_cells = len(cell_index)

    # Calculate the time of each pattern interval
    time_end_of_pattern = pattern_generator.pattern_length_cum
    time_init_of_pattern = numpy.append([0.0],time_end_of_pattern[:-1])

    # Calculate the bin of each pattern interval. Check the round of the last bin to avoid out of range
    bin_end_of_pattern = numpy.floor(time_end_of_pattern * inv_time_bin).astype(int)
    if (bin_end_of_pattern[-1]>=num_bins):
        bin_end_of_pattern[-1]=num_bins-1
    bin_init_of_pattern = numpy.append([0],bin_end_of_pattern[:-1])
    if (bin_init_of_pattern[-1]>=num_bins):
        bin_init_of_pattern[-1]=num_bins-1

    # Final matrix indicating which bins are considered of each pattern
    bin_is_pattern = numpy.empty((num_patterns, num_bins),dtype='bool')
    bin_is_pattern[:,:] = False
    bin_pattern = numpy.zeros(num_bins)

    # Final matrix indicating which bins are registered spikes
    bin_has_fired = numpy.empty((num_cells, num_bins), dtype='bool')
    bin_has_fired[:,:] = False

    for key, value in enumerate(pattern_index):
        time_of_pattern_in_bin = numpy.zeros(num_bins)
        for index in pattern_generator.pattern_id_index[value]:
            init_bin = bin_init_of_pattern[index]
            end_bin = bin_end_of_pattern[index]

            list_of_bins = range(init_bin,end_bin+1)

            # Add the time of the initial bin (if exists)
            if init_bin!=end_bin:
                time_of_pattern_in_bin[list_of_bins[0]] += (bin_time_end[init_bin] - time_init_of_pattern[index])

            # Add the time of the intermediate bins (if exist)
            time_of_pattern_in_bin[list_of_bins[1:-1]] += time_bin

            # Add the time of the final bin
            time_of_pattern_in_bin[list_of_bins[-1]] += (time_end_of_pattern[index] - max(time_init_of_pattern[index],bin_time_init[end_bin]))

        # Those bins where the time in the pattern is longer than half of the bin are set to part of that pattern    
        bin_is_pattern[key,time_of_pattern_in_bin>(time_bin/2.)] = True
        bin_pattern[bin_is_pattern[key,:]] = bin_pattern[bin_is_pattern[key,:]] + 2**value

    # Create a map of cells to index
    cell_map = dict()
    for key, value in enumerate(cell_index):
        cell_map[value] = key

    # Load data from the data provider
    gtime,gcell_id = simulation.cerebellum.get_spike_activity(neuron_layer = layer, init_time = 0.0, end_time = window_length)


    spike_bin_index = numpy.floor(gtime*inv_time_bin).astype(int)

    av_firing_rate = float(len(gtime))/(len(cell_index)*(window_length))
    print 'Average firing rate in MI analysis:',av_firing_rate,'Hz'

    cell_index = numpy.array([cell_map[value] for value in gcell_id])

    # Final matrix indicating which bins are registered spikes
    if len(spike_bin_index) and len(cell_index):
        bin_has_fired[cell_index,spike_bin_index] = True

    # Calculate mutual information in the time window
    init_bin = int(0 * inv_time_bin)
    end_bin = int(window_length * inv_time_bin)


    # Calculate hit matrix for each pattern
    cr_matrix, hit_matrix, miss_matrix, fa_matrix, faa_matrix = calc_Ind_Pattern_Hit_Matrix(bin_has_fired[:,init_bin:end_bin], bin_is_pattern[:,init_bin:end_bin])

    return cr_matrix, hit_matrix, miss_matrix, fa_matrix, faa_matrix

# %% [markdown]
# Represent the hit rate matrix of each GrC to each pattern

# %%
layer = 'grclayer'
window_length = simulation.config_options['hit_analysis']['window_length'] = simulation_time
time_bin = simulation.config_options['hit_analysis']['time_bin'] = 0.125

cr_matrix, hit_matrix, miss_matrix, fa_matrix, faa_matrix = analyze_activity(layer, window_length, time_bin)

#numpy.set_printoptions(threshold=numpy.nan)
#print 'Individual pattern hit matrix:'
#print hit_matrix
#print 'Individual pattern correct rejection matrix:'
#print cr_matrix
#print 'Individual pattern miss matrix:'
#print miss_matrix
#print 'Individual pattern false alarm matrix:'
#print fa_matrix
#print 'All patterns false alarm array:'
#print faa_matrix

extended_hit = numpy.append(hit_matrix, [faa_matrix], axis=0)
selected_pattern = numpy.argmax(extended_hit, axis=0)
plt.figure()
plt.hist(selected_pattern, bins=simulation.pattern_generator.number_of_patterns+1)
plt.ylabel('Count GrCs')
plt.xlabel('Favourite pattern')
cell_sorted = numpy.argsort(selected_pattern)
plt.figure()
plt.matshow(extended_hit[:,cell_sorted], extent=[0,simulation.cerebellum.get_number_of_elements(layer=layer),
                                                 simulation.pattern_generator.number_of_patterns+1,0], 
            vmin=0, vmax=1.0, aspect='auto')
plt.ylabel('Pattern')
plt.xlabel('GrC neuron')
plt.colorbar()
# Out:
# Average firing rate in MI analysis: 3.6613265 Hz

# %% [markdown]
# Estimate the goodness of the matrix

# %%
extended_hit = numpy.append(hit_matrix, [faa_matrix], axis=0)
selected_pattern = numpy.argmax(extended_hit, axis=0)

# Select those cells mainly responding to one of the patterns
ind = numpy.where(selected_pattern<simulation.pattern_generator.number_of_patterns)

diagonal = hit_matrix[selected_pattern[ind],ind]

# Create a new matrix setting the diagonal values to zero
zero_matrix = numpy.copy(hit_matrix)
zero_matrix[selected_pattern[ind],ind] = 0.0

# Calculate the average of the diagonal elements
av_selected = numpy.average(diagonal)
av_nonselected = numpy.sum(zero_matrix[:])/(simulation.cerebellum.get_number_of_elements(layer=layer)*(simulation.pattern_generator.number_of_patterns))
print 'Average hits of selected elements:',av_selected
print 'Average hits of non-selected elements:',av_nonselected
hit_index = av_selected - av_nonselected
print 'Hit index:',hit_index
# Out:
# Average hits of selected elements: 0.717864887756
# Average hits of non-selected elements: 0.284278093704
# Hit index: 0.433586794052

# %% [markdown]
# ## GoC activity analysis

# %% [markdown]
# Calculate the average firing frequency of each Golgi cells during the ending 100 seconds

# %%
gtime,gcell_id = simulation.cerebellum.get_spike_activity(neuron_layer = 'goclayer',
                                                          init_time = simulation.current_time-simulation_time, 
                                                          end_time = simulation.current_time)
import numpy
firing_frequency = numpy.bincount(gcell_id) / (simulation_time*8.0)
# %matplotlib inline
import matplotlib.pyplot as plt
plt.hist(firing_frequency, bins=20)
plt.ylabel('Number of GoC cells')
plt.xlabel('Av. Spikes per Oscillatory Cycle')

# %% [markdown]
# Get the histogram of input synapses for the Golgi cells

# %%
target_cell_index = simulation.cerebellum.layer_map['mfgocsynapsis'].target_index
cell_number = simulation.cerebellum.layer_map['goclayer'].number_of_neurons
number_of_inputs = numpy.bincount(target_cell_index)
plt.hist(number_of_inputs, bins=30)
plt.ylabel('Number of GoC cells')
plt.xlabel('Number of input synapses from glomeruli')

# %% [markdown]
# Plot the histogram of non-zero weights between MF and GoC

# %%
target_cell_index = simulation.cerebellum.layer_map['mfgocsynapsis'].target_index
source_cell_index = simulation.cerebellum.layer_map['mfgocsynapsis'].source_index
weight = simulation.cerebellum.layer_map['mfgocsynapsis'].weights
plt.figure()
plt.hist(weight, bins=20)
plt.ylabel('Synaptic Weight')
plt.xlabel('Number of MF-GoC synapses')
max_weight = numpy.max(weight)
active_synapses = weight>max_weight*0.2
number_of_active_inputs = numpy.bincount(target_cell_index[active_synapses])
plt.figure()
plt.hist(number_of_active_inputs, bins=10)
plt.ylabel('Number of GoC cells')
plt.xlabel('Number of active inputs')
print 'Number of active synapses MF-GoC:',numpy.count_nonzero(active_synapses)
# Out:
# Number of active synapses MF-GoC: 82

# %% [markdown]
# Histogram of active synapses connecting input fibers included in the pattern

# %%
for pat_id in range(simulation.pattern_generator.number_of_patterns):
    included_in_pattern = numpy.in1d(source_cell_index, simulation.pattern_generator.fibers_in_pattern[pat_id,:])
    included_and_active = numpy.logical_and(included_in_pattern,active_synapses)
    number_of_active_inputs_in_pattern = numpy.bincount(target_cell_index[included_and_active])
    plt.figure()
    plt.hist(number_of_active_inputs_in_pattern, bins=10)
    plt.ylabel('Number of GoC cells')
    plt.xlabel('Number of active inputs in pattern')
    print 'Number of active MF-GoC synapses also included in pattern',pat_id,':', numpy.count_nonzero(included_and_active)
    plt.figure()
    simulation.pattern_generator.fibers_in_pattern[0,:]
    activation_level = [simulation.pattern_generator.pattern_activation[pat_id,numpy.where(simulation.pattern_generator.fibers_in_pattern[pat_id,:]==source)[0][0]] 
                    for source in source_cell_index[included_and_active]]
    plt.hist(activation_level, bins=20)
    plt.ylabel('Number of active synapses')
    plt.xlabel('Activation level')
# Out:
# Number of active MF-GoC synapses also included in pattern 0 : 23
# Number of active MF-GoC synapses also included in pattern 1 : 74
# Number of active MF-GoC synapses also included in pattern 2 : 11
# Number of active MF-GoC synapses also included in pattern 3 : 17

# %% [markdown]
# Represent the hit rate matrix of each GoC to each pattern

# %%
layer = 'goclayer'
window_length = simulation.config_options['hit_analysis']['window_length'] = simulation_time
time_bin = simulation.config_options['hit_analysis']['time_bin'] = 0.125

cr_matrix, hit_matrix, miss_matrix, fa_matrix, faa_matrix = analyze_activity(layer, window_length, time_bin)

#numpy.set_printoptions(threshold=numpy.nan)
#print 'Individual pattern hit matrix:'
#print hit_matrix
#print 'Individual pattern correct rejection matrix:'
#print cr_matrix
#print 'Individual pattern miss matrix:'
#print miss_matrix
#print 'Individual pattern false alarm matrix:'
#print fa_matrix
#print 'All patterns false alarm array:'
#print faa_matrix

extended_hit = numpy.append(hit_matrix, [faa_matrix], axis=0)
selected_pattern = numpy.argmax(extended_hit, axis=0)
plt.figure()
plt.hist(selected_pattern, bins=simulation.pattern_generator.number_of_patterns+1)
plt.ylabel('Count GoCs')
plt.xlabel('Favourite pattern')
cell_sorted = numpy.argsort(selected_pattern)
plt.figure()
plt.matshow(extended_hit[:,cell_sorted], extent=[0,simulation.cerebellum.get_number_of_elements(layer=layer),0,simulation.pattern_generator.number_of_patterns+1], vmin=0, vmax=1.0, aspect='auto')
plt.ylabel('Pattern')
plt.xlabel('GoC neuron')
plt.colorbar()
# Out:
# Average firing rate in MI analysis: 2.25088888889 Hz

# %% [markdown]
# Estimate the goodness of the matrix

# %%
extended_hit = numpy.append(hit_matrix, [faa_matrix], axis=0)
selected_pattern = numpy.argmax(extended_hit, axis=0)

# Select those cells mainly responding to one of the patterns
ind = numpy.where(selected_pattern<simulation.pattern_generator.number_of_patterns)

diagonal = hit_matrix[selected_pattern[ind],ind]

# Create a new matrix setting the diagonal values to zero
zero_matrix = numpy.copy(hit_matrix)
zero_matrix[selected_pattern[ind],ind] = 0.0

# Calculate the average of the diagonal elements
av_selected = numpy.average(diagonal)
av_nonselected = numpy.sum(zero_matrix[:])/(simulation.cerebellum.get_number_of_elements(layer=layer)*(simulation.pattern_generator.number_of_patterns))
print 'Average hits of selected elements:',av_selected
print 'Average hits of non-selected elements:',av_nonselected
hit_index = av_selected - av_nonselected
print 'Hit index:',hit_index
# Out:
# Average hits of selected elements: 0.900739520433
# Average hits of non-selected elements: 0.248675991144
# Hit index: 0.652063529289

# %% [markdown]
# ## PC activity analysis

# %% [markdown]
# Histogram of active synapses GrC-PC

# %%
target_cell_index = simulation.cerebellum.layer_map['grcpcsynapsis'].target_index
source_cell_index = simulation.cerebellum.layer_map['grcpcsynapsis'].source_index
weight = simulation.cerebellum.layer_map['grcpcsynapsis'].weights
plt.figure()
plt.hist(weight, bins=20)
plt.ylabel('Number of GrC-PC synapses')
plt.xlabel('Synaptic Weight')
max_weight = numpy.max(weight)
active_synapses = weight>max_weight*0.2
number_of_active_inputs = numpy.bincount(target_cell_index[active_synapses])
plt.figure()
plt.hist(number_of_active_inputs, bins=10)
plt.ylabel('Number of PC cells')
plt.xlabel('Number of active inputs')
print 'Number of active synapses GrC-PC:',numpy.count_nonzero(active_synapses)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-173f00ce56f7> in <module>()
# ----> 1 target_cell_index = simulation.cerebellum.layer_map['grcpcsynapsis'].target_index
#       2 source_cell_index = simulation.cerebellum.layer_map['grcpcsynapsis'].source_index
#       3 weight = simulation.cerebellum.layer_map['grcpcsynapsis'].weights
#       4 plt.figure()
#       5 plt.hist(weight, bins=20)
#
# KeyError: 'grcpcsynapsis'
